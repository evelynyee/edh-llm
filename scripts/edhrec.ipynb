# %%
from openai import OpenAI

client = OpenAI(api_key='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')

stream = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "system", "content": "You are building a magic the gathering deck for EDH format. You take in a list of already selected cards plus the commander as well as a pool of possible cards and return a single card from the pool. Take a wholistic look at the deck and consider the amount of lands, the amount of ramp, the amount of draw, the amount of interaction, and the synergy. Return just the name of the selected card from the provided pool. Do not return any extra words"},
              {"role": "user", "content": "Commander: Marneus Calgar  Selected: An Offer you can't refuse, Arcane Denial, Arcane Sanctum, Arcane Signet, Ashnod's Altar, Austere Command, Battle Angels of Tyr, Birth of the Imperium Pool: Deadly Dispute, Aura Shards, Delayed Blast Fireball, Cathat's Crusade"},],
    stream=True,
)
for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Aura Shards

# %%
import pickle

# %%
with open('../data/commanders.pkl', 'rb') as file:
    decks = pickle.load(file)
decks
# Out:
# {'test': ['Firesong and Sunspeaker',
#   'Xun Yu, Wei Advisor',
#   'Gimli, Counter of Kills',
#   "Frodo, Sauron's Bane",
#   'Ziatora, the Incinerator',
#   'Bill the Pony',
#   'Elrond, Master of Healing',
#   'Florian, Voldaren Scion',
#   'Mayael the Anima',
#   'Laelia, the Blade Reforged',
#   'Djeru and Hazoret',
#   'Jadzi, Oracle of Arcavios',
#   'Gretchen Titchwillow',
#   'Dr. Madison Li',
#   'Galadriel of Lothlórien',
#   'Kalemne, Disciple of Iroas',
#   'Garza Zol, Plague Queen',
#   'Merry, Esquire of Rohan',
#   'Grandmother Sengir',
#   'Tobias Andrion',
#   'Lita, Mechanical Engineer',
#   "Saheeli, the Sun's Brilliance",
#   'Gnostro, Voice of the Crags',
#   'Junji, the Midnight Sky',
#   'Emperor Mihail II',
#   'Nefarox, Overlord of Grixis',
#   'Djeru, With Eyes Open',
#   'Teferi, Temporal Archmage',
#   'The Celestial Toymaker',
#   'Maralen of the Mornsong',
#   'Orvar, the All-Form',
#   'Deathleaper, Terror Weapon',
#   'Elenda and Azor',
# ...
