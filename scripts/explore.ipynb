# %%
import json
import os
import math
import pandas as pd
import pickle
import re
import requests
from unidecode import unidecode
from scrape_cardlists import *

# %% [markdown]
# ## load commanders

# %%
# load data
with open(os.path.abspath(os.path.join('..','data','cards.pkl')), 'rb') as f:
    cards = pickle.load(f)
with open(os.path.abspath(os.path.join('..','data','commanders.pkl')), 'rb') as f:
    commanders = pickle.load(f)
with open(os.path.abspath(os.path.join('..','data','edhreclists.pkl')), 'rb') as f:
    comm_lists = pickle.load(f)

# %% [markdown]
# ## data exploration

# %%
cards.columns
# Out:
# Index(['artist', 'artistIds', 'asciiName', 'attractionLights', 'availability',
#        'boosterTypes', 'borderColor', 'cardParts', 'colorIdentity',
#        'colorIndicator', 'colors', 'defense', 'duelDeck', 'edhrecRank',
#        'edhrecSaltiness', 'faceConvertedManaCost', 'faceFlavorName',
#        'faceManaValue', 'faceName', 'finishes', 'flavorName', 'flavorText',
#        'frameEffects', 'frameVersion', 'hand', 'hasAlternativeDeckLimit',
#        'hasContentWarning', 'hasFoil', 'hasNonFoil', 'isAlternative',
#        'isFullArt', 'isFunny', 'isOnlineOnly', 'isOversized', 'isPromo',
#        'isRebalanced', 'isReprint', 'isReserved', 'isStarter',
#        'isStorySpotlight', 'isTextless', 'isTimeshifted', 'keywords',
#        'language', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'manaValue', 'name', 'number', 'originalPrintings',
#        'originalReleaseDate', 'originalText', 'originalType', 'otherFaceIds',
#        'power', 'printings', 'promoTypes', 'rarity', 'rebalancedPrintings',
#        'relatedCards', 'securityStamp', 'setCode', 'side', 'signature',
#        'sourceProducts', 'subsets', 'subtypes', 'supertypes', 'text',
#        'toughness', 'type', 'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
fail = []
for card in commanders['valid']:
    if card in cards['name']:
        continue
    fail.append(card)
len(fail)
# Out:
# 200

# %%
commanders['valid'][0]
# Out:
# 'Stangg, Echo Warrior'

# %%
stangg = cards[cards['name'].str.contains('Stangg, Echo Warrior')]
for col in stangg.columns:
    print(f'{col}: {len(stangg[col].unique())} unique values: {stangg[col].unique()}')
# Out:
# artist: 1 unique values: ['Randy Vargas']
# artistIds: 1 unique values: ['d20672ca-0555-4238-a984-fd171d36b247']
# asciiName: 1 unique values: [nan]
# attractionLights: 1 unique values: [nan]
# availability: 2 unique values: ['mtgo, paper' 'paper']
# boosterTypes: 1 unique values: [nan]
# borderColor: 1 unique values: ['black']
# cardParts: 1 unique values: [nan]
# colorIdentity: 1 unique values: ['G, R']
# colorIndicator: 1 unique values: [nan]
# colors: 1 unique values: ['G, R']
# defense: 1 unique values: [nan]
# duelDeck: 1 unique values: [nan]
# edhrecRank: 1 unique values: [10905.]
# edhrecSaltiness: 1 unique values: [nan]
# faceConvertedManaCost: 1 unique values: [nan]
# faceFlavorName: 1 unique values: [nan]
# faceManaValue: 1 unique values: [nan]
# faceName: 1 unique values: [nan]
# finishes: 2 unique values: ['nonfoil, foil' 'etched']
# flavorName: 1 unique values: [nan]
# flavorText: 1 unique values: [nan]
# frameEffects: 2 unique values: ['legendary' 'legendary, inverted']
# frameVersion: 1 unique values: [2015]
# hand: 1 unique values: [nan]
# hasAlternativeDeckLimit: 1 unique values: [nan]
# hasContentWarning: 1 unique values: [nan]
# hasFoil: 2 unique values: [ True False]
# hasNonFoil: 2 unique values: [ True False]
# isAlternative: 1 unique values: [nan]
# isFullArt: 1 unique values: [nan]
# isFunny: 1 unique values: [nan]
# isOnlineOnly: 1 unique values: [nan]
# isOversized: 1 unique values: [nan]
# isPromo: 1 unique values: [nan]
# isRebalanced: 1 unique values: [nan]
# isReprint: 1 unique values: [nan]
# isReserved: 1 unique values: [nan]
# isStarter: 1 unique values: [True]
# isStorySpotlight: 1 unique values: [nan]
# isTextless: 1 unique values: [nan]
# isTimeshifted: 1 unique values: [nan]
# keywords: 1 unique values: [nan]
# language: 1 unique values: ['English']
# layout: 1 unique values: ['normal']
# leadershipSkills: 1 unique values: ['{"brawl": false, "commander": true, "oathbreaker": false}']
# life: 1 unique values: [nan]
# loyalty: 1 unique values: [nan]
# manaCost: 1 unique values: ['{2}{R}{G}']
# manaValue: 1 unique values: [4.]
# name: 1 unique values: ['Stangg, Echo Warrior']
# number: 2 unique values: ['42' '64']
# originalPrintings: 1 unique values: [nan]
# originalReleaseDate: 1 unique values: [nan]
# originalText: 2 unique values: ["Whenever Stangg, Echo Warrior attacks, create Stangg Twin, a legendary 3/4 red and green Human Warrior creature token. It enters the battlefield tapped and attacking. For each Aura and Equipment attached to Stangg, create a token that's a copy of it attached to Stangg Twin. Sacrifice all tokens created this way at the beginning of the next end step."
#  nan]
# originalType: 2 unique values: ['Legendary Creature — Human Warrior' nan]
# otherFaceIds: 1 unique values: [nan]
# power: 1 unique values: ['3']
# printings: 1 unique values: ['DMC']
# promoTypes: 2 unique values: [nan 'boosterfun']
# rarity: 1 unique values: ['rare']
# rebalancedPrintings: 1 unique values: [nan]
# relatedCards: 1 unique values: [nan]
# securityStamp: 1 unique values: ['oval']
# setCode: 1 unique values: ['DMC']
# side: 1 unique values: [nan]
# signature: 1 unique values: [nan]
# sourceProducts: 2 unique values: ['{"foil": ["94cea37a-60d8-582e-94b7-375362650017"], "nonfoil": ["d1dd4fe5-896a-5347-835e-a62367233c66"]}'
#  '{"etched": ["d1dd4fe5-896a-5347-835e-a62367233c66"]}']
# subsets: 1 unique values: [nan]
# subtypes: 1 unique values: ['Human, Warrior']
# supertypes: 1 unique values: ['Legendary']
# text: 1 unique values: ["Whenever Stangg, Echo Warrior attacks, create Stangg Twin, a legendary 3/4 red and green Human Warrior creature token. It enters the battlefield tapped and attacking. For each Aura and Equipment attached to Stangg, create a token that's a copy of it attached to Stangg Twin. Sacrifice all tokens created this way at the beginning of the next end step."]
# toughness: 1 unique values: ['4']
# type: 1 unique values: ['Legendary Creature — Human Warrior']
# types: 1 unique values: ['Creature']
# uuid: 2 unique values: ['a33c47a9-dd5e-5406-b188-a697d75d8451'
#  'a13cd221-9cbf-56a9-a26b-e313b6fdd422']
# variations: 2 unique values: ['a13cd221-9cbf-56a9-a26b-e313b6fdd422'
#  'a33c47a9-dd5e-5406-b188-a697d75d8451']
# watermark: 1 unique values: [nan]

# %%
cards.shape
# Out:
# (87566, 78)

# %%
unique = cards.drop_duplicates(subset=['name', 'colorIdentity', 'text'])
with open(os.path.abspath(os.path.join('..','data','cards_unique.pkl')), 'wb') as f:
    pickle.dump(unique, f)

# %%
duptext = []
dupcolor = []
for name, group in cards.groupby('name'):
    if len(group['colorIdentity'].unique()) > 1:
        dupcolor.append(name)
    if len(group['text'].unique()) > 1:
        duptext.append(name)

# %%
len(dupcolor), len(duptext)
# Out:
# (1, 670)

# %%
duptext
# Out:
# ['A-Alrund, God of the Cosmos // A-Hakka, Whispering Raven',
#  'A-Binding Geist // A-Spectral Binding',
#  "A-Blessed Hippogriff // A-Tyr's Blessing",
#  'A-Brine Comber // A-Brinebound Gift',
#  'A-Devoted Grafkeeper // A-Departed Soulkeeper',
#  "A-Dorothea, Vengeful Victim // A-Dorothea's Retribution",
#  'A-Emerald Dragon // A-Dissonant Wave',
#  'A-Gutter Skulker // A-Gutter Shortcut',
#  "A-Lantern Bearer // A-Lanterns' Lift",
#  'A-Mischievous Catgeist // A-Catlike Curiosity',
#  'A-Rowan, Scholar of Sparks // A-Will, Scholar of Frost',
#  'A-Young Blue Dragon // A-Sand Augury',
#  'A-Young Red Dragon // A-Bathe in Gold',
#  'Aberrant Researcher // Perfected Form',
#  'Accident-Prone Apprentice // Amphibian Accident',
#  'Accursed Witch // Infectious Curse',
#  'Aclazotz, Deepest Betrayal // Temple of the Dead',
#  'Aetherblade Agent // Gitaxian Mindstinger',
#  'Afflicted Deserter // Werewolf Ransacker',
#  "Agadeem's Awakening // Agadeem, the Undercrypt",
#  'Akki Lavarunner // Tok-Tok, Volcano Born',
#  'Akoum Warrior // Akoum Teeth',
#  'Alive // Well',
#  'Alluring Suitor // Deadly Dancer',
#  'Alrund, God of the Cosmos // Hakka, Whispering Raven',
#  'Altar of Bhaal // Bone Offering',
#  'Altar of the Wretched // Wretched Bonemass',
#  'Ambitious Farmhand // Seasoned Cathar',
#  'Amethyst Dragon // Explosive Crystal',
#  'Animating Faerie // Bring to Life',
#  'Appeal // Authority',
#  'Aquatic Alchemist // Bubble Up',
#  'Arcee, Sharpshooter // Arcee, Acrobatic Coupe',
#  'Archangel Avacyn // Avacyn, the Purifier',
#  'Ardenvale Tactician // Dizzying Swoop',
#  "Arguel's Blood Fast // Temple of Aclazotz",
#  'Arlinn Kord // Arlinn, Embraced by the Moon',
#  "Arlinn, the Pack's Hope // Arlinn, the Moon's Fury",
#  'Armed // Dangerous',
#  'Assault // Battery',
#  'Assure // Assemble',
#  'Augmenter Pugilist // Echoing Equation',
#  'Autumnal Gloom // Ancient of the Equinox',
#  'Avabruck Caretaker // Hollowhenge Huntmaster',
#  'Avacynian Missionaries // Lunarch Inquisitors',
#  'Ayara, Widow of the Realm // Ayara, Furnace Queen',
#  "Azor's Gateway // Sanctum of the Sun",
#  "Azusa's Many Journeys // Likeness of the Seeker",
#  'B.F.M. (Big Furry Monster)',
#  'Baithook Angler // Hook-Haunt Drifter',
#  'Bala Ged Recovery // Bala Ged Sanctuary',
#  'Ballista Watcher // Ballista Wielder',
#  'Baneblade Scoundrel // Baneclaw Marauder',
#  'Barkchannel Pathway // Tidechannel Pathway',
#  'Beanstalk Giant // Fertile Footsteps',
#  'Beanstalk Wurm // Plant Beans',
#  'Beck // Call',
#  'Bedeck // Bedazzle',
#  'Befriending the Moths // Imperial Moth',
#  'Behold the Unspeakable // Vision of the Unspeakable',
#  'Bellowing Bruiser // Beat a Path',
#  'Beloved Beggar // Generous Soul',
#  'Beluna Grandsquall // Seek Thrills',
#  "Beluna's Gatekeeper // Entry Denied",
#  'Bereaved Survivor // Dauntless Avenger',
#  'Besotted Knight // Betroth the Beast',
#  'Beyeen Veil // Beyeen Coast',
#  'Bind // Liberate',
#  'Binding Geist // Spectral Binding',
#  'Biolume Egg // Biolume Serpent',
#  'Bird Admirer // Wing Shredder',
#  'Birgi, God of Storytelling // Harnfel, Horn of Bounty',
#  'Blackbloom Rogue // Blackbloom Bog',
#  'Blaster, Combat DJ // Blaster, Morale Booster',
#  "Blessed Hippogriff // Tyr's Blessing",
#  'Blex, Vexing Pest // Search for Blex',
#  'Blightreaper Thallid // Blightsower Thallid',
#  'Blightstep Pathway // Searstep Pathway',
#  'Blitzwing, Cruel Tormentor // Blitzwing, Adaptive Assailant',
#  'Bloodline Keeper // Lord of Lineage',
#  'Bloodsworn Squire // Bloodsworn Knight',
#  'Bonded Herdbeast // Plated Kilnbeast',
#  'Bonecrusher Giant // Stomp',
#  'Boom // Bust',
#  'Boseiju Reaches Skyward // Branch of Boseiju',
#  'Bound // Determined',
#  'Braided Net // Braided Quipu',
#  'Bramble Familiar // Fetch Quest',
#  'Branchloft Pathway // Boulderloft Pathway',
#  "Brass's Tunnel-Grinder // Tecutlan, the Searing Rift",
#  'Brazen Borrower // Petty Theft',
#  'Breaking // Entering',
#  'Breakneck Rider // Neck Breaker',
#  'Brightclimb Pathway // Grimclimb Pathway',
#  'Brine Comber // Brinebound Gift',
#  'Brutal Cathar // Moonrage Brute',
#  'Budoka Gardener // Dokai, Weaver of Life',
#  'Budoka Pupil // Ichiga, Who Topples Oaks',
#  'Burly Breaker // Dire-Strain Demolisher',
#  'Bushi Tenderfoot // Kenzo the Hardhearted',
#  'Callous Sell-Sword // Burn Together',
#  'Callow Jushi // Jaraku the Interloper',
#  'Captive Weird // Compleated Conjurer',
#  'Carnival // Carnage',
#  'Catapult Fodder // Catapult Captain',
#  'Catch // Release',
#  'Chalice of Life // Chalice of Death',
#  'Champions of Archery // Join the Group',
#  'Chandra, Fire of Kaladesh // Chandra, Roaring Flame',
#  'Chaplain of Alms // Chapel Shieldgeist',
#  'Cheeky House-Mouse // Squeak By',
#  'Child of the Pack // Savage Packmate',
#  "Chosen of Markov // Markov's Servant",
#  'Civilized Scholar // Homicidal Brute',
#  'Claim // Fame',
#  'Clay-Fired Bricks // Cosmium Kiln',
#  'Clearwater Pathway // Murkwater Pathway',
#  'Cloistered Youth // Unholy Fiend',
#  'Collectigull // Only the Best',
#  'Collision // Colossus',
#  'Colossal Badger // Dig Deep',
#  'Commit // Memory',
#  'Concealing Curtains // Revealing Eye',
#  'Conceited Witch // Price of Beauty',
#  'Conduit of Storms // Conduit of Emrakul',
#  'Connive // Concoct',
#  "Conqueror's Galleon // Conqueror's Foothold",
#  'Consecrate // Consume',
#  'Consign // Oblivion',
#  'Convicted Killer // Branded Howler',
#  'Cosima, God of the Voyage // The Omenkeel',
#  'Covert Cutpurse // Covetous Geist',
#  'Covetous Castaway // Ghostly Castigator',
#  'Coward // Killer',
#  'Cragcrown Pathway // Timbercrown Pathway',
#  'Crime // Punishment',
#  "Cruel Somnophage // Can't Wake Up",
#  'Cryptolith Fragment // Aurora of Emrakul',
#  'Crystal Dragon // Rob the Hoard',
#  'Cunning Bandit // Azamuki, Treachery Incarnate',
#  'Curious Homunculus // Voracious Reader',
#  'Curious Pair // Treats to Share',
#  'Curse of Leeches // Leeching Lurker',
#  'Curse of the Fire Penguin // Curse of the Fire Penguin Creature',
#  'Cut // Ribbons',
#  'Cyclonus, the Saboteur // Cyclonus, Cybertronian Fighter',
#  'Daring Sleuth // Bearer of Overwhelming Truths',
#  'Darkbore Pathway // Slitherbore Pathway',
#  'Daybreak Ranger // Nightfall Predator',
#  'Dead // Gone',
#  'Deathbonnet Sprout // Deathbonnet Hulk',
#  'Decadent Dragon // Expensive Taste',
#  'Decorated Knight // Present Arms',
#  'Delver of Secrets // Insectile Aberration',
#  'Dennick, Pious Apprentice // Dennick, Pious Apparition',
#  'Depose // Deploy',
#  'Desperate Farmer // Depraved Harvester',
#  'Destined // Lead',
#  'Devoted Grafkeeper // Departed Soulkeeper',
#  'Devouring Sugarmaw // Have for Dinner',
#  'Dire Flail // Dire Blunderbuss',
#  'Discovery // Dispersal',
#  'Distracting Geist // Clever Distraction',
#  'Docent of Perfection // Final Iteration',
#  "Doric, Nature's Warden // Doric, Owlbear Avenger",
#  'Dormant Grove // Gnarled Grovestrider',
#  "Dorothea, Vengeful Victim // Dorothea's Retribution",
#  'Down // Dirty',
#  'Dowsing Dagger // Lost Vale',
#  'Dowsing Device // Geode Grotto',
#  'Dread Linnorm // Scale Deflection',
#  'Driven // Despair',
#  'Drogskol Infantry // Drogskol Armaments',
#  'Dusk // Dawn',
#  'Duskwatch Recruiter // Krallenhorde Howler',
#  'Ecstatic Awakener // Awoken Demon',
#  "Edgar, Charmed Groom // Edgar Markov's Coffin",
#  'Egon, God of Death // Throne of Death',
#  'Elbrus, the Binding Blade // Withengar Unbound',
#  'Elesh Norn // The Argent Etchings',
#  "Elusive Otter // Grove's Bounty",
#  'Elusive Tormentor // Insidious Mist',
#  'Embereth Shieldbreaker // Battle Display',
#  'Emerald Dragon // Dissonant Wave',
#  "Emeria's Call // Emeria, Shattered Skyclave",
#  'Enduring Angel // Angelic Enforcer',
#  'Era of Enlightenment // Hand of Enlightenment',
#  "Erayo, Soratami Ascendant // Erayo's Essence",
#  'Esika, God of the Tree // The Prismatic Bridge',
#  'Etali, Primal Conqueror // Etali, Primal Sickness',
#  'Ettercap // Web Shot',
#  'Everythingamajig',
#  'Expansion // Explosion',
#  'Extricator of Sin // Extricator of Flesh',
#  'Extus, Oriq Overlord // Awaken the Blood Avatar',
#  'Eye of Ojer Taq // Apex Observatory',
#  'Fable of the Mirror-Breaker // Reflection of Kiki-Jiki',
#  'Fae of Wishes // Granted',
#  'Faerie Guidemother // Gift of the Fae',
#  'Failure // Comply',
#  "Faithbound Judge // Sinner's Judgment",
#  'Faithful Squire // Kaiso, Memory of Loyalty',
#  'Fang Dragon // Forktail Sweep',
#  'Fangblade Brigand // Fangblade Eviscerator',
#  'Far // Away',
#  'Farm // Market',
#  'Fast // Furious',
#  'Fearful Villager // Fearsome Werewolf',
#  'Fell Horseman // Deathly Ride',
#  'Ferocious Werefox // Guard Change',
#  'Find // Finality',
#  'Fire // Ice',
#  'Flame Channeler // Embodiment of Flame',
#  'Flamescroll Celebrant // Revel in Silence',
#  'Flamewar, Brash Veteran // Flamewar, Streetwise Operative',
#  'Flaxen Intruder // Welcome Home',
#  'Flesh // Blood',
#  'Flower // Flourish',
#  'Foreboding Statue // Forsaken Thresher',
#  'Foulmire Knight // Profane Insight',
#  'Frolicking Familiar // Blow Off Steam',
#  'Galedrifter // Waildrifter',
#  'Gallifrey Falls // No More',
#  'Galvanic Giant // Storm Reading',
#  'Garbage Elemental',
#  "Garenbrig Carver // Shield's Might",
#  'Garruk Relentless // Garruk, the Veil-Cursed',
#  'Gatstaf Arsonists // Gatstaf Ravagers',
#  'Gatstaf Shepherd // Gatstaf Howler',
#  'Geier Reach Bandit // Vildin-Pack Alpha',
#  'Ghost Lantern // Bind Spirit',
#  'Giant Killer // Chop Down',
#  'Gingerbread Hunter // Puny Snack',
#  'Give // Take',
#  'Glasspool Mimic // Glasspool Shore',
#  'Gnottvold Hermit // Chrome Host Hulk',
#  "Goldbug, Humanity's Ally // Goldbug, Scrappy Scout",
#  'Golden Guardian // Gold-Forge Garrison',
#  "Grabby Giant // That's Mine",
#  "Grasping Shadows // Shadows' Lair",
#  'Graveyard Trespasser // Graveyard Glutton',
#  'Gray Slaad // Entropic Decay',
#  'Grimlock, Dinobot Leader // Grimlock, Ferocious King',
#  'Grind // Dust',
#  'Grizzled Angler // Grisly Anglerfish',
#  'Grizzled Outcasts // Krallenhorde Wantons',
#  'Growing Rites of Itlimoc // Itlimoc, Cradle of the Sun',
#  'Guardian Naga // Banishing Coils',
#  'Gumdrop Poisoner // Tempt with Treats',
#  'Gutter Skulker // Gutter Shortcut',
#  "Hadana's Climb // Winged Temple of Orazca",
#  'Hagra Mauling // Hagra Broodpit',
#  'Halvar, God of Battle // Sword of the Realms',
#  'Hanweir Militia Captain // Westvale Cult Leader',
#  'Hanweir Watchkeep // Bane of Hanweir',
#  'Harried Artisan // Phyrexian Skyflayer',
#  'Harvest Hand // Scrounged Scythe',
#  'Harvesttide Infiltrator // Harvesttide Assailant',
#  'Havengul Laboratory // Havengul Mystery',
#  'Heartflame Duelist // Heartflame Slash',
#  'Hearth Elemental // Stoke Genius',
#  'Heaven // Earth',
#  'Heir of Falkenrath // Heir to the Night',
#  'Heirloom Mirror // Inherited Fiend',
#  'Heliod, the Radiant Dawn // Heliod, the Warped Eclipse',
#  'Hengegate Pathway // Mistgate Pathway',
#  'Henrika Domnathi // Henrika, Infernal Seer',
#  'Herbology Instructor // Malady Invoker',
#  'Hermit of the Natterknolls // Lone Wolf of the Natterknolls',
#  'Hezrou // Demonic Stench',
#  'Hide // Seek',
#  'Hidetsugu Consumes All // Vessel of the All-Consuming',
#  'Hinterland Hermit // Hinterland Scourge',
#  'Hinterland Logger // Timber Shredder',
#  'Hired Muscle // Scarmaker',
#  'Hit // Run',
#  'Hollow Scavenger // Bakery Raid',
#  "Homura, Human Ascendant // Homura's Essence",
#  'Hookhand Mariner // Riphook Raider',
#  "Horn of Valhalla // Ysgard's Call",
#  'Horned Loch-Whale // Lagoon Breach',
#  'Hostile Hostel // Creeping Inn',
#  'Hound Tamer // Untamed Pup',
#  'Howlpack Piper // Wildsong Howler',
#  'Huatli, Poet of Unity // Roar of the Fifth People',
#  'Huntmaster of the Fells // Ravager of the Fells',
#  'Hypnotic Sprite // Mesmeric Glare',
#  "Idol of the Deep King // Sovereign's Macuahuitl",
#  'Ill-Tempered Loner // Howlpack Avenger',
#  'Illithid Harvester // Plant Tadpoles',
#  'Illusion // Reality',
#  "Imodane's Recruiter // Train Troops",
#  'Incubation // Incongruity',
#  'Indulge // Excess',
#  'Ineffable Blessing',
#  'Infestation Expert // Infested Werewolf',
#  'Initiate of Blood // Goka the Unjust',
#  'Innocent Traveler // Malicious Invader',
#  'Instigator Gang // Wildblood Pack',
#  'Insult // Injury',
#  'Integrity // Intervention',
#  'Intrepid Trufflesnout // Go Hog Wild',
#  'Invasion of Alara // Awaken the Maelstrom',
#  'Invasion of Amonkhet // Lazotep Convert',
#  'Invasion of Arcavios // Invocation of the Founders',
#  'Invasion of Azgol // Ashen Reaper',
#  'Invasion of Belenon // Belenon War Anthem',
#  'Invasion of Dominaria // Serra Faithkeeper',
#  'Invasion of Eldraine // Prickle Faeries',
#  'Invasion of Ergamon // Truga Cliffcharger',
#  'Invasion of Fiora // Marchesa, Resolute Monarch',
#  'Invasion of Gobakhan // Lightshield Array',
#  'Invasion of Ikoria // Zilortha, Apex of Ikoria',
#  'Invasion of Innistrad // Deluge of the Dead',
#  'Invasion of Ixalan // Belligerent Regisaur',
#  'Invasion of Kaladesh // Aetherwing, Golden-Scale Flagship',
#  'Invasion of Kaldheim // Pyre of the World Tree',
#  'Invasion of Kamigawa // Rooftop Saboteurs',
#  'Invasion of Karsus // Refraction Elemental',
#  "Invasion of Kylem // Valor's Reach Tag Team",
#  'Invasion of Lorwyn // Winnowing Forces',
#  'Invasion of Mercadia // Kyren Flamewright',
#  'Invasion of Moag // Bloomwielder Dryads',
#  'Invasion of Muraganda // Primordial Plasm',
#  'Invasion of New Capenna // Holy Frazzle-Cannon',
#  'Invasion of New Phyrexia // Teferi Akosa of Zhalfir',
#  'Invasion of Pyrulea // Gargantuan Slabhorn',
#  'Invasion of Ravnica // Guildpact Paragon',
#  'Invasion of Regatha // Disciples of the Inferno',
#  'Invasion of Segovia // Caetus, Sea Tyrant of Segovia',
#  'Invasion of Shandalar // Leyline Surge',
#  'Invasion of Tarkir // Defiant Thundermaw',
#  'Invasion of Theros // Ephara, Ever-Sheltering',
#  'Invasion of Tolvada // The Broken Sky',
#  'Invasion of Ulgrotha // Grandmother Ravi Sengir',
#  'Invasion of Vryn // Overloaded Mage-Ring',
#  'Invasion of Xerex // Vertex Paladin',
#  'Invasion of Zendikar // Awakened Skyclave',
#  'Inventive Iteration // Living Breakthrough',
#  'Invert // Invent',
#  'Inverted Iceberg // Iceberg Titan',
#  "Jace, Vryn's Prodigy // Jace, Telepath Unbound",
#  "Jacob Hauken, Inspector // Hauken's Insight",
#  'Jade Seedstones // Jadeheart Attendant',
#  'Jadzi, Oracle of Arcavios // Journey to the Oracle',
#  'Jerren, Corrupted Bishop // Ormendahl, the Corrupter',
#  'Jetfire, Ingenious Scientist // Jetfire, Air Guardian',
#  'Jin-Gitaxias // The Great Synthesis',
#  'Jorn, God of Winter // Kaldring, the Rimestaff',
#  'Journey to Eternity // Atzal, Cave of Eternity',
#  'Jugan Defends the Temple // Remnant of the Rising Star',
#  'Jushi Apprentice // Tomoya the Revealer',
#  'Jwari Disruption // Jwari Ruins',
#  'Kabira Takedown // Kabira Plateau',
#  'Karvanista, Loyal Lupari // Lupari Shield',
#  "Kaslem's Stonetree // Kaslem's Strider",
#  "Katilda, Dawnhart Martyr // Katilda's Rising Dawn",
#  'Kazandu Mammoth // Kazandu Valley',
#  "Kazuul's Fury // Kazuul's Cliffs",
#  'Kellan, Daring Traveler // Journey On',
#  'Kellan, the Fae-Blooded // Birthright Boon',
#  'Kessig Forgemaster // Flameheart Werewolf',
#  'Kessig Naturalist // Lord of the Ulvenwald',
#  'Kessig Prowler // Sinuous Predator',
#  'Khalni Ambush // Khalni Territory',
#  'Khenra Spellspear // Gitaxian Spellstalker',
#  'Kianne, Dean of Substance // Imbraham, Dean of Theory',
#  "Kindly Ancestor // Ancestor's Embrace",
#  'Kindly Stranger // Demon-Possessed Witch',
#  'Kitsune Mystic // Autumn-Tail, Kitsune Sage',
#  'Knight of the Kitchen Sink',
#  'Kolvori, God of Kinship // The Ringhart Crest',
#  'Kruin Outlaw // Terror of Kruin Pass',
#  'Kumano Faces Kakkazan // Etching of Kumano',
#  "Kuon, Ogre Ascendant // Kuon's Essence",
#  'Kytheon, Hero of Akros // Gideon, Battle-Forged',
#  'Lambholt Elder // Silverpelt Werewolf',
#  'Lambholt Pacifist // Lambholt Butcher',
#  'Lambholt Raconteur // Lambholt Ravager',
#  "Lantern Bearer // Lanterns' Lift",
#  'Leave // Chance',
#  "Legion's Landing // Adanto, the First Fort",
#  'Life // Death',
#  'Life of Toshiro Umezawa // Memory of Toshiro',
#  'Liliana, Heretical Healer // Liliana, Defiant Necromancer',
#  'Lodestone Needle // Guidestone Compass',
#  'Lone Rider // It That Rides as One',
#  'Lonesome Unicorn // Rider in Need',
#  "Lovestruck Beast // Heart's Desire",
#  'Loyal Cathar // Unhallowed Cathar',
#  "Ludevic's Test Subject // Ludevic's Abomination",
#  "Ludevic, Necrogenius // Olag, Ludevic's Hubris",
#  'Lunarch Veteran // Luminous Phantom',
#  'Makindi Stampede // Makindi Mesas',
#  'Malakir Rebirth // Malakir Mire',
#  'Malevolent Hermit // Benevolent Geist',
#  "Master's Guide-Mural // Master's Manufactory",
#  'Matzalantli, the Great Door // The Core',
#  'Mayor of Avabruck // Howlpack Alpha',
#  'Megatron, Tyrant // Megatron, Destructive Force',
#  'Merchant of the Vale // Haggle',
#  'Merfolk Secretkeeper // Venture Deeper',
#  "Michiko's Reign of Truth // Portrait of Michiko",
#  'Mila, Crafty Companion // Lukka, Wayward Bonder',
#  'Minecart Daredevil // Ride the Rails',
#  'Mirrorhall Mimic // Ghastly Mimicry',
#  'Mischievous Catgeist // Catlike Curiosity',
#  "Mondronen Shaman // Tovolar's Magehunter",
#  'Monster Manual // Zoological Study',
#  'Moonshae Pixie // Pixie Dust',
#  'Mosswood Dreadknight // Dread Whispers',
#  'Mourning Patrol // Morning Apparition',
#  'Mouth // Feed',
#  'Murderous Rider // Swift End',
#  'Mysterious Tome // Chilling Chronicle',
#  'Mystic Skull // Mystic Monstrosity',
#  'Naughty // Nice',
#  'Needleverge Pathway // Pillarverge Pathway',
#  'Neglected Heirloom // Ashmouth Blade',
#  'Never // Return',
#  'Nezumi Freewheeler // Hideous Fleshwheeler',
#  'Nezumi Graverobber // Nighteyes the Desecrator',
#  'Nezumi Shortfang // Stabwhisker the Odious',
#  'Nicol Bolas, the Ravager // Nicol Bolas, the Arisen',
#  'Night // Day',
#  'Nightmare Moon // Princess Luna',
#  'Nissa, Vastwood Seer // Nissa, Sage Animist',
#  'Oakhame Ranger // Bring Back',
#  'Oakshade Stalker // Moonlit Ambusher',
#  "Obyra's Attendants // Desperate Parry",
#  'Odds // Ends',
#  'Ojer Axonil, Deepest Might // Temple of Power',
#  'Ojer Kaslem, Deepest Growth // Temple of Cultivation',
#  'Ojer Pakpatiq, Deepest Epoch // Temple of Cyclical Time',
#  'Ojer Taq, Deepest Foundation // Temple of Civilization',
#  'Okiba Reckoner Raid // Nezumi Road Captain',
#  'Omniclown Colossus // Pie-roclasm',
#  'Ondu Inversion // Ondu Skyruins',
#  'Onward // Victory',
#  'Optimus Prime, Hero // Optimus Prime, Autobot Leader',
#  'Order // Chaos',
#  'Order of Midnight // Alter Fate',
#  'Order of the Mirror // Order of the Alabaster Host',
#  'Ore-Rich Stalactite // Cosmium Catalyst',
#  'Orochi Eggwatcher // Shidako, Broodmistress',
#  'Oteclan Landmark // Oteclan Levitator',
#  'Outland Liberator // Frenzied Trapbreaker',
#  'Overwhelmed Archivist // Archive Haunt',
#  'Pain // Suffering',
#  "Paleontologist's Pick-Axe // Dinosaur Headdress",
#  'Panicked Bystander // Cackling Culprit',
#  'Path of Mettle // Metzali, Tower of Triumph',
#  'Pegasus Guardian // Rescue the Foal',
#  'Pelakka Predation // Pelakka Caverns',
#  'Pestilent Cauldron // Restorative Burst',
#  'Picklock Prankster // Free the Fae',
#  'Picnic Ruiner // Stolen Goodies',
#  'Pious Evangel // Wayward Disciple',
#  'Plargg, Dean of Chaos // Augusta, Dean of Order',
#  'Pollen-Shield Hare // Hare Raising',
#  'Polukranos Reborn // Polukranos, Engine of Ruin',
#  'Poppet Stitcher // Poppet Factory',
#  'Porcine Portent // Lend a Ham',
#  'Prepare // Fight',
#  'Primal Amulet // Primal Wellspring',
#  'Profane Procession // Tomb of the Dusk Rose',
#  'Profit // Loss',
#  'Promise of Aclazotz // Foul Rebirth',
#  'Protect // Serve',
#  'Prowl, Stoic Strategist // Prowl, Pursuit Vehicle',
#  'Pure // Simple',
#  'Pyretic Prankster // Glistening Goremonger',
#  'Queen of Ice // Rage of Winter',
#  'Questing Druid // Seek the Beast',
#  'Radiant Grace // Radiant Restraints',
#  'Ragged Recluse // Odious Witch',
#  'Rags // Riches',
#  'Rahilda, Wanted Cutthroat // Rahilda, Feral Outlaw',
#  'Ratcatcher Trainee // Pest Problem',
#  'Ratchet, Field Medic // Ratchet, Rescue Racer',
#  'Ravenous Demon // Archdemon of Greed',
#  'Ready // Willing',
#  'Realm-Cloaked Giant // Cast Off',
#  'Reaper of Night // Harvest Fear',
#  'Reason // Believe',
#  'Reckless Stormseeker // Storm-Charged Slasher',
#  'Reckless Waif // Merciless Predator',
#  'Reduce // Rubble',
#  'Refuse // Cooperate',
#  "Reidane, God of the Worthy // Valkmira, Protector's Shield",
#  'Repudiate // Replicate',
#  'Research // Development',
#  'Response // Resurgence',
#  'Restless Bloodseeker // Bloodsoaked Reveler',
#  'Revival // Revenge',
#  'Rimrock Knight // Boulder Rush',
#  'Rise // Fall',
#  'Riverglide Pathway // Lavaglide Pathway',
#  'Road // Ruin',
#  'Rona, Herald of Invasion // Rona, Tolarian Obliterator',
#  'Rosethorn Acolyte // Seasonal Ritual',
#  'Rough // Tumble',
#  'Rowan, Scholar of Sparks // Will, Scholar of Frost',
#  "Rune-Tail, Kitsune Ascendant // Rune-Tail's Essence",
#  'Runo Stromkirk // Krothuss, Lord of the Deep',
#  'Sage of Ancient Lore // Werewolf of Ancient Hunger',
#  "Saheeli's Lattice // Mastercraft Raptor",
#  'Said // Done',
#  'Sapphire Dragon // Psionic Pulse',
#  "Sasaya, Orochi Ascendant // Sasaya's Essence",
#  'Scalding Viper // Steam Clean',
#  'Scavenger Hunt',
#  'Scorned Villager // Moonscarred Werewolf',
#  'Screeching Bat // Stalking Vampire',
#  'Sea Gate Restoration // Sea Gate, Reborn',
#  'Sea Hag // Aquatic Ingress',
#  'Search for Azcanta // Azcanta, the Sunken Ruin',
#  'Sejiri Shelter // Sejiri Glacier',
#  'Selfless Glyphweaver // Deadly Vanity',
#  'Seraph of New Capenna // Seraph of New Phyrexia',
#  'Shady Traveler // Stalking Predator',
#  'Shaile, Dean of Radiance // Embrose, Dean of Shadow',
#  'Shatterskull Smashing // Shatterskull, the Hammer Pass',
#  'Sheoldred // The True Scriptures',
#  'Shepherd of the Flock // Usher to Safety',
#  'Shrill Howler // Howling Chorus',
#  'Shrouded Shepherd // Cleave Shadows',
#  'Silundi Vision // Silundi Isle',
#  'Silverflame Squire // On Alert',
#  'Skin Invasion // Skin Shedder',
#  'Skyclave Aerialist // Skyclave Invader',
#  'Skyclave Cleric // Skyclave Basilica',
#  'Slicer, Hired Muscle // Slicer, High-Speed Antagonist',
#  'Sly Spy',
#  'Smelt // Herd // Saw',
#  'Smitten Swordmaster // Curry Favor',
#  'Smoldering Egg // Ashmouth Dragon',
#  'Smoldering Werewolf // Erupting Dreadwolf',
#  'Solitary Hunter // One of the Pack',
#  'Song-Mad Treachery // Song-Mad Ruins',
#  'Soul Seizer // Ghastly Haunting',
#  'Soulcipher Board // Cipherbound Spirit',
#  'Soundwave, Sonic Spy // Soundwave, Superior Captain',
#  'Spellrune Painter // Spellrune Howler',
#  'Spellscorn Coven // Take It Back',
#  'Spikefield Hazard // Spikefield Cave',
#  'Spite // Malice',
#  'Spring // Mind',
#  'Spring-Loaded Sawblades // Bladewheel Chariot',
#  'Stand // Deliver',
#  'Starscream, Power Hungry // Starscream, Seeker Leader',
#  'Start // Finish',
#  'Start // Fire',
#  'Startled Awake // Persistent Nightmare',
#  'Status // Statue',
#  'Steady Tortoise // Harried Dash',
#  'Storm the Vault // Vault of Catlacan',
#  'Stormkeld Curator // Giant Secrets',
#  'Stormkeld Vanguard // Bear Down',
#  'Struggle // Survive',
#  'Student of Elements // Tobita, Master of Winds',
#  'Sun-Blessed Guardian // Furnace-Blessed Conqueror',
#  'Sunbird Standard // Sunbird Effigy',
#  'Supply // Demand',
#  'Suspicious Stowaway // Seafaring Werewolf',
#  'Sword Coast Serpent // Capsizing Wave',
#  "Tales of Master Seshiro // Seshiro's Living Legacy",
#  'Tangleclaw Werewolf // Fibrous Entangler',
#  'Tangled Florahedron // Tangled Vale',
#  'Tarkir Duneshaper // Burnished Dunestomper',
#  "Tarrian's Journal // The Tomb of Aclazotz",
#  'Tavern Ruffian // Tavern Smasher',
#  'Teachings of the Kirin // Kirin-Touched Orochi',
#  'Tempest Hart // Scan the Clouds',
#  "Tergrid, God of Fright // Tergrid's Lantern",
#  'Tetzin, Gnome Champion // The Golden-Gear Colossus',
#  'Thaumatic Compass // Spires of Orazca',
#  "The Dragon-Kami Reborn // Dragon-Kami's Egg",
#  'The Enigma Jewel // Locus of Enlightenment',
#  'The Everflowing Well // The Myriad Pools',
#  'The Fall of Lord Konda // Fragment of Konda',
#  'The Kami War // O-Kagachi Made Manifest',
#  "The Long Reach of Night // Animus of Night's Reach",
#  'The Modern Age // Vector Glider',
#  'The Restoration of Eiganjo // Architect of Restoration',
#  'The Shattered States Era // Nameless Conqueror',
#  'The Superlatorium',
#  'Thing in the Ice // Awoken Horror',
#  'Thousand Moons Smithy // Barracks of the Thousand',
#  'Thraben Gargoyle // Stonewing Antagonizer',
#  'Thraben Sentry // Thraben Militia',
#  'Thrash // Threat',
#  'Threadbind Clique // Rip the Seams',
#  'Throne of the Grim Captain // The Grim Captain',
#  'Tireless Hauler // Dire-Strain Brawler',
#  'Tithing Blade // Consuming Sepulcher',
#  'Tlincalli Hunter // Retrieve Prey',
#  'Toil // Trouble',
#  'Topaz Dragon // Entropic Cloud',
#  "Toralf, God of Fury // Toralf's Hammer",
#  'Tormented Pariah // Rampaging Werewolf',
#  'Torrent Sculptor // Flamethrower Sonata',
#  "Tovolar's Huntmaster // Tovolar's Packleader",
#  'Tovolar, Dire Overlord // Tovolar, the Midnight Scourge',
#  'Town Gossipmonger // Incited Rabble',
#  'Treasure Map // Treasure Cove',
#  'Trial // Error',
#  "Tribute to Horobi // Echo of Death's Wail",
#  'Trivia Contest',
#  'Tuinvale Treefolk // Oaken Boon',
#  'Turn // Burn',
#  'Turntimber Symbiosis // Turntimber, Serpentine Wood',
#  'Twice Upon a Time // Unlikely Meeting',
#  'Twinblade Geist // Twinblade Invocation',
#  'Twining Twins // Swift Spiral',
#  'Twists and Turns // Mycoid Maze',
#  'Two-Handed Axe // Sweeping Cleave',
#  'Two-Headed Hunter // Twice the Rage',
#  'Ulrich of the Krallenhorde // Ulrich, Uncontested Alpha',
#  'Ultra Magnus, Tactician // Ultra Magnus, Armored Carrier',
#  'Ulvenwald Captive // Ulvenwald Abomination',
#  'Ulvenwald Mystics // Ulvenwald Primordials',
#  'Ulvenwald Oddity // Ulvenwald Behemoth',
#  'Umara Wizard // Umara Skyfalls',
#  'Uninvited Geist // Unimpeded Trespasser',
#  'Unquenchable Fury',
#  'Unstable Glyphbridge // Sandswirl Wanderglyph',
#  'Urabrask // The Great Work',
#  'Uvilda, Dean of Perfection // Nassari, Dean of Expression',
#  'Valakut Awakening // Valakut Stoneforge',
#  'Valentin, Dean of the Vein // Lisette, Dean of the Root',
#  'Valki, God of Lies // Tibalt, Cosmic Impostor',
#  "Vance's Blasting Cannons // Spitfire Bastion",
#  'Vantress Transmuter // Croaking Curse',
#  'Vastwood Fortification // Vastwood Thicket',
#  'Vengeful Strangler // Strangling Grasp',
#  'Very Cryptic Command',
#  'Vildin-Pack Outcast // Dronepack Kindred',
#  'Village Ironsmith // Ironfang',
#  'Village Messenger // Moonrise Intruder',
#  'Village Watch // Village Reavers',
#  'Villagers of Estwald // Howlpack of Estwald',
#  'Virtue of Courage // Embereth Blaze',
#  'Virtue of Knowledge // Vantress Visions',
#  'Virtue of Loyalty // Ardenvale Fealty',
#  'Virtue of Persistence // Locthwain Scorn',
#  'Virtue of Strength // Garenbrig Growth',
#  'Visage of Dread // Dread Osseosaur',
#  'Volatile Arsonist // Dire-Strain Anarchist',
#  'Voldaren Bloodcaster // Bloodbat Summoner',
#  'Voldaren Pariah // Abolisher of Bloodlines',
#  'Voltaic Visionary // Volt-Charged Berserker',
#  'Vorinclex // The Grand Evolution',
#  'Wandering Archaic // Explore the Vastlands',
#  'Warrant // Warden',
#  'Waterlogged Hulk // Watertight Gondola',
#  'Wax // Wane',
#  'Wear // Tear',
#  'Weary Prisoner // Wrathful Jailbreaker',
#  'Weaver of Blossoms // Blossom-Clad Werewolf',
#  'Wedding Announcement // Wedding Festivity',
#  'Welcome to . . . // Jurassic Park',
#  'Westvale Abbey // Ormendahl, Profane Prince',
#  'Who // What // When // Where // Why',
#  'Wolfbitten Captive // Krallenhorde Killer',
#  'Wolfkin Outcast // Wedding Crasher',
#  'Woodland Acolyte // Mend the Wilds',
#  'Young Blue Dragon // Sand Augury',
#  'Young Red Dragon // Bathe in Gold',
#  'Zof Consumption // Zof Bloodbog']

# %%
cards.columns
# Out:
# Index(['artist', 'artistIds', 'asciiName', 'attractionLights', 'availability',
#        'boosterTypes', 'borderColor', 'cardParts', 'colorIdentity',
#        'colorIndicator', 'colors', 'defense', 'duelDeck', 'edhrecRank',
#        'edhrecSaltiness', 'faceConvertedManaCost', 'faceFlavorName',
#        'faceManaValue', 'faceName', 'finishes', 'flavorName', 'flavorText',
#        'frameEffects', 'frameVersion', 'hand', 'hasAlternativeDeckLimit',
#        'hasContentWarning', 'hasFoil', 'hasNonFoil', 'isAlternative',
#        'isFullArt', 'isFunny', 'isOnlineOnly', 'isOversized', 'isPromo',
#        'isRebalanced', 'isReprint', 'isReserved', 'isStarter',
#        'isStorySpotlight', 'isTextless', 'isTimeshifted', 'keywords',
#        'language', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'manaValue', 'name', 'number', 'originalPrintings',
#        'originalReleaseDate', 'originalText', 'originalType', 'otherFaceIds',
#        'power', 'printings', 'promoTypes', 'rarity', 'rebalancedPrintings',
#        'relatedCards', 'securityStamp', 'setCode', 'side', 'signature',
#        'sourceProducts', 'subsets', 'subtypes', 'supertypes', 'text',
#        'toughness', 'type', 'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
cards[cards['name'] == 'A-Alrund, God of the Cosmos // A-Hakka, Whispering Raven']['text'].unique()
# Out:
# array(['Alrund gets +1/+1 for each card in your hand and each foretold card you own in exile.\\nAt the beginning of your end step, choose a card type, then reveal the top three cards of your library. Put all cards of the chosen type revealed this way into your hand and the rest on the bottom of your library in any order.',
#        "Flying\\nWhenever Hakka, Whispering Raven deals combat damage to a player, return it to its owner's hand, then scry 2."],
#       dtype=object)

# %%
cards.drop_duplicates(subset=['name', 'text']).shape
# Out:
# (28781, 78)

# %%
cards.drop_duplicates(subset=['text']).shape
# Out:
# (27060, 78)

# %% [markdown]
# ## cardlist stuff

# %%
def format_commander_name(commander_name:str):
    non_alphas_regex = "[^\w\s-]" # Remove everything that's not alphanumeric or space or hyphen
    formatted_name = re.sub(non_alphas_regex, "", commander_name)
    formatted_name = formatted_name.lower() # Make lowercase
    formatted_name = formatted_name.replace(" ", "-")  # Replace spaces with hyphens
    formatted_name = unidecode(formatted_name)
    print(f"In format_commander_name and formatted name is {formatted_name}")
    return formatted_name

# %%
format_commander_name("Orvar, the All-Form")
# Out:
# In format_commander_name and formatted name is orvar-the-all-form
# 'orvar-the-all-form'

# %%
commander_name = fail[0]

formatted_name = format_commander_name(commander_name)
json_url = f"https://json.edhrec.com/pages/commanders/{formatted_name}.json"
response = requests.get(json_url)
if response.status_code == 200:
    json_data = response.json()
    print(f"JSON request successful!")
    data = json_data
    print(sorted(data['cardlist'], key=lambda card: card['num_decks'], reverse=True))
else:
    print(f"JSON request failed! Try different commander name")
# Out:
# In format_commander_name and formatted name is galadriel-of-lothlórien
# JSON request failed! Try different commander name

# %%
data['container']
# Out:
# {'description': 'Popular decks and cards for Stangg, Echo Warrior',
#  'json_dict': {'cardlists': [{'cardviews': [{'name': "Etali's Favor",
#       'sanitized': 'etalis-favor',
#       'sanitized_wo': 'etalis-favor',
#       'url': '/cards/etalis-favor',
#       'synergy': 0.89,
#       'inclusion': 149,
#       'label': '95% of 157 decks\n+89% synergy',
#       'num_decks': 149,
#       'potential_decks': 157},
#      {'name': 'Diamond Pick-Axe',
#       'sanitized': 'diamond-pick-axe',
#       'sanitized_wo': 'diamond-pick-axe',
#       'url': '/cards/diamond-pick-axe',
#       'synergy': 0.15,
#       'inclusion': 38,
#       'label': '21% of 180 decks\n+15% synergy',
#       'num_decks': 38,
#       'potential_decks': 180},
#      {'name': "Tarrian's Soulcleaver",
#       'sanitized': 'tarrians-soulcleaver',
#       'sanitized_wo': 'tarrians-soulcleaver',
#       'url': '/cards/tarrians-soulcleaver',
#       'synergy': 0.08,
#       'inclusion': 29,
#       'label': '16% of 180 decks\n+8% synergy',
#       'num_decks': 29,
#       'potential_decks': 180},
#      {'name': 'Roaming Throne',
#       'sanitized': 'roaming-throne',
#       'sanitized_wo': 'roaming-throne',
#       'url': '/cards/roaming-throne',
#       'synergy': -0.18,
#       'inclusion': 11,
#       'label': '7% of 157 decks\n-18% synergy',
#       'num_decks': 11,
#       'potential_decks': 157}],
#     'header': 'New Cards',
#     'tag': 'newcards'},
#    {'cardviews': [{'name': 'Chishiro, the Shattered Blade',
#       'sanitized': 'chishiro-the-shattered-blade',
#       'sanitized_wo': 'chishiro-the-shattered-blade',
#       'url': '/cards/chishiro-the-shattered-blade',
#       'synergy': 0.81,
#       'inclusion': 1347,
#       'label': '84% of 1596 decks\n+81% synergy',
#       'num_decks': 1347,
#       'potential_decks': 1596},
#      {'name': 'Audacity',
#       'sanitized': 'audacity',
#       'sanitized_wo': 'audacity',
#       'url': '/cards/audacity',
#       'synergy': 0.79,
#       'inclusion': 1033,
#       'label': '82% of 1255 decks\n+79% synergy',
#       'num_decks': 1033,
#       'potential_decks': 1255},
#      {'name': 'Sticky Fingers',
#       'sanitized': 'sticky-fingers',
#       'sanitized_wo': 'sticky-fingers',
#       'url': '/cards/sticky-fingers',
#       'synergy': 0.78,
#       'inclusion': 1331,
#       'label': '84% of 1588 decks\n+78% synergy',
#       'num_decks': 1331,
#       'potential_decks': 1588},
#      {'name': 'Fruit of the First Tree',
#       'sanitized': 'fruit-of-the-first-tree',
#       'sanitized_wo': 'fruit-of-the-first-tree',
#       'url': '/cards/fruit-of-the-first-tree',
#       'synergy': 0.76,
#       'inclusion': 1240,
#       'label': '78% of 1598 decks\n+76% synergy',
#       'num_decks': 1240,
#       'potential_decks': 1598},
#      {'name': 'Rune of Might',
#       'sanitized': 'rune-of-might',
#       'sanitized_wo': 'rune-of-might',
#       'url': '/cards/rune-of-might',
#       'synergy': 0.75,
#       'inclusion': 1239,
#       'label': '78% of 1598 decks\n+75% synergy',
#       'num_decks': 1239,
#       'potential_decks': 1598},
#      {'name': 'Tanglespan Lookout',
#       'sanitized': 'tanglespan-lookout',
#       'sanitized_wo': 'tanglespan-lookout',
#       'url': '/cards/tanglespan-lookout',
#       'synergy': 0.74,
#       'inclusion': 372,
#       'label': '78% of 480 decks\n+74% synergy',
#       'num_decks': 372,
#       'potential_decks': 480},
#      {'name': 'Ancestral Mask',
#       'sanitized': 'ancestral-mask',
#       'sanitized_wo': 'ancestral-mask',
#       'url': '/cards/ancestral-mask',
#       'synergy': 0.72,
#       'inclusion': 1185,
#       'label': '74% of 1598 decks\n+72% synergy',
#       'num_decks': 1185,
#       'potential_decks': 1598},
#      {'name': 'One with the Kami',
#       'sanitized': 'one-with-the-kami',
#       'sanitized_wo': 'one-with-the-kami',
#       'url': '/cards/one-with-the-kami',
#       'synergy': 0.72,
#       'inclusion': 1230,
#       'label': '77% of 1596 decks\n+72% synergy',
#       'num_decks': 1230,
#       'potential_decks': 1596},
#      {'name': 'Setessan Champion',
#       'sanitized': 'setessan-champion',
#       'sanitized_wo': 'setessan-champion',
#       'url': '/cards/setessan-champion',
#       'synergy': 0.71,
#       'inclusion': 1193,
#       'label': '75% of 1598 decks\n+71% synergy',
#       'num_decks': 1193,
#       'potential_decks': 1598},
#      {'name': 'Eidolon of Blossoms',
#       'sanitized': 'eidolon-of-blossoms',
#       'sanitized_wo': 'eidolon-of-blossoms',
#       'url': '/cards/eidolon-of-blossoms',
#       'synergy': 0.71,
#       'inclusion': 1185,
#       'label': '74% of 1598 decks\n+71% synergy',
#       'num_decks': 1185,
#       'potential_decks': 1598}],
#     'header': 'High Synergy Cards',
#     'tag': 'highsynergycards'},
#    {'cardviews': [{'name': 'Swiftfoot Boots',
#       'sanitized': 'swiftfoot-boots',
#       'sanitized_wo': 'swiftfoot-boots',
#       'url': '/cards/swiftfoot-boots',
#       'synergy': 0.41,
#       'inclusion': 1243,
#       'label': '78% of 1598 decks\n+41% synergy',
#       'num_decks': 1243,
#       'potential_decks': 1598},
#      {'name': 'Bequeathal',
#       'sanitized': 'bequeathal',
#       'sanitized_wo': 'bequeathal',
#       'url': '/cards/bequeathal',
#       'synergy': 0.7,
#       'inclusion': 1152,
#       'label': '72% of 1598 decks\n+70% synergy',
#       'num_decks': 1152,
#       'potential_decks': 1598},
#      {'name': 'Snake Umbra',
#       'sanitized': 'snake-umbra',
#       'sanitized_wo': 'snake-umbra',
#       'url': '/cards/snake-umbra',
#       'synergy': 0.59,
#       'inclusion': 1118,
#       'label': '70% of 1598 decks\n+59% synergy',
#       'num_decks': 1118,
#       'potential_decks': 1598},
#      {'name': 'Beast Within',
#       'sanitized': 'beast-within',
#       'sanitized_wo': 'beast-within',
#       'url': '/cards/beast-within',
#       'synergy': 0.09,
#       'inclusion': 1109,
#       'label': '69% of 1598 decks\n+9% synergy',
#       'num_decks': 1109,
#       'potential_decks': 1598},
#      {'name': 'Thran Power Suit',
#       'sanitized': 'thran-power-suit',
#       'sanitized_wo': 'thran-power-suit',
#       'url': '/cards/thran-power-suit',
#       'synergy': 0.67,
#       'inclusion': 866,
#       'label': '69% of 1255 decks\n+67% synergy',
#       'num_decks': 866,
#       'potential_decks': 1255},
#      {'name': 'Goblin Anarchomancer',
#       'sanitized': 'goblin-anarchomancer',
#       'sanitized_wo': 'goblin-anarchomancer',
#       'url': '/cards/goblin-anarchomancer',
#       'synergy': 0.17,
#       'inclusion': 1100,
#       'label': '69% of 1597 decks\n+17% synergy',
#       'num_decks': 1100,
#       'potential_decks': 1597},
#      {'name': 'Alpha Authority',
#       'sanitized': 'alpha-authority',
#       'sanitized_wo': 'alpha-authority',
#       'url': '/cards/alpha-authority',
#       'synergy': 0.65,
#       'inclusion': 1090,
#       'label': '68% of 1598 decks\n+65% synergy',
#       'num_decks': 1090,
#       'potential_decks': 1598},
#      {'name': 'Sanctum Weaver',
#       'sanitized': 'sanctum-weaver',
#       'sanitized_wo': 'sanctum-weaver',
#       'url': '/cards/sanctum-weaver',
#       'synergy': 0.63,
#       'inclusion': 1060,
#       'label': '66% of 1597 decks\n+63% synergy',
#       'num_decks': 1060,
#       'potential_decks': 1597},
#      {'name': 'Rancor',
#       'sanitized': 'rancor',
#       'sanitized_wo': 'rancor',
#       'url': '/cards/rancor',
#       'synergy': 0.55,
#       'inclusion': 1051,
#       'label': '66% of 1598 decks\n+55% synergy',
#       'num_decks': 1051,
#       'potential_decks': 1598},
#      {'name': 'Bear Umbra',
#       'sanitized': 'bear-umbra',
#       'sanitized_wo': 'bear-umbra',
#       'url': '/cards/bear-umbra',
#       'synergy': 0.54,
#       'inclusion': 1033,
#       'label': '65% of 1598 decks\n+54% synergy',
#       'num_decks': 1033,
#       'potential_decks': 1598}],
#     'header': 'Top Cards',
#     'tag': 'topcards'},
#    {'cardviews': [{'name': 'Akki Battle Squad',
#       'sanitized': 'akki-battle-squad',
#       'sanitized_wo': 'akki-battle-squad',
#       'url': '/cards/akki-battle-squad',
#       'synergy': 0.52,
#       'inclusion': 956,
#       'label': '60% of 1596 decks\n+52% synergy',
#       'num_decks': 956,
#       'potential_decks': 1596},
#      {'name': 'Lizard Blades',
#       'sanitized': 'lizard-blades',
#       'sanitized_wo': 'lizard-blades',
#       'url': '/cards/lizard-blades',
#       'synergy': 0.45,
#       'inclusion': 806,
#       'label': '51% of 1596 decks\n+45% synergy',
#       'num_decks': 806,
#       'potential_decks': 1596},
#      {'name': "Nylea's Colossus",
#       'sanitized': 'nyleas-colossus',
#       'sanitized_wo': 'nyleas-colossus',
#       'url': '/cards/nyleas-colossus',
#       'synergy': 0.46,
#       'inclusion': 748,
#       'label': '47% of 1598 decks\n+46% synergy',
#       'num_decks': 748,
#       'potential_decks': 1598},
#      {'name': 'Kodama of the West Tree',
#       'sanitized': 'kodama-of-the-west-tree',
#       'sanitized_wo': 'kodama-of-the-west-tree',
#       'url': '/cards/kodama-of-the-west-tree',
#       'synergy': 0.33,
#       'inclusion': 713,
#       'label': '45% of 1596 decks\n+33% synergy',
#       'num_decks': 713,
#       'potential_decks': 1596},
#      {'name': 'Kediss, Emberclaw Familiar',
#       'sanitized': 'kediss-emberclaw-familiar',
#       'sanitized_wo': 'kediss-emberclaw-familiar',
#       'url': '/cards/kediss-emberclaw-familiar',
#       'synergy': 0.4,
#       'inclusion': 706,
#       'label': '44% of 1598 decks\n+40% synergy',
#       'num_decks': 706,
#       'potential_decks': 1598},
#      {'name': 'Composer of Spring',
#       'sanitized': 'composer-of-spring',
#       'sanitized_wo': 'composer-of-spring',
#       'url': '/cards/composer-of-spring',
#       'synergy': 0.41,
#       'inclusion': 231,
#       'label': '43% of 542 decks\n+41% synergy',
#       'num_decks': 231,
#       'potential_decks': 542},
#      {'name': 'Wulfgar of Icewind Dale',
#       'sanitized': 'wulfgar-of-icewind-dale',
#       'sanitized_wo': 'wulfgar-of-icewind-dale',
#       'url': '/cards/wulfgar-of-icewind-dale',
#       'synergy': 0.35,
#       'inclusion': 645,
#       'label': '40% of 1597 decks\n+35% synergy',
#       'num_decks': 645,
#       'potential_decks': 1597},
#      {'name': 'Herald of the Pantheon',
#       'sanitized': 'herald-of-the-pantheon',
#       'sanitized_wo': 'herald-of-the-pantheon',
#       'url': '/cards/herald-of-the-pantheon',
#       'synergy': 0.36,
#       'inclusion': 606,
#       'label': '38% of 1598 decks\n+36% synergy',
#       'num_decks': 606,
#       'potential_decks': 1598},
#      {'name': 'Storm Herald',
#       'sanitized': 'storm-herald',
#       'sanitized_wo': 'storm-herald',
#       'url': '/cards/storm-herald',
#       'synergy': 0.34,
#       'inclusion': 558,
#       'label': '35% of 1598 decks\n+34% synergy',
#       'num_decks': 558,
#       'potential_decks': 1598},
#      {'name': 'Karlach, Fury of Avernus',
#       'sanitized': 'karlach-fury-of-avernus',
#       'sanitized_wo': 'karlach-fury-of-avernus',
#       'url': '/cards/karlach-fury-of-avernus',
#       'synergy': 0.26,
#       'inclusion': 515,
#       'label': '33% of 1555 decks\n+26% synergy',
#       'num_decks': 515,
#       'potential_decks': 1555},
#      {'name': 'Sakura-Tribe Elder',
#       'sanitized': 'sakura-tribe-elder',
#       'sanitized_wo': 'sakura-tribe-elder',
#       'url': '/cards/sakura-tribe-elder',
#       'synergy': -0.01,
#       'inclusion': 472,
#       'label': '30% of 1598 decks\n-1% synergy',
#       'num_decks': 472,
#       'potential_decks': 1598},
#      {'name': 'Knickknack Ouphe',
#       'sanitized': 'knickknack-ouphe',
#       'sanitized_wo': 'knickknack-ouphe',
#       'url': '/cards/knickknack-ouphe',
#       'synergy': 0.28,
#       'inclusion': 102,
#       'label': '29% of 350 decks\n+28% synergy',
#       'num_decks': 102,
#       'potential_decks': 350},
#      {'name': 'Komainu Battle Armor',
#       'sanitized': 'komainu-battle-armor',
#       'sanitized_wo': 'komainu-battle-armor',
#       'url': '/cards/komainu-battle-armor',
#       'synergy': 0.23,
#       'inclusion': 442,
#       'label': '28% of 1596 decks\n+23% synergy',
#       'num_decks': 442,
#       'potential_decks': 1596},
#      {'name': 'Tanuki Transplanter',
#       'sanitized': 'tanuki-transplanter',
#       'sanitized_wo': 'tanuki-transplanter',
#       'url': '/cards/tanuki-transplanter',
#       'synergy': 0.21,
#       'inclusion': 414,
#       'label': '26% of 1596 decks\n+21% synergy',
#       'num_decks': 414,
#       'potential_decks': 1596},
#      {'name': 'Verduran Enchantress',
#       'sanitized': 'verduran-enchantress',
#       'sanitized_wo': 'verduran-enchantress',
#       'url': '/cards/verduran-enchantress',
#       'synergy': 0.23,
#       'inclusion': 405,
#       'label': '25% of 1598 decks\n+23% synergy',
#       'num_decks': 405,
#       'potential_decks': 1598},
#      {'name': 'Eternal Witness',
#       'sanitized': 'eternal-witness',
#       'sanitized_wo': 'eternal-witness',
#       'url': '/cards/eternal-witness',
#       'synergy': -0.01,
#       'inclusion': 382,
#       'label': '24% of 1598 decks\n-1% synergy',
#       'num_decks': 382,
#       'potential_decks': 1598},
#      {'name': 'Destiny Spinner',
#       'sanitized': 'destiny-spinner',
#       'sanitized_wo': 'destiny-spinner',
#       'url': '/cards/destiny-spinner',
#       'synergy': 0.18,
#       'inclusion': 371,
#       'label': '23% of 1598 decks\n+18% synergy',
#       'num_decks': 371,
#       'potential_decks': 1598},
#      {'name': 'Forgeborn Oreads',
#       'sanitized': 'forgeborn-oreads',
#       'sanitized_wo': 'forgeborn-oreads',
#       'url': '/cards/forgeborn-oreads',
#       'synergy': 0.22,
#       'inclusion': 351,
#       'label': '22% of 1598 decks\n+22% synergy',
#       'num_decks': 351,
#       'potential_decks': 1598},
#      {'name': 'Jaheira, Friend of the Forest',
#       'sanitized': 'jaheira-friend-of-the-forest',
#       'sanitized_wo': 'jaheira-friend-of-the-forest',
#       'url': '/cards/jaheira-friend-of-the-forest',
#       'synergy': 0.15,
#       'inclusion': 298,
#       'label': '19% of 1530 decks\n+15% synergy',
#       'num_decks': 298,
#       'potential_decks': 1530},
#      {'name': 'Llanowar Elves',
#       'sanitized': 'llanowar-elves',
#       'sanitized_wo': 'llanowar-elves',
#       'url': '/cards/llanowar-elves',
#       'synergy': -0.16,
#       'inclusion': 292,
#       'label': '18% of 1598 decks\n-16% synergy',
#       'num_decks': 292,
#       'potential_decks': 1598},
#      {'name': 'Elvish Archivist',
#       'sanitized': 'elvish-archivist',
#       'sanitized_wo': 'elvish-archivist',
#       'url': '/cards/elvish-archivist',
#       'synergy': 0.16,
#       'inclusion': 83,
#       'label': '17% of 480 decks\n+16% synergy',
#       'num_decks': 83,
#       'potential_decks': 480},
#      {'name': 'Birds of Paradise',
#       'sanitized': 'birds-of-paradise',
#       'sanitized_wo': 'birds-of-paradise',
#       'url': '/cards/birds-of-paradise',
#       'synergy': -0.08,
#       'inclusion': 266,
#       'label': '17% of 1598 decks\n-8% synergy',
#       'num_decks': 266,
#       'potential_decks': 1598},
#      {'name': 'Nessian Wanderer',
#       'sanitized': 'nessian-wanderer',
#       'sanitized_wo': 'nessian-wanderer',
#       'url': '/cards/nessian-wanderer',
#       'synergy': 0.15,
#       'inclusion': 257,
#       'label': '16% of 1598 decks\n+15% synergy',
#       'num_decks': 257,
#       'potential_decks': 1598},
#      {'name': 'Elvish Mystic',
#       'sanitized': 'elvish-mystic',
#       'sanitized_wo': 'elvish-mystic',
#       'url': '/cards/elvish-mystic',
#       'synergy': -0.14,
#       'inclusion': 227,
#       'label': '14% of 1598 decks\n-14% synergy',
#       'num_decks': 227,
#       'potential_decks': 1598},
#      {'name': 'Guardian Augmenter',
#       'sanitized': 'guardian-augmenter',
#       'sanitized_wo': 'guardian-augmenter',
#       'url': '/cards/guardian-augmenter',
#       'synergy': 0.1,
#       'inclusion': 224,
#       'label': '14% of 1597 decks\n+10% synergy',
#       'num_decks': 224,
#       'potential_decks': 1597},
#      {'name': 'Samut, Vizier of Naktamun',
#       'sanitized': 'samut-vizier-of-naktamun',
#       'sanitized_wo': 'samut-vizier-of-naktamun',
#       'url': '/cards/samut-vizier-of-naktamun',
#       'synergy': 0.11,
#       'inclusion': 94,
#       'label': '14% of 671 decks\n+11% synergy',
#       'num_decks': 94,
#       'potential_decks': 671},
#      {'name': 'Nyxborn Behemoth',
#       'sanitized': 'nyxborn-behemoth',
#       'sanitized_wo': 'nyxborn-behemoth',
#       'url': '/cards/nyxborn-behemoth',
#       'synergy': 0.13,
#       'inclusion': 73,
#       'label': '13% of 542 decks\n+13% synergy',
#       'num_decks': 73,
#       'potential_decks': 542},
#      {'name': 'Brass Squire',
#       'sanitized': 'brass-squire',
#       'sanitized_wo': 'brass-squire',
#       'url': '/cards/brass-squire',
#       'synergy': 0.12,
#       'inclusion': 207,
#       'label': '13% of 1598 decks\n+12% synergy',
#       'num_decks': 207,
#       'potential_decks': 1598},
#      {'name': 'Rabbit Battery',
#       'sanitized': 'rabbit-battery',
#       'sanitized_wo': 'rabbit-battery',
#       'url': '/cards/rabbit-battery',
#       'synergy': 0.1,
#       'inclusion': 192,
#       'label': '12% of 1596 decks\n+10% synergy',
#       'num_decks': 192,
#       'potential_decks': 1596},
#      {'name': 'Fyndhorn Elves',
#       'sanitized': 'fyndhorn-elves',
#       'sanitized_wo': 'fyndhorn-elves',
#       'url': '/cards/fyndhorn-elves',
#       'synergy': -0.12,
#       'inclusion': 187,
#       'label': '12% of 1598 decks\n-12% synergy',
#       'num_decks': 187,
#       'potential_decks': 1598},
#      {'name': 'Argothian Enchantress',
#       'sanitized': 'argothian-enchantress',
#       'sanitized_wo': 'argothian-enchantress',
#       'url': '/cards/argothian-enchantress',
#       'synergy': 0.11,
#       'inclusion': 185,
#       'label': '12% of 1598 decks\n+11% synergy',
#       'num_decks': 185,
#       'potential_decks': 1598},
#      {'name': 'Nexus Wardens',
#       'sanitized': 'nexus-wardens',
#       'sanitized_wo': 'nexus-wardens',
#       'url': '/cards/nexus-wardens',
#       'synergy': 0.1,
#       'inclusion': 172,
#       'label': '11% of 1598 decks\n+10% synergy',
#       'num_decks': 172,
#       'potential_decks': 1598},
#      {'name': 'Xenagos, God of Revels',
#       'sanitized': 'xenagos-god-of-revels',
#       'sanitized_wo': 'xenagos-god-of-revels',
#       'url': '/cards/xenagos-god-of-revels',
#       'synergy': -0.01,
#       'inclusion': 150,
#       'label': '9% of 1598 decks\n-1% synergy',
#       'num_decks': 150,
#       'potential_decks': 1598},
#      {'name': 'Reckless Fireweaver',
#       'sanitized': 'reckless-fireweaver',
#       'sanitized_wo': 'reckless-fireweaver',
#       'url': '/cards/reckless-fireweaver',
#       'synergy': 0.04,
#       'inclusion': 148,
#       'label': '9% of 1598 decks\n+4% synergy',
#       'num_decks': 148,
#       'potential_decks': 1598},
#      {'name': 'Delighted Halfling',
#       'sanitized': 'delighted-halfling',
#       'sanitized_wo': 'delighted-halfling',
#       'url': '/cards/delighted-halfling',
#       'synergy': -0.1,
#       'inclusion': 57,
#       'label': '9% of 636 decks\n-10% synergy',
#       'num_decks': 57,
#       'potential_decks': 636},
#      {'name': 'Reclamation Sage',
#       'sanitized': 'reclamation-sage',
#       'sanitized_wo': 'reclamation-sage',
#       'url': '/cards/reclamation-sage',
#       'synergy': -0.08,
#       'inclusion': 141,
#       'label': '9% of 1598 decks\n-8% synergy',
#       'num_decks': 141,
#       'potential_decks': 1598},
#      {'name': 'Ingenious Artillerist',
#       'sanitized': 'ingenious-artillerist',
#       'sanitized_wo': 'ingenious-artillerist',
#       'url': '/cards/ingenious-artillerist',
#       'synergy': 0.04,
#       'inclusion': 126,
#       'label': '8% of 1494 decks\n+4% synergy',
#       'num_decks': 126,
#       'potential_decks': 1494},
#      {'name': 'Aura Gnarlid',
#       'sanitized': 'aura-gnarlid',
#       'sanitized_wo': 'aura-gnarlid',
#       'url': '/cards/aura-gnarlid',
#       'synergy': 0.08,
#       'inclusion': 129,
#       'label': '8% of 1598 decks\n+8% synergy',
#       'num_decks': 129,
#       'potential_decks': 1598},
#      {'name': 'Champion of Lambholt',
#       'sanitized': 'champion-of-lambholt',
#       'sanitized_wo': 'champion-of-lambholt',
#       'url': '/cards/champion-of-lambholt',
#       'synergy': -0.02,
#       'inclusion': 128,
#       'label': '8% of 1598 decks\n-2% synergy',
#       'num_decks': 128,
#       'potential_decks': 1598},
#      {'name': 'Meria, Scholar of Antiquity',
#       'sanitized': 'meria-scholar-of-antiquity',
#       'sanitized_wo': 'meria-scholar-of-antiquity',
#       'url': '/cards/meria-scholar-of-antiquity',
#       'synergy': 0.06,
#       'inclusion': 95,
#       'label': '7% of 1339 decks\n+6% synergy',
#       'num_decks': 95,
#       'potential_decks': 1339},
#      {'name': 'Dockside Extortionist',
#       'sanitized': 'dockside-extortionist',
#       'sanitized_wo': 'dockside-extortionist',
#       'url': '/cards/dockside-extortionist',
#       'synergy': -0.05,
#       'inclusion': 111,
#       'label': '7% of 1598 decks\n-5% synergy',
#       'num_decks': 111,
#       'potential_decks': 1598},
#      {'name': 'Kami of Transience',
#       'sanitized': 'kami-of-transience',
#       'sanitized_wo': 'kami-of-transience',
#       'url': '/cards/kami-of-transience',
#       'synergy': 0.06,
#       'inclusion': 106,
#       'label': '7% of 1596 decks\n+6% synergy',
#       'num_decks': 106,
#       'potential_decks': 1596},
#      {'name': 'Valduk, Keeper of the Flame',
#       'sanitized': 'valduk-keeper-of-the-flame',
#       'sanitized_wo': 'valduk-keeper-of-the-flame',
#       'url': '/cards/valduk-keeper-of-the-flame',
#       'synergy': 0.06,
#       'inclusion': 106,
#       'label': '7% of 1598 decks\n+6% synergy',
#       'num_decks': 106,
#       'potential_decks': 1598},
#      {'name': 'Éomer, Marshal of Rohan',
#       'sanitized': 'eomer-marshal-of-rohan',
#       'sanitized_wo': 'eomer-marshal-of-rohan',
#       'url': '/cards/eomer-marshal-of-rohan',
#       'synergy': 0.06,
#       'inclusion': 37,
#       'label': '6% of 573 decks\n+6% synergy',
#       'num_decks': 37,
#       'potential_decks': 573},
#      {'name': 'Halana and Alena, Partners',
#       'sanitized': 'halana-and-alena-partners',
#       'sanitized_wo': 'halana-and-alena-partners',
#       'url': '/cards/halana-and-alena-partners',
#       'synergy': -0.06,
#       'inclusion': 101,
#       'label': '6% of 1596 decks\n-6% synergy',
#       'num_decks': 101,
#       'potential_decks': 1596},
#      {'name': 'Moraug, Fury of Akoum',
#       'sanitized': 'moraug-fury-of-akoum',
#       'sanitized_wo': 'moraug-fury-of-akoum',
#       'url': '/cards/moraug-fury-of-akoum',
#       'synergy': -0.03,
#       'inclusion': 96,
#       'label': '6% of 1598 decks\n-3% synergy',
#       'num_decks': 96,
#       'potential_decks': 1598},
#      {'name': 'Godo, Bandit Warlord',
#       'sanitized': 'godo-bandit-warlord',
#       'sanitized_wo': 'godo-bandit-warlord',
#       'url': '/cards/godo-bandit-warlord',
#       'synergy': 0.04,
#       'inclusion': 88,
#       'label': '6% of 1598 decks\n+4% synergy',
#       'num_decks': 88,
#       'potential_decks': 1598},
#      {'name': 'Toski, Bearer of Secrets',
#       'sanitized': 'toski-bearer-of-secrets',
#       'sanitized_wo': 'toski-bearer-of-secrets',
#       'url': '/cards/toski-bearer-of-secrets',
#       'synergy': -0.09,
#       'inclusion': 84,
#       'label': '5% of 1598 decks\n-9% synergy',
#       'num_decks': 84,
#       'potential_decks': 1598}],
#     'header': 'Creatures',
#     'tag': 'creatures'},
#    {'cardviews': [{'name': "Tamiyo's Safekeeping",
#       'sanitized': 'tamiyos-safekeeping',
#       'sanitized_wo': 'tamiyos-safekeeping',
#       'url': '/cards/tamiyos-safekeeping',
#       'synergy': 0.44,
#       'inclusion': 980,
#       'label': '61% of 1596 decks\n+44% synergy',
#       'num_decks': 980,
#       'potential_decks': 1596},
#      {'name': 'Royal Treatment',
#       'sanitized': 'royal-treatment',
#       'sanitized_wo': 'royal-treatment',
#       'url': '/cards/royal-treatment',
#       'synergy': 0.52,
#       'inclusion': 249,
#       'label': '59% of 419 decks\n+52% synergy',
#       'num_decks': 249,
#       'potential_decks': 419},
#      {'name': "Tyvar's Stand",
#       'sanitized': 'tyvars-stand',
#       'sanitized_wo': 'tyvars-stand',
#       'url': '/cards/tyvars-stand',
#       'synergy': 0.41,
#       'inclusion': 522,
#       'label': '59% of 887 decks\n+41% synergy',
#       'num_decks': 522,
#       'potential_decks': 887},
#      {'name': 'Chaos Warp',
#       'sanitized': 'chaos-warp',
#       'sanitized_wo': 'chaos-warp',
#       'url': '/cards/chaos-warp',
#       'synergy': 0.13,
#       'inclusion': 912,
#       'label': '57% of 1598 decks\n+13% synergy',
#       'num_decks': 912,
#       'potential_decks': 1598},
#      {'name': 'Silkguard',
#       'sanitized': 'silkguard',
#       'sanitized_wo': 'silkguard',
#       'url': '/cards/silkguard',
#       'synergy': 0.4,
#       'inclusion': 791,
#       'label': '50% of 1596 decks\n+40% synergy',
#       'num_decks': 791,
#       'potential_decks': 1596},
#      {'name': 'Heroic Intervention',
#       'sanitized': 'heroic-intervention',
#       'sanitized_wo': 'heroic-intervention',
#       'url': '/cards/heroic-intervention',
#       'synergy': 0.1,
#       'inclusion': 726,
#       'label': '45% of 1598 decks\n+10% synergy',
#       'num_decks': 726,
#       'potential_decks': 1598},
#      {'name': "Kazuul's Fury",
#       'sanitized': 'kazuuls-fury',
#       'sanitized_wo': 'kazuuls-fury',
#       'url': '/cards/kazuuls-fury',
#       'cards': [{'name': "Kazuul's Fury", 'url': 'kazuuls-fury'},
#        {'name': "Kazuul's Cliffs", 'url': 'kazuuls-fury'}],
#       'synergy': 0.24,
#       'inclusion': 503,
#       'label': '31% of 1598 decks\n+24% synergy',
#       'num_decks': 503,
#       'potential_decks': 1598},
#      {'name': "Gaea's Gift",
#       'sanitized': 'gaeas-gift',
#       'sanitized_wo': 'gaeas-gift',
#       'url': '/cards/gaeas-gift',
#       'synergy': 0.21,
#       'inclusion': 380,
#       'label': '30% of 1255 decks\n+21% synergy',
#       'num_decks': 380,
#       'potential_decks': 1255},
#      {'name': "Nature's Claim",
#       'sanitized': 'natures-claim',
#       'sanitized_wo': 'natures-claim',
#       'url': '/cards/natures-claim',
#       'synergy': 0.03,
#       'inclusion': 340,
#       'label': '21% of 1598 decks\n+3% synergy',
#       'num_decks': 340,
#       'potential_decks': 1598},
#      {'name': 'Bolt Bend',
#       'sanitized': 'bolt-bend',
#       'sanitized_wo': 'bolt-bend',
#       'url': '/cards/bolt-bend',
#       'synergy': 0.14,
#       'inclusion': 325,
#       'label': '20% of 1598 decks\n+14% synergy',
#       'num_decks': 325,
#       'potential_decks': 1598},
#      {'name': 'Khalni Ambush',
#       'sanitized': 'khalni-ambush',
#       'sanitized_wo': 'khalni-ambush',
#       'url': '/cards/khalni-ambush',
#       'cards': [{'name': 'Khalni Ambush', 'url': 'khalni-ambush'},
#        {'name': 'Khalni Territory', 'url': 'khalni-ambush'}],
#       'synergy': 0.11,
#       'inclusion': 292,
#       'label': '18% of 1598 decks\n+11% synergy',
#       'num_decks': 292,
#       'potential_decks': 1598},
#      {'name': 'Krosan Grip',
#       'sanitized': 'krosan-grip',
#       'sanitized_wo': 'krosan-grip',
#       'url': '/cards/krosan-grip',
#       'synergy': 0.03,
#       'inclusion': 284,
#       'label': '18% of 1598 decks\n+3% synergy',
#       'num_decks': 284,
#       'potential_decks': 1598},
#      {'name': 'Deflecting Swat',
#       'sanitized': 'deflecting-swat',
#       'sanitized_wo': 'deflecting-swat',
#       'url': '/cards/deflecting-swat',
#       'synergy': 0.03,
#       'inclusion': 282,
#       'label': '18% of 1598 decks\n+3% synergy',
#       'num_decks': 282,
#       'potential_decks': 1598},
#      {'name': 'Snakeskin Veil',
#       'sanitized': 'snakeskin-veil',
#       'sanitized_wo': 'snakeskin-veil',
#       'url': '/cards/snakeskin-veil',
#       'synergy': 0.08,
#       'inclusion': 268,
#       'label': '17% of 1597 decks\n+8% synergy',
#       'num_decks': 268,
#       'potential_decks': 1597},
#      {'name': "Hunter's Insight",
#       'sanitized': 'hunters-insight',
#       'sanitized_wo': 'hunters-insight',
#       'url': '/cards/hunters-insight',
#       'synergy': -0.0,
#       'inclusion': 234,
#       'label': '15% of 1598 decks\n-0% synergy',
#       'num_decks': 234,
#       'potential_decks': 1598},
#      {'name': 'Fling',
#       'sanitized': 'fling',
#       'sanitized_wo': 'fling',
#       'url': '/cards/fling',
#       'synergy': 0.09,
#       'inclusion': 230,
#       'label': '14% of 1598 decks\n+9% synergy',
#       'num_decks': 230,
#       'potential_decks': 1598},
#      {'name': 'Return to Nature',
#       'sanitized': 'return-to-nature',
#       'sanitized_wo': 'return-to-nature',
#       'url': '/cards/return-to-nature',
#       'synergy': -0.02,
#       'inclusion': 220,
#       'label': '14% of 1598 decks\n-2% synergy',
#       'num_decks': 220,
#       'potential_decks': 1598},
#      {'name': "Tibalt's Trickery",
#       'sanitized': 'tibalts-trickery',
#       'sanitized_wo': 'tibalts-trickery',
#       'url': '/cards/tibalts-trickery',
#       'synergy': -0.01,
#       'inclusion': 136,
#       'label': '9% of 1598 decks\n-1% synergy',
#       'num_decks': 136,
#       'potential_decks': 1598},
#      {'name': 'Second Harvest',
#       'sanitized': 'second-harvest',
#       'sanitized_wo': 'second-harvest',
#       'url': '/cards/second-harvest',
#       'synergy': 0.02,
#       'inclusion': 109,
#       'label': '7% of 1598 decks\n+2% synergy',
#       'num_decks': 109,
#       'potential_decks': 1598},
#      {'name': 'Abrade',
#       'sanitized': 'abrade',
#       'sanitized_wo': 'abrade',
#       'url': '/cards/abrade',
#       'synergy': -0.06,
#       'inclusion': 100,
#       'label': '6% of 1598 decks\n-6% synergy',
#       'num_decks': 100,
#       'potential_decks': 1598},
#      {'name': 'Wild Magic Surge',
#       'sanitized': 'wild-magic-surge',
#       'sanitized_wo': 'wild-magic-surge',
#       'url': '/cards/wild-magic-surge',
#       'synergy': 0.01,
#       'inclusion': 88,
#       'label': '6% of 1502 decks\n+1% synergy',
#       'num_decks': 88,
#       'potential_decks': 1502},
#      {'name': 'Thrill of Possibility',
#       'sanitized': 'thrill-of-possibility',
#       'sanitized_wo': 'thrill-of-possibility',
#       'url': '/cards/thrill-of-possibility',
#       'synergy': -0.02,
#       'inclusion': 92,
#       'label': '6% of 1598 decks\n-2% synergy',
#       'num_decks': 92,
#       'potential_decks': 1598}],
#     'header': 'Instants',
#     'tag': 'instants'},
#    {'cardviews': [{'name': 'Blasphemous Act',
#       'sanitized': 'blasphemous-act',
#       'sanitized_wo': 'blasphemous-act',
#       'url': '/cards/blasphemous-act',
#       'synergy': 0.12,
#       'inclusion': 855,
#       'label': '54% of 1598 decks\n+12% synergy',
#       'num_decks': 855,
#       'potential_decks': 1598},
#      {'name': "Nature's Lore",
#       'sanitized': 'natures-lore',
#       'sanitized_wo': 'natures-lore',
#       'url': '/cards/natures-lore',
#       'synergy': 0.15,
#       'inclusion': 846,
#       'label': '53% of 1598 decks\n+15% synergy',
#       'num_decks': 846,
#       'potential_decks': 1598},
#      {'name': 'Cultivate',
#       'sanitized': 'cultivate',
#       'sanitized_wo': 'cultivate',
#       'url': '/cards/cultivate',
#       'synergy': -0.03,
#       'inclusion': 844,
#       'label': '53% of 1598 decks\n-3% synergy',
#       'num_decks': 844,
#       'potential_decks': 1598},
#      {'name': 'Rampant Growth',
#       'sanitized': 'rampant-growth',
#       'sanitized_wo': 'rampant-growth',
#       'url': '/cards/rampant-growth',
#       'synergy': 0.07,
#       'inclusion': 834,
#       'label': '52% of 1598 decks\n+7% synergy',
#       'num_decks': 834,
#       'potential_decks': 1598},
#      {'name': "Kodama's Reach",
#       'sanitized': 'kodamas-reach',
#       'sanitized_wo': 'kodamas-reach',
#       'url': '/cards/kodamas-reach',
#       'synergy': -0.06,
#       'inclusion': 597,
#       'label': '37% of 1598 decks\n-6% synergy',
#       'num_decks': 597,
#       'potential_decks': 1598},
#      {'name': 'Three Visits',
#       'sanitized': 'three-visits',
#       'sanitized_wo': 'three-visits',
#       'url': '/cards/three-visits',
#       'synergy': 0.07,
#       'inclusion': 591,
#       'label': '37% of 1598 decks\n+7% synergy',
#       'num_decks': 591,
#       'potential_decks': 1598},
#      {'name': 'Farseek',
#       'sanitized': 'farseek',
#       'sanitized_wo': 'farseek',
#       'url': '/cards/farseek',
#       'synergy': 0.08,
#       'inclusion': 539,
#       'label': '34% of 1598 decks\n+8% synergy',
#       'num_decks': 539,
#       'potential_decks': 1598},
#      {'name': 'Decimate',
#       'sanitized': 'decimate',
#       'sanitized_wo': 'decimate',
#       'url': '/cards/decimate',
#       'synergy': 0.06,
#       'inclusion': 441,
#       'label': '28% of 1598 decks\n+6% synergy',
#       'num_decks': 441,
#       'potential_decks': 1598},
#      {'name': 'Last Night Together',
#       'sanitized': 'last-night-together',
#       'sanitized_wo': 'last-night-together',
#       'url': '/cards/last-night-together',
#       'synergy': 0.22,
#       'inclusion': 57,
#       'label': '26% of 220 decks\n+22% synergy',
#       'num_decks': 57,
#       'potential_decks': 220},
#      {'name': 'Hull Breach',
#       'sanitized': 'hull-breach',
#       'sanitized_wo': 'hull-breach',
#       'url': '/cards/hull-breach',
#       'synergy': 0.12,
#       'inclusion': 413,
#       'label': '26% of 1598 decks\n+12% synergy',
#       'num_decks': 413,
#       'potential_decks': 1598},
#      {'name': 'Bala Ged Recovery',
#       'sanitized': 'bala-ged-recovery',
#       'sanitized_wo': 'bala-ged-recovery',
#       'url': '/cards/bala-ged-recovery',
#       'cards': [{'name': 'Bala Ged Recovery', 'url': 'bala-ged-recovery'},
#        {'name': 'Bala Ged Sanctuary', 'url': 'bala-ged-recovery'}],
#       'synergy': 0.05,
#       'inclusion': 311,
#       'label': '19% of 1598 decks\n+5% synergy',
#       'num_decks': 311,
#       'potential_decks': 1598},
#      {'name': "Rishkar's Expertise",
#       'sanitized': 'rishkars-expertise',
#       'sanitized_wo': 'rishkars-expertise',
#       'url': '/cards/rishkars-expertise',
#       'synergy': -0.09,
#       'inclusion': 294,
#       'label': '18% of 1598 decks\n-9% synergy',
#       'num_decks': 294,
#       'potential_decks': 1598},
#      {'name': 'Vandalblast',
#       'sanitized': 'vandalblast',
#       'sanitized_wo': 'vandalblast',
#       'url': '/cards/vandalblast',
#       'synergy': -0.04,
#       'inclusion': 271,
#       'label': '17% of 1598 decks\n-4% synergy',
#       'num_decks': 271,
#       'potential_decks': 1598},
#      {'name': 'Chain Reaction',
#       'sanitized': 'chain-reaction',
#       'sanitized_wo': 'chain-reaction',
#       'url': '/cards/chain-reaction',
#       'synergy': 0.04,
#       'inclusion': 270,
#       'label': '17% of 1598 decks\n+4% synergy',
#       'num_decks': 270,
#       'potential_decks': 1598},
#      {'name': "Chandra's Ignition",
#       'sanitized': 'chandras-ignition',
#       'sanitized_wo': 'chandras-ignition',
#       'url': '/cards/chandras-ignition',
#       'synergy': 0.06,
#       'inclusion': 233,
#       'label': '15% of 1598 decks\n+6% synergy',
#       'num_decks': 233,
#       'potential_decks': 1598},
#      {'name': 'Seize the Day',
#       'sanitized': 'seize-the-day',
#       'sanitized_wo': 'seize-the-day',
#       'url': '/cards/seize-the-day',
#       'synergy': 0.09,
#       'inclusion': 195,
#       'label': '12% of 1598 decks\n+9% synergy',
#       'num_decks': 195,
#       'potential_decks': 1598},
#      {'name': "Rofellos's Gift",
#       'sanitized': 'rofelloss-gift',
#       'sanitized_wo': 'rofelloss-gift',
#       'url': '/cards/rofelloss-gift',
#       'synergy': 0.11,
#       'inclusion': 187,
#       'label': '12% of 1598 decks\n+11% synergy',
#       'num_decks': 187,
#       'potential_decks': 1598},
#      {'name': "Life's Legacy",
#       'sanitized': 'lifes-legacy',
#       'sanitized_wo': 'lifes-legacy',
#       'url': '/cards/lifes-legacy',
#       'synergy': 0.09,
#       'inclusion': 187,
#       'label': '12% of 1598 decks\n+9% synergy',
#       'num_decks': 187,
#       'potential_decks': 1598},
#      {'name': 'Relentless Assault',
#       'sanitized': 'relentless-assault',
#       'sanitized_wo': 'relentless-assault',
#       'url': '/cards/relentless-assault',
#       'synergy': 0.05,
#       'inclusion': 185,
#       'label': '12% of 1598 decks\n+5% synergy',
#       'num_decks': 185,
#       'potential_decks': 1598},
#      {'name': "Jeska's Will",
#       'sanitized': 'jeskas-will',
#       'sanitized_wo': 'jeskas-will',
#       'url': '/cards/jeskas-will',
#       'synergy': -0.1,
#       'inclusion': 185,
#       'label': '12% of 1598 decks\n-10% synergy',
#       'num_decks': 185,
#       'potential_decks': 1598},
#      {'name': 'Creeping Renaissance',
#       'sanitized': 'creeping-renaissance',
#       'sanitized_wo': 'creeping-renaissance',
#       'url': '/cards/creeping-renaissance',
#       'synergy': 0.07,
#       'inclusion': 170,
#       'label': '11% of 1598 decks\n+7% synergy',
#       'num_decks': 170,
#       'potential_decks': 1598},
#      {'name': 'Harmonize',
#       'sanitized': 'harmonize',
#       'sanitized_wo': 'harmonize',
#       'url': '/cards/harmonize',
#       'synergy': -0.1,
#       'inclusion': 160,
#       'label': '10% of 1598 decks\n-10% synergy',
#       'num_decks': 160,
#       'potential_decks': 1598},
#      {'name': "Smoke Spirits' Aid",
#       'sanitized': 'smoke-spirits-aid',
#       'sanitized_wo': 'smoke-spirits-aid',
#       'url': '/cards/smoke-spirits-aid',
#       'synergy': 0.03,
#       'inclusion': 114,
#       'label': '7% of 1596 decks\n+3% synergy',
#       'num_decks': 114,
#       'potential_decks': 1596},
#      {'name': "Soul's Majesty",
#       'sanitized': 'souls-majesty',
#       'sanitized_wo': 'souls-majesty',
#       'url': '/cards/souls-majesty',
#       'synergy': 0.01,
#       'inclusion': 107,
#       'label': '7% of 1598 decks\n+1% synergy',
#       'num_decks': 107,
#       'potential_decks': 1598},
#      {'name': 'Skyshroud Claim',
#       'sanitized': 'skyshroud-claim',
#       'sanitized_wo': 'skyshroud-claim',
#       'url': '/cards/skyshroud-claim',
#       'synergy': -0.06,
#       'inclusion': 103,
#       'label': '6% of 1598 decks\n-6% synergy',
#       'num_decks': 103,
#       'potential_decks': 1598},
#      {'name': "Witch's Mark",
#       'sanitized': 'witchs-mark',
#       'sanitized_wo': 'witchs-mark',
#       'url': '/cards/witchs-mark',
#       'synergy': -0.01,
#       'inclusion': 21,
#       'label': '6% of 350 decks\n-1% synergy',
#       'num_decks': 21,
#       'potential_decks': 350},
#      {'name': 'Reckless Handling',
#       'sanitized': 'reckless-handling',
#       'sanitized_wo': 'reckless-handling',
#       'url': '/cards/reckless-handling',
#       'synergy': 0.03,
#       'inclusion': 37,
#       'label': '6% of 671 decks\n+3% synergy',
#       'num_decks': 37,
#       'potential_decks': 671}],
#     'header': 'Sorceries',
#     'tag': 'sorceries'},
#    {'cardviews': [{'name': 'Helm of the Gods',
#       'sanitized': 'helm-of-the-gods',
#       'sanitized_wo': 'helm-of-the-gods',
#       'url': '/cards/helm-of-the-gods',
#       'synergy': 0.47,
#       'inclusion': 764,
#       'label': '48% of 1598 decks\n+47% synergy',
#       'num_decks': 764,
#       'potential_decks': 1598},
#      {'name': 'Skullclamp',
#       'sanitized': 'skullclamp',
#       'sanitized_wo': 'skullclamp',
#       'url': '/cards/skullclamp',
#       'synergy': 0.37,
#       'inclusion': 679,
#       'label': '42% of 1598 decks\n+37% synergy',
#       'num_decks': 679,
#       'potential_decks': 1598},
#      {'name': 'Nettlecyst',
#       'sanitized': 'nettlecyst',
#       'sanitized_wo': 'nettlecyst',
#       'url': '/cards/nettlecyst',
#       'synergy': 0.37,
#       'inclusion': 624,
#       'label': '39% of 1597 decks\n+37% synergy',
#       'num_decks': 624,
#       'potential_decks': 1597},
#      {'name': 'Mithril Coat',
#       'sanitized': 'mithril-coat',
#       'sanitized_wo': 'mithril-coat',
#       'url': '/cards/mithril-coat',
#       'synergy': 0.29,
#       'inclusion': 238,
#       'label': '38% of 630 decks\n+29% synergy',
#       'num_decks': 238,
#       'potential_decks': 630},
#      {'name': 'Basilisk Collar',
#       'sanitized': 'basilisk-collar',
#       'sanitized_wo': 'basilisk-collar',
#       'url': '/cards/basilisk-collar',
#       'synergy': 0.31,
#       'inclusion': 583,
#       'label': '36% of 1598 decks\n+31% synergy',
#       'num_decks': 583,
#       'potential_decks': 1598},
#      {'name': 'Blackblade Reforged',
#       'sanitized': 'blackblade-reforged',
#       'sanitized_wo': 'blackblade-reforged',
#       'url': '/cards/blackblade-reforged',
#       'synergy': 0.21,
#       'inclusion': 477,
#       'label': '30% of 1598 decks\n+21% synergy',
#       'num_decks': 477,
#       'potential_decks': 1598},
#      {'name': 'The Reaver Cleaver',
#       'sanitized': 'the-reaver-cleaver',
#       'sanitized_wo': 'the-reaver-cleaver',
#       'url': '/cards/the-reaver-cleaver',
#       'synergy': 0.25,
#       'inclusion': 424,
#       'label': '29% of 1464 decks\n+25% synergy',
#       'num_decks': 424,
#       'potential_decks': 1464},
#      {'name': 'Bloodforged Battle-Axe',
#       'sanitized': 'bloodforged-battle-axe',
#       'sanitized_wo': 'bloodforged-battle-axe',
#       'url': '/cards/bloodforged-battle-axe',
#       'synergy': 0.24,
#       'inclusion': 421,
#       'label': '26% of 1598 decks\n+24% synergy',
#       'num_decks': 421,
#       'potential_decks': 1598},
#      {'name': 'Mage Slayer',
#       'sanitized': 'mage-slayer',
#       'sanitized_wo': 'mage-slayer',
#       'url': '/cards/mage-slayer',
#       'synergy': 0.17,
#       'inclusion': 415,
#       'label': '26% of 1598 decks\n+17% synergy',
#       'num_decks': 415,
#       'potential_decks': 1598},
#      {'name': 'Beamtown Beatstick',
#       'sanitized': 'beamtown-beatstick',
#       'sanitized_wo': 'beamtown-beatstick',
#       'url': '/cards/beamtown-beatstick',
#       'synergy': 0.21,
#       'inclusion': 176,
#       'label': '23% of 751 decks\n+21% synergy',
#       'num_decks': 176,
#       'potential_decks': 751},
#      {'name': 'Hammer of Nazahn',
#       'sanitized': 'hammer-of-nazahn',
#       'sanitized_wo': 'hammer-of-nazahn',
#       'url': '/cards/hammer-of-nazahn',
#       'synergy': 0.19,
#       'inclusion': 338,
#       'label': '21% of 1598 decks\n+19% synergy',
#       'num_decks': 338,
#       'potential_decks': 1598},
#      {'name': 'Scepter of Celebration',
#       'sanitized': 'scepter-of-celebration',
#       'sanitized_wo': 'scepter-of-celebration',
#       'url': '/cards/scepter-of-celebration',
#       'synergy': 0.17,
#       'inclusion': 294,
#       'label': '19% of 1588 decks\n+17% synergy',
#       'num_decks': 294,
#       'potential_decks': 1588},
#      {'name': "Commander's Plate",
#       'sanitized': 'commanders-plate',
#       'sanitized_wo': 'commanders-plate',
#       'url': '/cards/commanders-plate',
#       'synergy': 0.16,
#       'inclusion': 293,
#       'label': '18% of 1598 decks\n+16% synergy',
#       'num_decks': 293,
#       'potential_decks': 1598},
#      {'name': 'Mirror Box',
#       'sanitized': 'mirror-box',
#       'sanitized_wo': 'mirror-box',
#       'url': '/cards/mirror-box',
#       'synergy': 0.16,
#       'inclusion': 288,
#       'label': '18% of 1596 decks\n+16% synergy',
#       'num_decks': 288,
#       'potential_decks': 1596},
#      {'name': 'Gilded Pinions',
#       'sanitized': 'gilded-pinions',
#       'sanitized_wo': 'gilded-pinions',
#       'url': '/cards/gilded-pinions',
#       'synergy': 0.17,
#       'inclusion': 275,
#       'label': '17% of 1588 decks\n+17% synergy',
#       'num_decks': 275,
#       'potential_decks': 1588},
#      {'name': 'Darksteel Plate',
#       'sanitized': 'darksteel-plate',
#       'sanitized_wo': 'darksteel-plate',
#       'url': '/cards/darksteel-plate',
#       'synergy': 0.14,
#       'inclusion': 271,
#       'label': '17% of 1598 decks\n+14% synergy',
#       'num_decks': 271,
#       'potential_decks': 1598},
#      {'name': 'Sword of Vengeance',
#       'sanitized': 'sword-of-vengeance',
#       'sanitized_wo': 'sword-of-vengeance',
#       'url': '/cards/sword-of-vengeance',
#       'synergy': 0.12,
#       'inclusion': 249,
#       'label': '16% of 1598 decks\n+12% synergy',
#       'num_decks': 249,
#       'potential_decks': 1598},
#      {'name': 'Loxodon Warhammer',
#       'sanitized': 'loxodon-warhammer',
#       'sanitized_wo': 'loxodon-warhammer',
#       'url': '/cards/loxodon-warhammer',
#       'synergy': 0.12,
#       'inclusion': 245,
#       'label': '15% of 1598 decks\n+12% synergy',
#       'num_decks': 245,
#       'potential_decks': 1598},
#      {'name': "Trailblazer's Boots",
#       'sanitized': 'trailblazers-boots',
#       'sanitized_wo': 'trailblazers-boots',
#       'url': '/cards/trailblazers-boots',
#       'synergy': 0.14,
#       'inclusion': 244,
#       'label': '15% of 1598 decks\n+14% synergy',
#       'num_decks': 244,
#       'potential_decks': 1598},
#      {'name': 'Sundial of the Infinite',
#       'sanitized': 'sundial-of-the-infinite',
#       'sanitized_wo': 'sundial-of-the-infinite',
#       'url': '/cards/sundial-of-the-infinite',
#       'synergy': 0.15,
#       'inclusion': 238,
#       'label': '15% of 1598 decks\n+15% synergy',
#       'num_decks': 238,
#       'potential_decks': 1598},
#      {'name': 'Sword of the Animist',
#       'sanitized': 'sword-of-the-animist',
#       'sanitized_wo': 'sword-of-the-animist',
#       'url': '/cards/sword-of-the-animist',
#       'synergy': 0.09,
#       'inclusion': 228,
#       'label': '14% of 1598 decks\n+9% synergy',
#       'num_decks': 228,
#       'potential_decks': 1598},
#      {'name': 'Belt of Giant Strength',
#       'sanitized': 'belt-of-giant-strength',
#       'sanitized_wo': 'belt-of-giant-strength',
#       'url': '/cards/belt-of-giant-strength',
#       'synergy': 0.12,
#       'inclusion': 223,
#       'label': '14% of 1597 decks\n+12% synergy',
#       'num_decks': 223,
#       'potential_decks': 1597},
#      {'name': 'Two-Handed Axe',
#       'sanitized': 'two-handed-axe',
#       'sanitized_wo': 'two-handed-axe',
#       'url': '/cards/two-handed-axe',
#       'synergy': 0.09,
#       'inclusion': 209,
#       'label': '14% of 1530 decks\n+9% synergy',
#       'num_decks': 209,
#       'potential_decks': 1530},
#      {'name': 'Hexplate Wallbreaker',
#       'sanitized': 'hexplate-wallbreaker',
#       'sanitized_wo': 'hexplate-wallbreaker',
#       'url': '/cards/hexplate-wallbreaker',
#       'synergy': 0.12,
#       'inclusion': 124,
#       'label': '13% of 920 decks\n+12% synergy',
#       'num_decks': 124,
#       'potential_decks': 920},
#      {'name': 'Shadowspear',
#       'sanitized': 'shadowspear',
#       'sanitized_wo': 'shadowspear',
#       'url': '/cards/shadowspear',
#       'synergy': 0.07,
#       'inclusion': 190,
#       'label': '12% of 1598 decks\n+7% synergy',
#       'num_decks': 190,
#       'potential_decks': 1598},
#      {'name': 'Embercleave',
#       'sanitized': 'embercleave',
#       'sanitized_wo': 'embercleave',
#       'url': '/cards/embercleave',
#       'synergy': 0.05,
#       'inclusion': 172,
#       'label': '11% of 1598 decks\n+5% synergy',
#       'num_decks': 172,
#       'potential_decks': 1598},
#      {'name': 'Lightning Greaves',
#       'sanitized': 'lightning-greaves',
#       'sanitized_wo': 'lightning-greaves',
#       'url': '/cards/lightning-greaves',
#       'synergy': -0.13,
#       'inclusion': 167,
#       'label': '10% of 1598 decks\n-13% synergy',
#       'num_decks': 167,
#       'potential_decks': 1598},
#      {'name': 'Fireshrieker',
#       'sanitized': 'fireshrieker',
#       'sanitized_wo': 'fireshrieker',
#       'url': '/cards/fireshrieker',
#       'synergy': 0.07,
#       'inclusion': 166,
#       'label': '10% of 1598 decks\n+7% synergy',
#       'num_decks': 166,
#       'potential_decks': 1598},
#      {'name': 'Helm of the Host',
#       'sanitized': 'helm-of-the-host',
#       'sanitized_wo': 'helm-of-the-host',
#       'url': '/cards/helm-of-the-host',
#       'synergy': 0.06,
#       'inclusion': 166,
#       'label': '10% of 1598 decks\n+6% synergy',
#       'num_decks': 166,
#       'potential_decks': 1598},
#      {'name': 'Staff of Titania',
#       'sanitized': 'staff-of-titania',
#       'sanitized_wo': 'staff-of-titania',
#       'url': '/cards/staff-of-titania',
#       'synergy': 0.07,
#       'inclusion': 84,
#       'label': '9% of 982 decks\n+7% synergy',
#       'num_decks': 84,
#       'potential_decks': 982},
#      {'name': 'Masterwork of Ingenuity',
#       'sanitized': 'masterwork-of-ingenuity',
#       'sanitized_wo': 'masterwork-of-ingenuity',
#       'url': '/cards/masterwork-of-ingenuity',
#       'synergy': 0.08,
#       'inclusion': 134,
#       'label': '8% of 1598 decks\n+8% synergy',
#       'num_decks': 134,
#       'potential_decks': 1598},
#      {'name': 'Mask of Memory',
#       'sanitized': 'mask-of-memory',
#       'sanitized_wo': 'mask-of-memory',
#       'url': '/cards/mask-of-memory',
#       'synergy': 0.07,
#       'inclusion': 130,
#       'label': '8% of 1598 decks\n+7% synergy',
#       'num_decks': 130,
#       'potential_decks': 1598},
#      {'name': 'Sword of Feast and Famine',
#       'sanitized': 'sword-of-feast-and-famine',
# ...
#       'label': '10% of 1596 decks\n+8% synergy',
#       'num_decks': 154,
#       'potential_decks': 1596},
#      {'name': 'Spinerock Knoll',
#       'sanitized': 'spinerock-knoll',
#       'sanitized_wo': 'spinerock-knoll',
#       'url': '/cards/spinerock-knoll',
#       'synergy': -0.01,
#       'inclusion': 154,
#       'label': '10% of 1598 decks\n-1% synergy',
#       'num_decks': 154,
#       'potential_decks': 1598},
#      {'name': 'Scavenger Grounds',
#       'sanitized': 'scavenger-grounds',
#       'sanitized_wo': 'scavenger-grounds',
#       'url': '/cards/scavenger-grounds',
#       'synergy': 0.04,
#       'inclusion': 148,
#       'label': '9% of 1598 decks\n+4% synergy',
#       'num_decks': 148,
#       'potential_decks': 1598},
#      {'name': 'Ancient Tomb',
#       'sanitized': 'ancient-tomb',
#       'sanitized_wo': 'ancient-tomb',
#       'url': '/cards/ancient-tomb',
#       'synergy': -0.02,
#       'inclusion': 117,
#       'label': '7% of 1598 decks\n-2% synergy',
#       'num_decks': 117,
#       'potential_decks': 1598},
#      {'name': 'Buried Ruin',
#       'sanitized': 'buried-ruin',
#       'sanitized_wo': 'buried-ruin',
#       'url': '/cards/buried-ruin',
#       'synergy': 0.05,
#       'inclusion': 115,
#       'label': '7% of 1598 decks\n+5% synergy',
#       'num_decks': 115,
#       'potential_decks': 1598},
#      {'name': "Urza's Saga",
#       'sanitized': 'urzas-saga',
#       'sanitized_wo': 'urzas-saga',
#       'url': '/cards/urzas-saga',
#       'synergy': 0.03,
#       'inclusion': 109,
#       'label': '7% of 1597 decks\n+3% synergy',
#       'num_decks': 109,
#       'potential_decks': 1597},
#      {'name': 'War Room',
#       'sanitized': 'war-room',
#       'sanitized_wo': 'war-room',
#       'url': '/cards/war-room',
#       'synergy': 0.02,
#       'inclusion': 97,
#       'label': '6% of 1598 decks\n+2% synergy',
#       'num_decks': 97,
#       'potential_decks': 1598},
#      {'name': 'Raging Ravine',
#       'sanitized': 'raging-ravine',
#       'sanitized_wo': 'raging-ravine',
#       'url': '/cards/raging-ravine',
#       'synergy': -0.05,
#       'inclusion': 97,
#       'label': '6% of 1598 decks\n-5% synergy',
#       'num_decks': 97,
#       'potential_decks': 1598}],
#     'header': 'Utility Lands',
#     'tag': 'utilitylands'},
#    {'cardviews': [{'name': 'Sol Ring',
#       'sanitized': 'sol-ring',
#       'sanitized_wo': 'sol-ring',
#       'url': '/cards/sol-ring',
#       'synergy': 0.04,
#       'inclusion': 1321,
#       'label': '83% of 1598 decks\n+4% synergy',
#       'num_decks': 1321,
#       'potential_decks': 1598},
#      {'name': 'Arcane Signet',
#       'sanitized': 'arcane-signet',
#       'sanitized_wo': 'arcane-signet',
#       'url': '/cards/arcane-signet',
#       'synergy': 0.08,
#       'inclusion': 1043,
#       'label': '65% of 1598 decks\n+8% synergy',
#       'num_decks': 1043,
#       'potential_decks': 1598},
#      {'name': 'Gruul Signet',
#       'sanitized': 'gruul-signet',
#       'sanitized_wo': 'gruul-signet',
#       'url': '/cards/gruul-signet',
#       'synergy': 0.02,
#       'inclusion': 471,
#       'label': '29% of 1598 decks\n+2% synergy',
#       'num_decks': 471,
#       'potential_decks': 1598},
#      {'name': 'Thought Vessel',
#       'sanitized': 'thought-vessel',
#       'sanitized_wo': 'thought-vessel',
#       'url': '/cards/thought-vessel',
#       'synergy': 0.12,
#       'inclusion': 289,
#       'label': '18% of 1598 decks\n+12% synergy',
#       'num_decks': 289,
#       'potential_decks': 1598},
#      {'name': 'Talisman of Impulse',
#       'sanitized': 'talisman-of-impulse',
#       'sanitized_wo': 'talisman-of-impulse',
#       'url': '/cards/talisman-of-impulse',
#       'synergy': 0.01,
#       'inclusion': 225,
#       'label': '14% of 1598 decks\n+1% synergy',
#       'num_decks': 225,
#       'potential_decks': 1598},
#      {'name': 'Mind Stone',
#       'sanitized': 'mind-stone',
#       'sanitized_wo': 'mind-stone',
#       'url': '/cards/mind-stone',
#       'synergy': 0.02,
#       'inclusion': 113,
#       'label': '7% of 1598 decks\n+2% synergy',
#       'num_decks': 113,
#       'potential_decks': 1598},
#      {'name': 'Decanter of Endless Water',
#       'sanitized': 'decanter-of-endless-water',
#       'sanitized_wo': 'decanter-of-endless-water',
#       'url': '/cards/decanter-of-endless-water',
#       'synergy': 0.04,
#       'inclusion': 99,
#       'label': '7% of 1494 decks\n+4% synergy',
#       'num_decks': 99,
#       'potential_decks': 1494},
#      {'name': "Commander's Sphere",
#       'sanitized': 'commanders-sphere',
#       'sanitized_wo': 'commanders-sphere',
#       'url': '/cards/commanders-sphere',
#       'synergy': -0.04,
#       'inclusion': 102,
#       'label': '6% of 1598 decks\n-4% synergy',
#       'num_decks': 102,
#       'potential_decks': 1598}],
#     'header': 'Mana Artifacts',
#     'tag': 'manaartifacts'},
#    {'cardviews': [{'name': 'Command Tower',
#       'sanitized': 'command-tower',
#       'sanitized_wo': 'command-tower',
#       'url': '/cards/command-tower',
#       'synergy': 0.06,
#       'inclusion': 1405,
#       'label': '88% of 1598 decks\n+6% synergy',
#       'num_decks': 1405,
#       'potential_decks': 1598},
#      {'name': 'Cinder Glade',
#       'sanitized': 'cinder-glade',
#       'sanitized_wo': 'cinder-glade',
#       'url': '/cards/cinder-glade',
#       'synergy': 0.08,
#       'inclusion': 1219,
#       'label': '76% of 1598 decks\n+8% synergy',
#       'num_decks': 1219,
#       'potential_decks': 1598},
#      {'name': 'Rockfall Vale',
#       'sanitized': 'rockfall-vale',
#       'sanitized_wo': 'rockfall-vale',
#       'url': '/cards/rockfall-vale',
#       'synergy': 0.13,
#       'inclusion': 942,
#       'label': '59% of 1597 decks\n+13% synergy',
#       'num_decks': 942,
#       'potential_decks': 1597},
#      {'name': 'Game Trail',
#       'sanitized': 'game-trail',
#       'sanitized_wo': 'game-trail',
#       'url': '/cards/game-trail',
#       'synergy': 0.06,
#       'inclusion': 789,
#       'label': '49% of 1598 decks\n+6% synergy',
#       'num_decks': 789,
#       'potential_decks': 1598},
#      {'name': 'Rootbound Crag',
#       'sanitized': 'rootbound-crag',
#       'sanitized_wo': 'rootbound-crag',
#       'url': '/cards/rootbound-crag',
#       'synergy': 0.05,
#       'inclusion': 781,
#       'label': '49% of 1598 decks\n+5% synergy',
#       'num_decks': 781,
#       'potential_decks': 1598},
#      {'name': 'Spire Garden',
#       'sanitized': 'spire-garden',
#       'sanitized_wo': 'spire-garden',
#       'url': '/cards/spire-garden',
#       'synergy': 0.11,
#       'inclusion': 769,
#       'label': '48% of 1598 decks\n+11% synergy',
#       'num_decks': 769,
#       'potential_decks': 1598},
#      {'name': 'Karplusan Forest',
#       'sanitized': 'karplusan-forest',
#       'sanitized_wo': 'karplusan-forest',
#       'url': '/cards/karplusan-forest',
#       'synergy': 0.14,
#       'inclusion': 731,
#       'label': '46% of 1598 decks\n+14% synergy',
#       'num_decks': 731,
#       'potential_decks': 1598},
#      {'name': 'Stomping Ground',
#       'sanitized': 'stomping-ground',
#       'sanitized_wo': 'stomping-ground',
#       'url': '/cards/stomping-ground',
#       'synergy': -0.01,
#       'inclusion': 724,
#       'label': '45% of 1598 decks\n-1% synergy',
#       'num_decks': 724,
#       'potential_decks': 1598},
#      {'name': 'Gruul Turf',
#       'sanitized': 'gruul-turf',
#       'sanitized_wo': 'gruul-turf',
#       'url': '/cards/gruul-turf',
#       'synergy': 0.01,
#       'inclusion': 661,
#       'label': '41% of 1598 decks\n+1% synergy',
#       'num_decks': 661,
#       'potential_decks': 1598},
#      {'name': 'Mossfire Valley',
#       'sanitized': 'mossfire-valley',
#       'sanitized_wo': 'mossfire-valley',
#       'url': '/cards/mossfire-valley',
#       'synergy': 0.07,
#       'inclusion': 569,
#       'label': '36% of 1598 decks\n+7% synergy',
#       'num_decks': 569,
#       'potential_decks': 1598},
#      {'name': 'Temple of Abandon',
#       'sanitized': 'temple-of-abandon',
#       'sanitized_wo': 'temple-of-abandon',
#       'url': '/cards/temple-of-abandon',
#       'synergy': -0.03,
#       'inclusion': 492,
#       'label': '31% of 1598 decks\n-3% synergy',
#       'num_decks': 492,
#       'potential_decks': 1598},
#      {'name': 'Cragcrown Pathway',
#       'sanitized': 'cragcrown-pathway',
#       'sanitized_wo': 'cragcrown-pathway',
#       'url': '/cards/cragcrown-pathway',
#       'cards': [{'name': 'Cragcrown Pathway', 'url': 'cragcrown-pathway'},
#        {'name': 'Timbercrown Pathway', 'url': 'cragcrown-pathway'}],
#       'synergy': -0.02,
#       'inclusion': 397,
#       'label': '25% of 1598 decks\n-2% synergy',
#       'num_decks': 397,
#       'potential_decks': 1598},
#      {'name': 'Exotic Orchard',
#       'sanitized': 'exotic-orchard',
#       'sanitized_wo': 'exotic-orchard',
#       'url': '/cards/exotic-orchard',
#       'synergy': 0.03,
#       'inclusion': 386,
#       'label': '24% of 1598 decks\n+3% synergy',
#       'num_decks': 386,
#       'potential_decks': 1598},
#      {'name': 'Wooded Ridgeline',
#       'sanitized': 'wooded-ridgeline',
#       'sanitized_wo': 'wooded-ridgeline',
#       'url': '/cards/wooded-ridgeline',
#       'synergy': 0.03,
#       'inclusion': 279,
#       'label': '21% of 1334 decks\n+3% synergy',
#       'num_decks': 279,
#       'potential_decks': 1334},
#      {'name': 'Wooded Foothills',
#       'sanitized': 'wooded-foothills',
#       'sanitized_wo': 'wooded-foothills',
#       'url': '/cards/wooded-foothills',
#       'synergy': -0.05,
#       'inclusion': 312,
#       'label': '20% of 1598 decks\n-5% synergy',
#       'num_decks': 312,
#       'potential_decks': 1598},
#      {'name': 'Fire-Lit Thicket',
#       'sanitized': 'fire-lit-thicket',
#       'sanitized_wo': 'fire-lit-thicket',
#       'url': '/cards/fire-lit-thicket',
#       'synergy': 0.01,
#       'inclusion': 282,
#       'label': '18% of 1598 decks\n+1% synergy',
#       'num_decks': 282,
#       'potential_decks': 1598},
#      {'name': 'Sheltered Thicket',
#       'sanitized': 'sheltered-thicket',
#       'sanitized_wo': 'sheltered-thicket',
#       'url': '/cards/sheltered-thicket',
#       'synergy': 0.01,
#       'inclusion': 263,
#       'label': '16% of 1598 decks\n+1% synergy',
#       'num_decks': 263,
#       'potential_decks': 1598},
#      {'name': 'Plaza of Heroes',
#       'sanitized': 'plaza-of-heroes',
#       'sanitized_wo': 'plaza-of-heroes',
#       'url': '/cards/plaza-of-heroes',
#       'synergy': 0.13,
#       'inclusion': 219,
#       'label': '16% of 1386 decks\n+13% synergy',
#       'num_decks': 219,
#       'potential_decks': 1386},
#      {'name': 'Myriad Landscape',
#       'sanitized': 'myriad-landscape',
#       'sanitized_wo': 'myriad-landscape',
#       'url': '/cards/myriad-landscape',
#       'synergy': -0.08,
#       'inclusion': 244,
#       'label': '15% of 1598 decks\n-8% synergy',
#       'num_decks': 244,
#       'potential_decks': 1598},
#      {'name': 'Highland Forest',
#       'sanitized': 'highland-forest',
#       'sanitized_wo': 'highland-forest',
#       'url': '/cards/highland-forest',
#       'synergy': -0.03,
#       'inclusion': 210,
#       'label': '13% of 1597 decks\n-3% synergy',
#       'num_decks': 210,
#       'potential_decks': 1597},
#      {'name': 'Evolving Wilds',
#       'sanitized': 'evolving-wilds',
#       'sanitized_wo': 'evolving-wilds',
#       'url': '/cards/evolving-wilds',
#       'synergy': -0.12,
#       'inclusion': 201,
#       'label': '13% of 1598 decks\n-12% synergy',
#       'num_decks': 201,
#       'potential_decks': 1598},
#      {'name': 'Taiga',
#       'sanitized': 'taiga',
#       'sanitized_wo': 'taiga',
#       'url': '/cards/taiga',
#       'synergy': -0.01,
#       'inclusion': 170,
#       'label': '11% of 1598 decks\n-1% synergy',
#       'num_decks': 170,
#       'potential_decks': 1598},
#      {'name': 'Terramorphic Expanse',
#       'sanitized': 'terramorphic-expanse',
#       'sanitized_wo': 'terramorphic-expanse',
#       'url': '/cards/terramorphic-expanse',
#       'synergy': -0.08,
#       'inclusion': 146,
#       'label': '9% of 1598 decks\n-8% synergy',
#       'num_decks': 146,
#       'potential_decks': 1598},
#      {'name': 'Grove of the Burnwillows',
#       'sanitized': 'grove-of-the-burnwillows',
#       'sanitized_wo': 'grove-of-the-burnwillows',
#       'url': '/cards/grove-of-the-burnwillows',
#       'synergy': -0.01,
#       'inclusion': 131,
#       'label': '8% of 1598 decks\n-1% synergy',
#       'num_decks': 131,
#       'potential_decks': 1598},
#      {'name': 'Fabled Passage',
#       'sanitized': 'fabled-passage',
#       'sanitized_wo': 'fabled-passage',
#       'url': '/cards/fabled-passage',
#       'synergy': -0.05,
#       'inclusion': 123,
#       'label': '8% of 1598 decks\n-5% synergy',
#       'num_decks': 123,
#       'potential_decks': 1598},
#      {'name': 'Rugged Highlands',
#       'sanitized': 'rugged-highlands',
#       'sanitized_wo': 'rugged-highlands',
#       'url': '/cards/rugged-highlands',
#       'synergy': -0.06,
#       'inclusion': 117,
#       'label': '7% of 1598 decks\n-6% synergy',
#       'num_decks': 117,
#       'potential_decks': 1598},
#      {'name': 'Copperline Gorge',
#       'sanitized': 'copperline-gorge',
#       'sanitized_wo': 'copperline-gorge',
#       'url': '/cards/copperline-gorge',
#       'synergy': -0.03,
#       'inclusion': 111,
#       'label': '7% of 1598 decks\n-3% synergy',
#       'num_decks': 111,
#       'potential_decks': 1598},
#      {'name': 'Opal Palace',
#       'sanitized': 'opal-palace',
#       'sanitized_wo': 'opal-palace',
#       'url': '/cards/opal-palace',
#       'synergy': -0.01,
#       'inclusion': 89,
#       'label': '6% of 1598 decks\n-1% synergy',
#       'num_decks': 89,
#       'potential_decks': 1598}],
#     'header': 'Lands',
#     'tag': 'lands'}],
#   'card': {'inclusion': 1598,
#    'num_decks': 1598,
#    'potential_decks': 3448854,
#    'aetherhub_uri': 'https://aetherhub.com/Meta/Format/Commander/?com=Stangg%2C%20Echo%20Warrior&updated=all-time',
#    'archidekt_uri': 'https://archidekt.com/search/decks?commanders=%22Stangg%2C%20Echo%20Warrior%22&formats=3',
#    'color_identity': ['R', 'G'],
#    'cmc': 4.0,
#    'deckstats_uri': 'https://deckstats.net/decks/search/?search_cards[]=Stangg%2C%20Echo%20Warrior&search_format=10',
#    'image_uris': [{'normal': 'https://cards.scryfall.io/normal/front/7/7/7722a9a1-2ff9-4a39-b56e-c7eef2ff9dcd.jpg?1673304989',
#      'art_crop': 'https://cards.scryfall.io/art_crop/front/7/7/7722a9a1-2ff9-4a39-b56e-c7eef2ff9dcd.jpg?1673304989'}],
#    'layout': 'normal',
#    'moxfield_uri': 'https://moxfield.com/decks/public?format=commander&filter=Stangg%2C%20Echo%20Warrior',
#    'mtggoldfish_uri': 'https://www.mtggoldfish.com/deck/custom?mformat=commander&commander=Stangg%2C+Echo+Warrior',
#    'name': 'Stangg, Echo Warrior',
#    'names': ['Stangg, Echo Warrior'],
#    'prices': {'cardhoarder': {'price': 0.15,
#      'url': 'https://www.cardhoarder.com/cards/103526?affiliate_id=edhrec'},
#     'cardkingdom': {'price': 0.49,
#      'url': 'https://www.cardkingdom.com/mtg/dominaria-united-commander-decks-variants/stangg-echo-warrior-foil-etched?partner=edhrec&utm_source=edhrec&utm_medium=affiliate&utm_campaign=edhrec'},
#     'cardmarket': {'price': 0.16,
#      'set': 'Commander: Dominaria United: Extras',
#      'url': 'https://www.cardmarket.com/en/Magic/Products/Search?searchString=Stangg%2C+Echo+Warrior'},
#     'face2face': {'price': 0.26,
#      'url': 'https://www.facetofacegames.com/search/?keyword=Stangg, Echo Warrior'},
#     'mtgstocks': {'price': 0.24,
#      'url': 'https://www.mtgstocks.com/prints/79449-stangg-echo-warrior'},
#     'tcgplayer': {'price': 0.2,
#      'url': 'https://www.tcgplayer.com/product/283148/magic-commander-dominaria-united-stangg-echo-warrior?partner=EDHREC&utm_campaign=affiliate&utm_medium=EDHREC&utm_source=EDHREC'}},
#    'primary_type': 'Creature',
#    'rarity': 'rare',
#    'salt': 0.0,
#    'sanitized': 'stangg-echo-warrior',
#    'sanitized_wo': 'stangg-echo-warrior',
#    'scryfall_uri': 'https://scryfall.com/card/dmc/42/stangg-echo-warrior?utm_source=api',
#    'spellbook_uri': 'https://commanderspellbook.com/search/?q=Stangg%2C%20Echo%20Warrior',
#    'type': 'Legendary Creature — Human Warrior',
#    'combos': True,
#    'is_commander': True,
#    'label': '1598 decks (0.046%)\nRank #600',
#    'legal_commander': True,
#    'url': None}},
#  'keywords': 'Stangg,Echo,Warrior,Commander',
#  'title': 'Stangg, Echo Warrior (Commander)'}

# %%
sorted(data['cardlist'], key=lambda card: card['num_decks'], reverse=True)
data['cardlist'][:5]
# Out:
# [{'name': "Etali's Favor",
#   'sanitized': 'etalis-favor',
#   'sanitized_wo': 'etalis-favor',
#   'url': '/cards/etalis-favor',
#   'synergy': 0.89,
#   'num_decks': 149,
#   'potential_decks': 157},
#  {'name': 'Command Tower',
#   'sanitized': 'command-tower',
#   'sanitized_wo': 'command-tower',
#   'url': '/cards/command-tower',
#   'synergy': 0.06,
#   'num_decks': 1405,
#   'potential_decks': 1598},
#  {'name': 'Chishiro, the Shattered Blade',
#   'sanitized': 'chishiro-the-shattered-blade',
#   'sanitized_wo': 'chishiro-the-shattered-blade',
#   'url': '/cards/chishiro-the-shattered-blade',
#   'synergy': 0.81,
#   'num_decks': 1347,
#   'potential_decks': 1596},
#  {'name': 'Sticky Fingers',
#   'sanitized': 'sticky-fingers',
#   'sanitized_wo': 'sticky-fingers',
#   'url': '/cards/sticky-fingers',
#   'synergy': 0.78,
#   'num_decks': 1331,
#   'potential_decks': 1588},
#  {'name': 'Sol Ring',
#   'sanitized': 'sol-ring',
#   'sanitized_wo': 'sol-ring',
#   'url': '/cards/sol-ring',
#   'synergy': 0.04,
#   'num_decks': 1321,
#   'potential_decks': 1598}]

# %%
flat = []
for cardlist in data['container']['json_dict']['cardlists']:
    for view in cardlist['cardviews']:
        flat.append(view)
flat[:5]
# Out:
# [{'name': "Etali's Favor",
#   'sanitized': 'etalis-favor',
#   'sanitized_wo': 'etalis-favor',
#   'url': '/cards/etalis-favor',
#   'synergy': 0.89,
#   'inclusion': 149,
#   'label': '95% of 157 decks\n+89% synergy',
#   'num_decks': 149,
#   'potential_decks': 157},
#  {'name': 'Diamond Pick-Axe',
#   'sanitized': 'diamond-pick-axe',
#   'sanitized_wo': 'diamond-pick-axe',
#   'url': '/cards/diamond-pick-axe',
#   'synergy': 0.15,
#   'inclusion': 38,
#   'label': '21% of 180 decks\n+15% synergy',
#   'num_decks': 38,
#   'potential_decks': 180},
#  {'name': "Tarrian's Soulcleaver",
#   'sanitized': 'tarrians-soulcleaver',
#   'sanitized_wo': 'tarrians-soulcleaver',
#   'url': '/cards/tarrians-soulcleaver',
#   'synergy': 0.08,
#   'inclusion': 29,
#   'label': '16% of 180 decks\n+8% synergy',
#   'num_decks': 29,
#   'potential_decks': 180},
#  {'name': 'Roaming Throne',
#   'sanitized': 'roaming-throne',
#   'sanitized_wo': 'roaming-throne',
#   'url': '/cards/roaming-throne',
#   'synergy': -0.18,
#   'inclusion': 11,
#   'label': '7% of 157 decks\n-18% synergy',
#   'num_decks': 11,
#   'potential_decks': 157},
#  {'name': 'Chishiro, the Shattered Blade',
#   'sanitized': 'chishiro-the-shattered-blade',
#   'sanitized_wo': 'chishiro-the-shattered-blade',
#   'url': '/cards/chishiro-the-shattered-blade',
#   'synergy': 0.81,
#   'inclusion': 1347,
#   'label': '84% of 1596 decks\n+81% synergy',
#   'num_decks': 1347,
#   'potential_decks': 1596}]

# %%
(data['container']['json_dict']['cardlists'][0]['cardviews'])
# Out:
# [{'name': "Etali's Favor",
#   'sanitized': 'etalis-favor',
#   'sanitized_wo': 'etalis-favor',
#   'url': '/cards/etalis-favor',
#   'synergy': 0.89,
#   'inclusion': 149,
#   'label': '95% of 157 decks\n+89% synergy',
#   'num_decks': 149,
#   'potential_decks': 157},
#  {'name': 'Diamond Pick-Axe',
#   'sanitized': 'diamond-pick-axe',
#   'sanitized_wo': 'diamond-pick-axe',
#   'url': '/cards/diamond-pick-axe',
#   'synergy': 0.15,
#   'inclusion': 38,
#   'label': '21% of 180 decks\n+15% synergy',
#   'num_decks': 38,
#   'potential_decks': 180},
#  {'name': "Tarrian's Soulcleaver",
#   'sanitized': 'tarrians-soulcleaver',
#   'sanitized_wo': 'tarrians-soulcleaver',
#   'url': '/cards/tarrians-soulcleaver',
#   'synergy': 0.08,
#   'inclusion': 29,
#   'label': '16% of 180 decks\n+8% synergy',
#   'num_decks': 29,
#   'potential_decks': 180},
#  {'name': 'Roaming Throne',
#   'sanitized': 'roaming-throne',
#   'sanitized_wo': 'roaming-throne',
#   'url': '/cards/roaming-throne',
#   'synergy': -0.18,
#   'inclusion': 11,
#   'label': '7% of 157 decks\n-18% synergy',
#   'num_decks': 11,
#   'potential_decks': 157}]

# %% [markdown]
# ## build synergy baseline decks

# %%
comm = commanders['valid'][0]
baseline = {}
for split in lists:
    baseline[split] = {}
    for comm in lists[split]:
        baseline[split][comm] = lists[split][comm][:99]

# %%
short = []
fail = []
for commander in commanders['test']+commanders['valid']:
    if commander in lists['valid']:
        if len(lists['valid'][commander]) < 99:
            short.append(commander)
    elif commander in lists['test']:
        if len(lists['test'][commander]) < 99:
            short.append(commander)
    else:
        fail.append(commander)
len(short),len(fail)
# Out:
# (8, 0)

# %%
set([len(deck) for deck in lists['valid'].values()])
# Out:
# {52,
#  70,
#  83,
#  96,
#  97,
#  99,
#  109,
#  144,
#  145,
#  152,
#  157,
#  161,
#  162,
#  164,
#  168,
#  170,
#  185,
#  218,
#  226,
#  229,
#  232,
#  233,
#  235,
#  239,
#  241,
#  244,
#  248,
#  249,
#  250,
#  253,
#  257,
#  258,
#  259,
#  261,
#  262,
#  263,
#  264,
#  266,
#  267,
#  269,
#  270,
#  272,
#  273,
#  275,
#  277,
#  279,
#  282,
#  283,
#  284,
#  285,
#  286,
#  287,
#  288,
#  290,
#  291,
#  292,
#  294,
#  298,
#  305,
#  307,
#  308,
#  310,
#  313,
#  314,
#  315,
#  317,
#  318,
#  319,
#  329,
#  359}

# %%
set([len(deck) for deck in baseline['valid'].values()])
# Out:
# {52, 70, 83, 96, 97, 99}

# %%
valid_list = lists['valid']
comm
# Out:
# 'Kiki-Jiki, Mirror Breaker'

# %%
cards = {card['sanitized']:{'total':card['num_decks'],comm:card['num_decks']}}

# %% [markdown]
# ## synergy metric

# %%
for split in ['non_commander']:
    counter = 0
    for card in tqdm(lists[split]):
        if isinstance(lists[split][card],dict):
            continue
        counter+= 1
        if counter%200 == 0:
            print(f'pausing after request # {counter}')
            time.sleep(5)
        json_data = request_json(card, False)
        if json_data:
            lists[split][card] = {'total':json_data['container']['json_dict']['card']['num_decks'],
                                  'cards':lists[split][card]}
# Out:
# 100%|██████████| 11794/11794 [00:00<00:00, 1182869.95it/s]

# %%
lists.keys()
# Out:
# dict_keys(['test', 'valid', 'non_commander'])

# %%
less_lists = {}
for split in lists:
    less_lists[split] = {}
    for commander in lists[split].keys():
        cards_less = {card['name']:card['num_decks'] for card in lists[split][commander]['cards']}
        less_lists[split][commander] = {'total':lists[split][commander]['total'],
                                        'cards':cards_less}

# %%
with open(os.path.join(DATA_PATH,'edhreclists.pkl'), 'wb') as f:
    pickle.dump(less_lists, f)

# %%
list(lists['non_commander'].values())[0]['cards']
# Out:
# [{'name': 'Arcane Signet',
#   'sanitized': 'arcane-signet',
#   'sanitized_wo': 'arcane-signet',
#   'url': '/cards/arcane-signet',
#   'synergy': 0.08,
#   'num_decks': 2261244,
#   'potential_decks': 2931462},
#  {'name': 'Command Tower',
#   'sanitized': 'command-tower',
#   'sanitized_wo': 'command-tower',
#   'url': '/cards/command-tower',
#   'synergy': 0.03,
#   'num_decks': 2211439,
#   'potential_decks': 2949653},
#  {'name': 'Exotic Orchard',
#   'sanitized': 'exotic-orchard',
#   'sanitized_wo': 'exotic-orchard',
#   'url': '/cards/exotic-orchard',
#   'synergy': 0.02,
#   'num_decks': 1049343,
#   'potential_decks': 2949920},
#  {'name': 'Swords to Plowshares',
#   'sanitized': 'swords-to-plowshares',
#   'sanitized_wo': 'swords-to-plowshares',
#   'url': '/cards/swords-to-plowshares',
#   'synergy': 0.38,
#   'num_decks': 893356,
#   'potential_decks': 1340893},
#  {'name': 'Swiftfoot Boots',
#   'sanitized': 'swiftfoot-boots',
#   'sanitized_wo': 'swiftfoot-boots',
#   'url': '/cards/swiftfoot-boots',
#   'synergy': 0.02,
#   'num_decks': 890489,
#   'potential_decks': 2949603},
#  {'name': 'Reliquary Tower',
#   'sanitized': 'reliquary-tower',
#   'sanitized_wo': 'reliquary-tower',
#   'url': '/cards/reliquary-tower',
#   'synergy': 0.02,
#   'num_decks': 868669,
#   'potential_decks': 2949920},
#  {'name': 'Lightning Greaves',
#   'sanitized': 'lightning-greaves',
#   'sanitized_wo': 'lightning-greaves',
#   'url': '/cards/lightning-greaves',
#   'synergy': 0.02,
#   'num_decks': 822869,
#   'potential_decks': 2950170},
#  {'name': 'Fellwar Stone',
#   'sanitized': 'fellwar-stone',
#   'sanitized_wo': 'fellwar-stone',
#   'url': '/cards/fellwar-stone',
#   'synergy': 0.02,
#   'num_decks': 679385,
#   'potential_decks': 2950922},
#  {'name': 'Counterspell',
#   'sanitized': 'counterspell',
#   'sanitized_wo': 'counterspell',
#   'url': '/cards/counterspell',
#   'synergy': 0.25,
#   'num_decks': 676083,
#   'potential_decks': 1465077},
#  {'name': 'Cultivate',
#   'sanitized': 'cultivate',
#   'sanitized_wo': 'cultivate',
#   'url': '/cards/cultivate',
#   'synergy': 0.29,
#   'num_decks': 660362,
#   'potential_decks': 1283608},
#  {'name': 'Mind Stone',
#   'sanitized': 'mind-stone',
#   'sanitized_wo': 'mind-stone',
#   'url': '/cards/mind-stone',
#   'synergy': 0.02,
#   'num_decks': 602112,
#   'potential_decks': 2950741},
#  {'name': 'Path to Exile',
#   'sanitized': 'path-to-exile',
#   'sanitized_wo': 'path-to-exile',
#   'url': '/cards/path-to-exile',
#   'synergy': 0.25,
#   'num_decks': 584956,
#   'potential_decks': 1340407},
#  {'name': 'Beast Within',
#   'sanitized': 'beast-within',
#   'sanitized_wo': 'beast-within',
#   'url': '/cards/beast-within',
#   'synergy': 0.25,
#   'num_decks': 574165,
#   'potential_decks': 1283594},
#  {'name': "Rogue's Passage",
#   'sanitized': 'rogues-passage',
#   'sanitized_wo': 'rogues-passage',
#   'url': '/cards/rogues-passage',
#   'synergy': 0.01,
#   'num_decks': 553312,
#   'potential_decks': 2949435},
#  {'name': "Commander's Sphere",
#   'sanitized': 'commanders-sphere',
#   'sanitized_wo': 'commanders-sphere',
#   'url': '/cards/commanders-sphere',
#   'synergy': 0.01,
#   'num_decks': 534521,
#   'potential_decks': 2948746},
#  {'name': 'Blasphemous Act',
#   'sanitized': 'blasphemous-act',
#   'sanitized_wo': 'blasphemous-act',
#   'url': '/cards/blasphemous-act',
#   'synergy': 0.2,
#   'num_decks': 511144,
#   'potential_decks': 1420348},
#  {'name': 'Chaos Warp',
#   'sanitized': 'chaos-warp',
#   'sanitized_wo': 'chaos-warp',
#   'url': '/cards/chaos-warp',
#   'synergy': 0.2,
#   'num_decks': 503026,
#   'potential_decks': 1420386},
#  {'name': 'Bojuka Bog',
#   'sanitized': 'bojuka-bog',
#   'sanitized_wo': 'bojuka-bog',
#   'url': '/cards/bojuka-bog',
#   'synergy': 0.17,
#   'num_decks': 502177,
#   'potential_decks': 1533066},
#  {'name': 'Thought Vessel',
#   'sanitized': 'thought-vessel',
#   'sanitized_wo': 'thought-vessel',
#   'url': '/cards/thought-vessel',
#   'synergy': 0.02,
#   'num_decks': 492816,
#   'potential_decks': 2948000},
#  {'name': 'Rampant Growth',
#   'sanitized': 'rampant-growth',
#   'sanitized_wo': 'rampant-growth',
#   'url': '/cards/rampant-growth',
#   'synergy': 0.21,
#   'num_decks': 481012,
#   'potential_decks': 1283990},
#  {'name': 'Cyclonic Rift',
#   'sanitized': 'cyclonic-rift',
#   'sanitized_wo': 'cyclonic-rift',
#   'url': '/cards/cyclonic-rift',
#   'synergy': 0.18,
#   'num_decks': 473565,
#   'potential_decks': 1464269},
#  {'name': 'Solemn Simulacrum',
#   'sanitized': 'solemn-simulacrum',
#   'sanitized_wo': 'solemn-simulacrum',
#   'url': '/cards/solemn-simulacrum',
#   'synergy': 0.01,
#   'num_decks': 472518,
#   'potential_decks': 2950170},
#  {'name': 'Rhystic Study',
#   'sanitized': 'rhystic-study',
#   'sanitized_wo': 'rhystic-study',
#   'url': '/cards/rhystic-study',
#   'synergy': 0.18,
#   'num_decks': 467372,
#   'potential_decks': 1464862},
#  {'name': "Kodama's Reach",
#   'sanitized': 'kodamas-reach',
#   'sanitized_wo': 'kodamas-reach',
#   'url': '/cards/kodamas-reach',
#   'synergy': 0.2,
#   'num_decks': 463560,
#   'potential_decks': 1283668},
#  {'name': 'Farseek',
#   'sanitized': 'farseek',
#   'sanitized_wo': 'farseek',
#   'url': '/cards/farseek',
#   'synergy': 0.2,
#   'num_decks': 457744,
#   'potential_decks': 1283659},
#  {'name': "Nature's Lore",
#   'sanitized': 'natures-lore',
#   'sanitized_wo': 'natures-lore',
#   'url': '/cards/natures-lore',
#   'synergy': 0.18,
#   'num_decks': 414475,
#   'potential_decks': 1284011},
#  {'name': 'Demonic Tutor',
#   'sanitized': 'demonic-tutor',
#   'sanitized_wo': 'demonic-tutor',
#   'url': '/cards/demonic-tutor',
#   'synergy': 0.14,
#   'num_decks': 411921,
#   'potential_decks': 1533726},
#  {'name': 'Skullclamp',
#   'sanitized': 'skullclamp',
#   'sanitized_wo': 'skullclamp',
#   'url': '/cards/skullclamp',
#   'synergy': 0.01,
#   'num_decks': 411353,
#   'potential_decks': 2950117},
#  {'name': 'Heroic Intervention',
#   'sanitized': 'heroic-intervention',
#   'sanitized_wo': 'heroic-intervention',
#   'url': '/cards/heroic-intervention',
#   'synergy': 0.18,
#   'num_decks': 397807,
#   'potential_decks': 1282115},
#  {'name': 'Mana Crypt',
#   'sanitized': 'mana-crypt',
#   'sanitized_wo': 'mana-crypt',
#   'url': '/cards/mana-crypt',
#   'synergy': 0.02,
#   'num_decks': 396345,
#   'potential_decks': 2950884},
#  {'name': 'Smothering Tithe',
#   'sanitized': 'smothering-tithe',
#   'sanitized_wo': 'smothering-tithe',
#   'url': '/cards/smothering-tithe',
#   'synergy': 0.17,
#   'num_decks': 385671,
#   'potential_decks': 1335905},
#  {'name': 'Brainstorm',
#   'sanitized': 'brainstorm',
#   'sanitized_wo': 'brainstorm',
#   'url': '/cards/brainstorm',
#   'synergy': 0.14,
#   'num_decks': 379816,
#   'potential_decks': 1464984},
#  {'name': 'Generous Gift',
#   'sanitized': 'generous-gift',
#   'sanitized_wo': 'generous-gift',
#   'url': '/cards/generous-gift',
#   'synergy': 0.16,
#   'num_decks': 370336,
#   'potential_decks': 1334272},
#  {'name': 'Ancient Tomb',
#   'sanitized': 'ancient-tomb',
#   'sanitized_wo': 'ancient-tomb',
#   'url': '/cards/ancient-tomb',
#   'synergy': 0.01,
#   'num_decks': 364929,
#   'potential_decks': 2950740},
#  {'name': 'Birds of Paradise',
#   'sanitized': 'birds-of-paradise',
#   'sanitized_wo': 'birds-of-paradise',
#   'url': '/cards/birds-of-paradise',
#   'synergy': 0.16,
#   'num_decks': 358256,
#   'potential_decks': 1284092},
#  {'name': 'Negate',
#   'sanitized': 'negate',
#   'sanitized_wo': 'negate',
#   'url': '/cards/negate',
#   'synergy': 0.13,
#   'num_decks': 355531,
#   'potential_decks': 1464491},
#  {'name': "Wayfarer's Bauble",
#   'sanitized': 'wayfarers-bauble',
#   'sanitized_wo': 'wayfarers-bauble',
#   'url': '/cards/wayfarers-bauble',
#   'synergy': 0.0,
#   'num_decks': 349932,
#   'potential_decks': 2950088},
#  {'name': 'Dark Ritual',
#   'sanitized': 'dark-ritual',
#   'sanitized_wo': 'dark-ritual',
#   'url': '/cards/dark-ritual',
#   'synergy': 0.12,
#   'num_decks': 349418,
#   'potential_decks': 1533726},
#  {'name': 'Watery Grave',
#   'sanitized': 'watery-grave',
#   'sanitized_wo': 'watery-grave',
#   'url': '/cards/watery-grave',
#   'synergy': 0.34,
#   'num_decks': 341083,
#   'potential_decks': 763718},
#  {'name': 'Three Visits',
#   'sanitized': 'three-visits',
#   'sanitized_wo': 'three-visits',
#   'url': '/cards/three-visits',
#   'synergy': 0.15,
#   'num_decks': 339925,
#   'potential_decks': 1283950},
#  {'name': 'Urborg, Tomb of Yawgmoth',
#   'sanitized': 'urborg-tomb-of-yawgmoth',
#   'sanitized_wo': 'urborg-tomb-of-yawgmoth',
#   'url': '/cards/urborg-tomb-of-yawgmoth',
#   'synergy': 0.01,
#   'num_decks': 335700,
#   'potential_decks': 2949982},
#  {'name': 'Vampiric Tutor',
#   'sanitized': 'vampiric-tutor',
#   'sanitized_wo': 'vampiric-tutor',
#   'url': '/cards/vampiric-tutor',
#   'synergy': 0.11,
#   'num_decks': 331242,
#   'potential_decks': 1533574},
#  {'name': 'Eternal Witness',
#   'sanitized': 'eternal-witness',
#   'sanitized_wo': 'eternal-witness',
#   'url': '/cards/eternal-witness',
#   'synergy': 0.14,
#   'num_decks': 318107,
#   'potential_decks': 1283673},
#  {'name': 'Esper Sentinel',
#   'sanitized': 'esper-sentinel',
#   'sanitized_wo': 'esper-sentinel',
#   'url': '/cards/esper-sentinel',
#   'synergy': 0.14,
#   'num_decks': 315615,
#   'potential_decks': 1300290},
#  {'name': 'Temple of the False God',
#   'sanitized': 'temple-of-the-false-god',
#   'sanitized_wo': 'temple-of-the-false-god',
#   'url': '/cards/temple-of-the-false-god',
#   'synergy': 0.01,
#   'num_decks': 314396,
#   'potential_decks': 2950492},
#  {'name': 'Llanowar Elves',
#   'sanitized': 'llanowar-elves',
#   'sanitized_wo': 'llanowar-elves',
#   'url': '/cards/llanowar-elves',
#   'synergy': 0.13,
#   'num_decks': 302278,
#   'potential_decks': 1284092},
#  {'name': 'Godless Shrine',
#   'sanitized': 'godless-shrine',
#   'sanitized_wo': 'godless-shrine',
#   'url': '/cards/godless-shrine',
#   'synergy': 0.35,
#   'num_decks': 300042,
#   'potential_decks': 675323},
#  {'name': 'Feed the Swarm',
#   'sanitized': 'feed-the-swarm',
#   'sanitized_wo': 'feed-the-swarm',
#   'url': '/cards/feed-the-swarm',
#   'synergy': 0.1,
#   'num_decks': 297934,
#   'potential_decks': 1511054},
#  {'name': "Teferi's Protection",
#   'sanitized': 'teferis-protection',
#   'sanitized_wo': 'teferis-protection',
#   'url': '/cards/teferis-protection',
#   'synergy': 0.13,
#   'num_decks': 297038,
#   'potential_decks': 1338321},
#  {'name': 'Mystic Remora',
#   'sanitized': 'mystic-remora',
#   'sanitized_wo': 'mystic-remora',
#   'url': '/cards/mystic-remora',
#   'synergy': 0.11,
#   'num_decks': 295441,
#   'potential_decks': 1464984},
#  {'name': 'Hallowed Fountain',
#   'sanitized': 'hallowed-fountain',
#   'sanitized_wo': 'hallowed-fountain',
#   'url': '/cards/hallowed-fountain',
#   'synergy': 0.36,
#   'num_decks': 294690,
#   'potential_decks': 652768},
#  {'name': 'Arcane Denial',
#   'sanitized': 'arcane-denial',
#   'sanitized_wo': 'arcane-denial',
#   'url': '/cards/arcane-denial',
#   'synergy': 0.11,
#   'num_decks': 294227,
#   'potential_decks': 1464962},
#  {'name': 'Chromatic Lantern',
#   'sanitized': 'chromatic-lantern',
#   'sanitized_wo': 'chromatic-lantern',
#   'url': '/cards/chromatic-lantern',
#   'synergy': 0.0,
#   'num_decks': 291509,
#   'potential_decks': 2949435},
#  {'name': 'Blood Crypt',
#   'sanitized': 'blood-crypt',
#   'sanitized_wo': 'blood-crypt',
#   'url': '/cards/blood-crypt',
#   'synergy': 0.33,
#   'num_decks': 286788,
#   'potential_decks': 679248},
#  {'name': 'Steam Vents',
#   'sanitized': 'steam-vents',
#   'sanitized_wo': 'steam-vents',
#   'url': '/cards/steam-vents',
#   'synergy': 0.34,
#   'num_decks': 284913,
#   'potential_decks': 661370},
#  {'name': 'Overgrown Tomb',
#   'sanitized': 'overgrown-tomb',
#   'sanitized_wo': 'overgrown-tomb',
#   'url': '/cards/overgrown-tomb',
#   'synergy': 0.37,
#   'num_decks': 282352,
#   'potential_decks': 603718},
#  {'name': "Jeska's Will",
#   'sanitized': 'jeskas-will',
#   'sanitized_wo': 'jeskas-will',
#   'url': '/cards/jeskas-will',
#   'synergy': 0.11,
#   'num_decks': 281273,
#   'potential_decks': 1396520},
#  {'name': 'Sakura-Tribe Elder',
#   'sanitized': 'sakura-tribe-elder',
#   'sanitized_wo': 'sakura-tribe-elder',
#   'url': '/cards/sakura-tribe-elder',
#   'synergy': 0.12,
#   'num_decks': 275689,
#   'potential_decks': 1283668},
#  {'name': 'Fierce Guardianship',
#   'sanitized': 'fierce-guardianship',
#   'sanitized_wo': 'fierce-guardianship',
#   'url': '/cards/fierce-guardianship',
#   'synergy': 0.1,
#   'num_decks': 273803,
#   'potential_decks': 1448313},
#  {'name': 'Stomping Ground',
#   'sanitized': 'stomping-ground',
#   'sanitized_wo': 'stomping-ground',
#   'url': '/cards/stomping-ground',
#   'synergy': 0.36,
#   'num_decks': 273195,
#   'potential_decks': 602332},
#  {'name': 'Breeding Pool',
#   'sanitized': 'breeding-pool',
#   'sanitized_wo': 'breeding-pool',
#   'url': '/cards/breeding-pool',
#   'synergy': 0.35,
#   'num_decks': 272530,
#   'potential_decks': 609792},
#  {'name': 'Dockside Extortionist',
#   'sanitized': 'dockside-extortionist',
#   'sanitized_wo': 'dockside-extortionist',
#   'url': '/cards/dockside-extortionist',
#   'synergy': 0.11,
#   'num_decks': 272130,
#   'potential_decks': 1412745},
#  {'name': 'Sunken Hollow',
#   'sanitized': 'sunken-hollow',
#   'sanitized_wo': 'sunken-hollow',
#   'url': '/cards/sunken-hollow',
#   'synergy': 0.27,
#   'num_decks': 271914,
#   'potential_decks': 763276},
#  {'name': 'Swan Song',
#   'sanitized': 'swan-song',
#   'sanitized_wo': 'swan-song',
#   'url': '/cards/swan-song',
#   'synergy': 0.1,
#   'num_decks': 270539,
#   'potential_decks': 1464182},
#  {'name': 'Enlightened Tutor',
#   'sanitized': 'enlightened-tutor',
#   'sanitized_wo': 'enlightened-tutor',
#   'url': '/cards/enlightened-tutor',
#   'synergy': 0.12,
#   'num_decks': 268606,
#   'potential_decks': 1340798},
#  {'name': 'Dimir Signet',
#   'sanitized': 'dimir-signet',
#   'sanitized_wo': 'dimir-signet',
#   'url': '/cards/dimir-signet',
#   'synergy': 0.27,
#   'num_decks': 267002,
#   'potential_decks': 763718},
#  {'name': 'Vandalblast',
#   'sanitized': 'vandalblast',
#   'sanitized_wo': 'vandalblast',
#   'url': '/cards/vandalblast',
#   'synergy': 0.1,
#   'num_decks': 266953,
#   'potential_decks': 1420288},
#  {'name': "An Offer You Can't Refuse",
#   'sanitized': 'an-offer-you-cant-refuse',
#   'sanitized_wo': 'an-offer-you-cant-refuse',
#   'url': '/cards/an-offer-you-cant-refuse',
#   'synergy': 0.12,
#   'num_decks': 265571,
#   'potential_decks': 1201360},
#  {'name': 'Faithless Looting',
#   'sanitized': 'faithless-looting',
#   'sanitized_wo': 'faithless-looting',
#   'url': '/cards/faithless-looting',
#   'synergy': 0.1,
#   'num_decks': 265085,
#   'potential_decks': 1420328},
#  {'name': 'Temple Garden',
#   'sanitized': 'temple-garden',
#   'sanitized_wo': 'temple-garden',
#   'url': '/cards/temple-garden',
#   'synergy': 0.35,
#   'num_decks': 262880,
#   'potential_decks': 590783},
#  {'name': 'Mystical Tutor',
#   'sanitized': 'mystical-tutor',
#   'sanitized_wo': 'mystical-tutor',
#   'url': '/cards/mystical-tutor',
#   'synergy': 0.1,
#   'num_decks': 261969,
#   'potential_decks': 1464939},
#  {'name': 'Yavimaya, Cradle of Growth',
#   'sanitized': 'yavimaya-cradle-of-growth',
#   'sanitized_wo': 'yavimaya-cradle-of-growth',
#   'url': '/cards/yavimaya-cradle-of-growth',
#   'synergy': -0.0,
#   'num_decks': 261692,
#   'potential_decks': 2853605},
#  {'name': 'Toxic Deluge',
#   'sanitized': 'toxic-deluge',
#   'sanitized_wo': 'toxic-deluge',
#   'url': '/cards/toxic-deluge',
#   'synergy': 0.09,
#   'num_decks': 258061,
#   'potential_decks': 1532683},
#  {'name': "Ashnod's Altar",
#   'sanitized': 'ashnods-altar',
#   'sanitized_wo': 'ashnods-altar',
#   'url': '/cards/ashnods-altar',
#   'synergy': 0.01,
#   'num_decks': 255712,
#   'potential_decks': 2950962},
#  {'name': 'Sacred Foundry',
#   'sanitized': 'sacred-foundry',
#   'sanitized_wo': 'sacred-foundry',
#   'url': '/cards/sacred-foundry',
#   'synergy': 0.32,
#   'num_decks': 254296,
#   'potential_decks': 632274},
#  {'name': 'Jeweled Lotus',
#   'sanitized': 'jeweled-lotus',
#   'sanitized_wo': 'jeweled-lotus',
#   'url': '/cards/jeweled-lotus',
#   'synergy': 0.01,
#   'num_decks': 254177,
#   'potential_decks': 2899809},
#  {'name': 'Mana Drain',
#   'sanitized': 'mana-drain',
#   'sanitized_wo': 'mana-drain',
#   'url': '/cards/mana-drain',
#   'synergy': 0.1,
#   'num_decks': 251904,
#   'potential_decks': 1465060},
#  {'name': 'Boseiju, Who Endures',
#   'sanitized': 'boseiju-who-endures',
#   'sanitized_wo': 'boseiju-who-endures',
#   'url': '/cards/boseiju-who-endures',
#   'synergy': 0.12,
#   'num_decks': 251480,
#   'potential_decks': 1148713},
#  {'name': 'Elvish Mystic',
#   'sanitized': 'elvish-mystic',
#   'sanitized_wo': 'elvish-mystic',
#   'url': '/cards/elvish-mystic',
#   'synergy': 0.11,
#   'num_decks': 247262,
#   'potential_decks': 1283341},
#  {'name': 'Talisman of Dominance',
#   'sanitized': 'talisman-of-dominance',
#   'sanitized_wo': 'talisman-of-dominance',
#   'url': '/cards/talisman-of-dominance',
#   'synergy': 0.24,
#   'num_decks': 243025,
#   'potential_decks': 763769},
#  {'name': 'Otawara, Soaring City',
#   'sanitized': 'otawara-soaring-city',
#   'sanitized_wo': 'otawara-soaring-city',
#   'url': '/cards/otawara-soaring-city',
#   'synergy': 0.1,
#   'num_decks': 239475,
#   'potential_decks': 1294299},
#  {'name': 'Deflecting Swat',
#   'sanitized': 'deflecting-swat',
#   'sanitized_wo': 'deflecting-swat',
#   'url': '/cards/deflecting-swat',
#   'synergy': 0.1,
#   'num_decks': 237567,
#   'potential_decks': 1406520},
#  {'name': 'Cinder Glade',
#   'sanitized': 'cinder-glade',
#   'sanitized_wo': 'cinder-glade',
#   'url': '/cards/cinder-glade',
#   'synergy': 0.31,
#   'num_decks': 237285,
#   'potential_decks': 601979},
#  {'name': 'Rakdos Signet',
#   'sanitized': 'rakdos-signet',
#   'sanitized_wo': 'rakdos-signet',
#   'url': '/cards/rakdos-signet',
#   'synergy': 0.27,
#   'num_decks': 234529,
#   'potential_decks': 679248},
#  {'name': "Urza's Saga",
#   'sanitized': 'urzas-saga',
#   'sanitized_wo': 'urzas-saga',
#   'url': '/cards/urzas-saga',
#   'synergy': 0.01,
#   'num_decks': 232420,
#   'potential_decks': 2838944},
#  {'name': 'Reanimate',
#   'sanitized': 'reanimate',
#   'sanitized_wo': 'reanimate',
#   'url': '/cards/reanimate',
#   'synergy': 0.08,
#   'num_decks': 232085,
#   'potential_decks': 1533564},
#  {'name': 'Phyrexian Arena',
#   'sanitized': 'phyrexian-arena',
#   'sanitized_wo': 'phyrexian-arena',
#   'url': '/cards/phyrexian-arena',
#   'synergy': 0.08,
#   'num_decks': 231318,
#   'potential_decks': 1533498},
#  {'name': 'Windfall',
#   'sanitized': 'windfall',
#   'sanitized_wo': 'windfall',
#   'url': '/cards/windfall',
#   'synergy': 0.09,
#   'num_decks': 230072,
#   'potential_decks': 1464908},
#  {'name': 'Ponder',
#   'sanitized': 'ponder',
#   'sanitized_wo': 'ponder',
#   'url': '/cards/ponder',
#   'synergy': 0.08,
#   'num_decks': 229300,
#   'potential_decks': 1464493},
#  {'name': 'Mana Vault',
#   'sanitized': 'mana-vault',
#   'sanitized_wo': 'mana-vault',
#   'url': '/cards/mana-vault',
#   'synergy': 0.01,
#   'num_decks': 228097,
#   'potential_decks': 2950988},
#  {'name': 'Prairie Stream',
#   'sanitized': 'prairie-stream',
#   'sanitized_wo': 'prairie-stream',
#   'url': '/cards/prairie-stream',
#   'synergy': 0.27,
#   'num_decks': 227200,
#   'potential_decks': 652370},
#  {'name': 'Chrome Mox',
#   'sanitized': 'chrome-mox',
#   'sanitized_wo': 'chrome-mox',
#   'url': '/cards/chrome-mox',
#   'synergy': 0.01,
#   'num_decks': 226703,
#   'potential_decks': 2950170},
#  {'name': 'Izzet Signet',
#   'sanitized': 'izzet-signet',
#   'sanitized_wo': 'izzet-signet',
#   'url': '/cards/izzet-signet',
#   'synergy': 0.27,
#   'num_decks': 221737,
#   'potential_decks': 661370},
#  {'name': 'Smoldering Marsh',
#   'sanitized': 'smoldering-marsh',
#   'sanitized_wo': 'smoldering-marsh',
#   'url': '/cards/smoldering-marsh',
#   'synergy': 0.25,
#   'num_decks': 217985,
#   'potential_decks': 678820},
#  {'name': 'Orzhov Signet',
#   'sanitized': 'orzhov-signet',
#   'sanitized_wo': 'orzhov-signet',
#   'url': '/cards/orzhov-signet',
#   'synergy': 0.25,
#   'num_decks': 215774,
#   'potential_decks': 675323},
#  {'name': 'Lotus Petal',
#   'sanitized': 'lotus-petal',
#   'sanitized_wo': 'lotus-petal',
#   'url': '/cards/lotus-petal',
#   'synergy': 0.01,
#   'num_decks': 215110,
#   'potential_decks': 2950740},
#  {'name': "Sensei's Divining Top",
#   'sanitized': 'senseis-divining-top',
#   'sanitized_wo': 'senseis-divining-top',
#   'url': '/cards/senseis-divining-top',
#   'synergy': 0.01,
#   'num_decks': 213431,
#   'potential_decks': 2950070},
#  {'name': 'Morphic Pool',
#   'sanitized': 'morphic-pool',
#   'sanitized_wo': 'morphic-pool',
#   'url': '/cards/morphic-pool',
#   'synergy': 0.21,
#   'num_decks': 209765,
#   'potential_decks': 761827},
#  {'name': 'Canopy Vista',
#   'sanitized': 'canopy-vista',
#   'sanitized_wo': 'canopy-vista',
#   'url': '/cards/canopy-vista',
#   'synergy': 0.28,
#   'num_decks': 209611,
#   'potential_decks': 590422},
#  {'name': 'Talisman of Creativity',
#   'sanitized': 'talisman-of-creativity',
#   'sanitized_wo': 'talisman-of-creativity',
#   'url': '/cards/talisman-of-creativity',
#   'synergy': 0.25,
#   'num_decks': 207836,
#   'potential_decks': 658104},
#  {'name': 'Worldly Tutor',
#   'sanitized': 'worldly-tutor',
#   'sanitized_wo': 'worldly-tutor',
#   'url': '/cards/worldly-tutor',
#   'synergy': 0.1,
#   'num_decks': 207812,
#   'potential_decks': 1283990},
#  {'name': 'Azorius Signet',
#   'sanitized': 'azorius-signet',
#   'sanitized_wo': 'azorius-signet',
#   'url': '/cards/azorius-signet',
#   'synergy': 0.25,
#   'num_decks': 207260,
#   'potential_decks': 652768},
#  {'name': 'Fyndhorn Elves',
#   'sanitized': 'fyndhorn-elves',
#   'sanitized_wo': 'fyndhorn-elves',
#   'url': '/cards/fyndhorn-elves',
#   'synergy': 0.09,
#   'num_decks': 207087,
#   'potential_decks': 1284011},
#  {'name': 'Mystic Sanctuary',
#   'sanitized': 'mystic-sanctuary',
#   'sanitized_wo': 'mystic-sanctuary',
#   'url': '/cards/mystic-sanctuary',
#   'synergy': 0.07,
#   'num_decks': 202636,
#   'potential_decks': 1455144},
#  {'name': 'Sylvan Library',
#   'sanitized': 'sylvan-library',
#   'sanitized_wo': 'sylvan-library',
#   'url': '/cards/sylvan-library',
#   'synergy': 0.09,
#   'num_decks': 201341,
#   'potential_decks': 1284078},
#  {'name': 'Dragonskull Summit',
#   'sanitized': 'dragonskull-summit',
#   'sanitized_wo': 'dragonskull-summit',
#   'url': '/cards/dragonskull-summit',
#   'synergy': 0.23,
#   'num_decks': 200819,
#   'potential_decks': 679230},
#  {'name': 'War Room',
#   'sanitized': 'war-room',
#   'sanitized_wo': 'war-room',
#   'url': '/cards/war-room',
#   'synergy': 0.0,
#   'num_decks': 198438,
#   'potential_decks': 2899809},
#  {'name': 'Cabal Coffers',
#   'sanitized': 'cabal-coffers',
#   'sanitized_wo': 'cabal-coffers',
#   'url': '/cards/cabal-coffers',
#   'synergy': 0.07,
#   'num_decks': 196352,
#   'potential_decks': 1533488},
#  {'name': 'Training Center',
#   'sanitized': 'training-center',
#   'sanitized_wo': 'training-center',
#   'url': '/cards/training-center',
#   'synergy': 0.24,
#   'num_decks': 196323,
#   'potential_decks': 650486},
#  {'name': 'Blood Artist',
#   'sanitized': 'blood-artist',
#   'sanitized_wo': 'blood-artist',
#   'url': '/cards/blood-artist',
#   'synergy': 0.06,
#   'num_decks': 194724,
#   'potential_decks': 1532854},
#  {'name': 'Preordain',
#   'sanitized': 'preordain',
#   'sanitized_wo': 'preordain',
#   'url': '/cards/preordain',
#   'synergy': 0.07,
#   'num_decks': 194409,
#   'potential_decks': 1464472},
#  {'name': 'Return of the Wildspeaker',
#   'sanitized': 'return-of-the-wildspeaker',
#   'sanitized_wo': 'return-of-the-wildspeaker',
#   'url': '/cards/return-of-the-wildspeaker',
#   'synergy': 0.08,
#   'num_decks': 192119,
#   'potential_decks': 1275323},
#  {'name': "Herald's Horn",
#   'sanitized': 'heralds-horn',
#   'sanitized_wo': 'heralds-horn',
#   'url': '/cards/heralds-horn',
#   'synergy': 0.0,
#   'num_decks': 190882,
#   'potential_decks': 2945183},
#  {'name': 'Caves of Koilos',
#   'sanitized': 'caves-of-koilos',
#   'sanitized_wo': 'caves-of-koilos',
#   'url': '/cards/caves-of-koilos',
#   'synergy': 0.22,
#   'num_decks': 190802,
#   'potential_decks': 675462},
#  {'name': "Garruk's Uprising",
#   'sanitized': 'garruks-uprising',
#   'sanitized_wo': 'garruks-uprising',
#   'url': '/cards/garruks-uprising',
#   'synergy': 0.09,
#   'num_decks': 190248,
#   'potential_decks': 1266691},
#  {'name': 'Sulfur Falls',
#   'sanitized': 'sulfur-falls',
#   'sanitized_wo': 'sulfur-falls',
#   'url': '/cards/sulfur-falls',
#   'synergy': 0.23,
#   'num_decks': 189312,
#   'potential_decks': 661302},
#  {'name': 'Pongify',
#   'sanitized': 'pongify',
#   'sanitized_wo': 'pongify',
#   'url': '/cards/pongify',
#   'synergy': 0.07,
#   'num_decks': 188029,
#   'potential_decks': 1464500},
#  {'name': 'Luxury Suite',
#   'sanitized': 'luxury-suite',
#   'sanitized_wo': 'luxury-suite',
#   'url': '/cards/luxury-suite',
#   'synergy': 0.22,
#   'num_decks': 187127,
#   'potential_decks': 677430},
#  {'name': 'Vault of Champions',
#   'sanitized': 'vault-of-champions',
#   'sanitized_wo': 'vault-of-champions',
#   'url': '/cards/vault-of-champions',
#   'synergy': 0.22,
#   'num_decks': 184070,
#   'potential_decks': 663935},
#  {'name': 'Victimize',
#   'sanitized': 'victimize',
#   'sanitized_wo': 'victimize',
#   'url': '/cards/victimize',
#   'synergy': 0.06,
#   'num_decks': 183211,
#   'potential_decks': 1533549},
#  {'name': 'Boros Signet',
#   'sanitized': 'boros-signet',
#   'sanitized_wo': 'boros-signet',
#   'url': '/cards/boros-signet',
#   'synergy': 0.23,
#   'num_decks': 183172,
#   'potential_decks': 632274},
#  {'name': 'Nykthos, Shrine to Nyx',
#   'sanitized': 'nykthos-shrine-to-nyx',
#   'sanitized_wo': 'nykthos-shrine-to-nyx',
#   'url': '/cards/nykthos-shrine-to-nyx',
#   'synergy': 0.0,
#   'num_decks': 182605,
#   'potential_decks': 2949271},
#  {'name': 'Frantic Search',
#   'sanitized': 'frantic-search',
#   'sanitized_wo': 'frantic-search',
#   'url': '/cards/frantic-search',
#   'synergy': 0.07,
#   'num_decks': 182540,
#   'potential_decks': 1464898},
#  {'name': 'Boros Charm',
#   'sanitized': 'boros-charm',
#   'sanitized_wo': 'boros-charm',
#   'url': '/cards/boros-charm',
#   'synergy': 0.23,
#   'num_decks': 182307,
#   'potential_decks': 632179},
#  {'name': "Assassin's Trophy",
#   'sanitized': 'assassins-trophy',
#   'sanitized_wo': 'assassins-trophy',
#   'url': '/cards/assassins-trophy',
#   'synergy': 0.24,
#   'num_decks': 181411,
#   'potential_decks': 601799},
#  {'name': "Bolas's Citadel",
#   'sanitized': 'bolass-citadel',
#   'sanitized_wo': 'bolass-citadel',
#   'url': '/cards/bolass-citadel',
#   'synergy': 0.06,
#   'num_decks': 179492,
#   'potential_decks': 1527300},
#  {'name': 'Force of Will',
#   'sanitized': 'force-of-will',
#   'sanitized_wo': 'force-of-will',
#   'url': '/cards/force-of-will',
#   'synergy': 0.07,
#   'num_decks': 179019,
#   'potential_decks': 1464962},
#  {'name': 'Talisman of Indulgence',
#   'sanitized': 'talisman-of-indulgence',
#   'sanitized_wo': 'talisman-of-indulgence',
#   'url': '/cards/talisman-of-indulgence',
#   'synergy': 0.21,
#   'num_decks': 179007,
#   'potential_decks': 679305},
#  {'name': 'Sun Titan',
#   'sanitized': 'sun-titan',
#   'sanitized_wo': 'sun-titan',
#   'url': '/cards/sun-titan',
#   'synergy': 0.07,
#   'num_decks': 178949,
#   'potential_decks': 1340391},
#  {'name': 'Farewell',
#   'sanitized': 'farewell',
#   'sanitized_wo': 'farewell',
#   'url': '/cards/farewell',
#   'synergy': 0.08,
#   'num_decks': 178348,
#   'potential_decks': 1187591},
#  {'name': 'Shivan Reef',
#   'sanitized': 'shivan-reef',
#   'sanitized_wo': 'shivan-reef',
#   'url': '/cards/shivan-reef',
#   'synergy': 0.21,
#   'num_decks': 178274,
#   'potential_decks': 661493},
#  {'name': 'Buried Ruin',
#   'sanitized': 'buried-ruin',
#   'sanitized_wo': 'buried-ruin',
#   'url': '/cards/buried-ruin',
#   'synergy': 0.0,
#   'num_decks': 177979,
#   'potential_decks': 2949603},
#  {'name': 'Reclamation Sage',
#   'sanitized': 'reclamation-sage',
#   'sanitized_wo': 'reclamation-sage',
#   'url': '/cards/reclamation-sage',
#   'synergy': 0.07,
#   'num_decks': 177754,
#   'potential_decks': 1283179},
#  {'name': 'Sea of Clouds',
#   'sanitized': 'sea-of-clouds',
#   'sanitized_wo': 'sea-of-clouds',
#   'url': '/cards/sea-of-clouds',
#   'synergy': 0.22,
#   'num_decks': 176631,
#   'potential_decks': 651094},
#  {'name': 'Rejuvenating Springs',
#   'sanitized': 'rejuvenating-springs',
#   'sanitized_wo': 'rejuvenating-springs',
#   'url': '/cards/rejuvenating-springs',
#   'synergy': 0.24,
#   'num_decks': 176237,
#   'potential_decks': 597289},
#  {'name': 'Zulaport Cutthroat',
#   'sanitized': 'zulaport-cutthroat',
#   'sanitized_wo': 'zulaport-cutthroat',
#   'url': '/cards/zulaport-cutthroat',
#   'synergy': 0.06,
#   'num_decks': 176067,
#   'potential_decks': 1532162},
#  {'name': 'Takenuma, Abandoned Mire',
#   'sanitized': 'takenuma-abandoned-mire',
#   'sanitized_wo': 'takenuma-abandoned-mire',
#   'url': '/cards/takenuma-abandoned-mire',
#   'synergy': 0.06,
#   'num_decks': 175729,
#   'potential_decks': 1352876},
#  {'name': 'Ghostly Prison',
#   'sanitized': 'ghostly-prison',
#   'sanitized_wo': 'ghostly-prison',
#   'url': '/cards/ghostly-prison',
#   'synergy': 0.07,
#   'num_decks': 175701,
#   'potential_decks': 1340453},
#  {'name': 'Talisman of Hierarchy',
#   'sanitized': 'talisman-of-hierarchy',
#   'sanitized_wo': 'talisman-of-hierarchy',
#   'url': '/cards/talisman-of-hierarchy',
#   'synergy': 0.21,
#   'num_decks': 175647,
#   'potential_decks': 671912},
#  {'name': 'Austere Command',
#   'sanitized': 'austere-command',
#   'sanitized_wo': 'austere-command',
#   'url': '/cards/austere-command',
#   'synergy': 0.07,
#   'num_decks': 174917,
#   'potential_decks': 1340410},
#  {'name': 'Anguished Unmaking',
#   'sanitized': 'anguished-unmaking',
#   'sanitized_wo': 'anguished-unmaking',
#   'url': '/cards/anguished-unmaking',
#   'synergy': 0.2,
#   'num_decks': 174582,
#   'potential_decks': 674836},
#  {'name': 'Isolated Chapel',
#   'sanitized': 'isolated-chapel',
#   'sanitized_wo': 'isolated-chapel',
#   'url': '/cards/isolated-chapel',
#   'synergy': 0.2,
#   'num_decks': 174060,
#   'potential_decks': 675234},
#  {'name': 'Viscera Seer',
#   'sanitized': 'viscera-seer',
#   'sanitized_wo': 'viscera-seer',
#   'url': '/cards/viscera-seer',
#   'synergy': 0.06,
#   'num_decks': 172785,
#   'potential_decks': 1533056},
#  {'name': 'Propaganda',
#   'sanitized': 'propaganda',
#   'sanitized_wo': 'propaganda',
#   'url': '/cards/propaganda',
#   'synergy': 0.06,
#   'num_decks': 171308,
#   'potential_decks': 1464922},
#  {'name': "Nature's Claim",
#   'sanitized': 'natures-claim',
#   'sanitized_wo': 'natures-claim',
#   'url': '/cards/natures-claim',
#   'synergy': 0.07,
#   'num_decks': 170076,
#   'potential_decks': 1283616},
#  {'name': 'Spectator Seating',
#   'sanitized': 'spectator-seating',
#   'sanitized_wo': 'spectator-seating',
#   'url': '/cards/spectator-seating',
#   'synergy': 0.22,
#   'num_decks': 169211,
#   'potential_decks': 621082},
#  {'name': 'Beast Whisperer',
#   'sanitized': 'beast-whisperer',
#   'sanitized_wo': 'beast-whisperer',
#   'url': '/cards/beast-whisperer',
#   'synergy': 0.07,
#   'num_decks': 168606,
#   'potential_decks': 1279734},
#  {'name': 'Dauthi Voidwalker',
#   'sanitized': 'dauthi-voidwalker',
#   'sanitized_wo': 'dauthi-voidwalker',
#   'url': '/cards/dauthi-voidwalker',
#   'synergy': 0.06,
#   'num_decks': 167424,
#   'potential_decks': 1479323},
#  {'name': 'Undergrowth Stadium',
#   'sanitized': 'undergrowth-stadium',
#   'sanitized_wo': 'undergrowth-stadium',
#   'url': '/cards/undergrowth-stadium',
#   'synergy': 0.23,
#   'num_decks': 166926,
#   'potential_decks': 592238},
#  {'name': 'Thrill of Possibility',
#   'sanitized': 'thrill-of-possibility',
#   'sanitized_wo': 'thrill-of-possibility',
#   'url': '/cards/thrill-of-possibility',
#   'synergy': 0.06,
#   'num_decks': 165614,
#   'potential_decks': 1411777},
#  {'name': 'Abrade',
#   'sanitized': 'abrade',
#   'sanitized_wo': 'abrade',
#   'url': '/cards/abrade',
#   'synergy': 0.06,
#   'num_decks': 165077,
#   'potential_decks': 1418523},
#  {'name': 'Sign in Blood',
#   'sanitized': 'sign-in-blood',
#   'sanitized_wo': 'sign-in-blood',
#   'url': '/cards/sign-in-blood',
#   'synergy': 0.05,
#   'num_decks': 164676,
#   'potential_decks': 1533075},
#  {'name': 'Sword of the Animist',
#   'sanitized': 'sword-of-the-animist',
#   'sanitized_wo': 'sword-of-the-animist',
#   'url': '/cards/sword-of-the-animist',
#   'synergy': 0.0,
#   'num_decks': 163953,
#   'potential_decks': 2948352},
#  {'name': 'Animate Dead',
#   'sanitized': 'animate-dead',
#   'sanitized_wo': 'animate-dead',
#   'url': '/cards/animate-dead',
#   'synergy': 0.05,
#   'num_decks': 161217,
#   'potential_decks': 1533726},
#  {'name': 'Village Rites',
#   'sanitized': 'village-rites',
#   'sanitized_wo': 'village-rites',
#   'url': '/cards/village-rites',
#   'synergy': 0.05,
#   'num_decks': 160320,
#   'potential_decks': 1513527},
#  {'name': 'Thran Dynamo',
#   'sanitized': 'thran-dynamo',
#   'sanitized_wo': 'thran-dynamo',
#   'url': '/cards/thran-dynamo',
#   'synergy': 0.01,
#   'num_decks': 159428,
#   'potential_decks': 2950683},
#  {'name': 'Yavimaya Coast',
#   'sanitized': 'yavimaya-coast',
#   'sanitized_wo': 'yavimaya-coast',
#   'url': '/cards/yavimaya-coast',
#   'synergy': 0.21,
#   'num_decks': 159425,
#   'potential_decks': 609909},
#  {'name': 'Gamble',
#   'sanitized': 'gamble',
#   'sanitized_wo': 'gamble',
#   'url': '/cards/gamble',
#   'synergy': 0.06,
#   'num_decks': 158868,
#   'potential_decks': 1420807},
#  {'name': 'Deadly Rollick',
#   'sanitized': 'deadly-rollick',
#   'sanitized_wo': 'deadly-rollick',
#   'url': '/cards/deadly-rollick',
#   'synergy': 0.05,
#   'num_decks': 157186,
#   'potential_decks': 1516661},
#  {'name': 'Terminate',
#   'sanitized': 'terminate',
#   'sanitized_wo': 'terminate',
#   'url': '/cards/terminate',
#   'synergy': 0.18,
#   'num_decks': 157074,
#   'potential_decks': 679435},
#  {'name': 'Everflowing Chalice',
#   'sanitized': 'everflowing-chalice',
#   'sanitized_wo': 'everflowing-chalice',
#   'url': '/cards/everflowing-chalice',
#   'synergy': 0.0,
#   'num_decks': 157052,
#   'potential_decks': 2949898},
#  {'name': "Dovin's Veto",
#   'sanitized': 'dovins-veto',
#   'sanitized_wo': 'dovins-veto',
#   'url': '/cards/dovins-veto',
#   'synergy': 0.19,
#   'num_decks': 156481,
#   'potential_decks': 650145},
#  {'name': 'Command Beacon',
#   'sanitized': 'command-beacon',
#   'sanitized_wo': 'command-beacon',
#   'url': '/cards/command-beacon',
#   'synergy': 0.0,
#   'num_decks': 156475,
#   'potential_decks': 2948000},
#  {'name': 'Deadly Dispute',
#   'sanitized': 'deadly-dispute',
#   'sanitized_wo': 'deadly-dispute',
#   'url': '/cards/deadly-dispute',
#   'synergy': 0.05,
#   'num_decks': 156027,
#   'potential_decks': 1462992},
#  {'name': 'Reality Shift',
#   'sanitized': 'reality-shift',
#   'sanitized_wo': 'reality-shift',
#   'url': '/cards/reality-shift',
#   'synergy': 0.06,
#   'num_decks': 154781,
#   'potential_decks': 1463842},
#  {'name': 'Damnation',
#   'sanitized': 'damnation',
#   'sanitized_wo': 'damnation',
#   'url': '/cards/damnation',
#   'synergy': 0.05,
#   'num_decks': 153102,
#   'potential_decks': 1533130},
#  {'name': "Night's Whisper",
#   'sanitized': 'nights-whisper',
#   'sanitized_wo': 'nights-whisper',
#   'url': '/cards/nights-whisper',
#   'synergy': 0.05,
#   'num_decks': 152158,
#   'potential_decks': 1533202},
#  {'name': 'Rhythm of the Wild',
#   'sanitized': 'rhythm-of-the-wild',
#   'sanitized_wo': 'rhythm-of-the-wild',
#   'url': '/cards/rhythm-of-the-wild',
#   'synergy': 0.2,
#   'num_decks': 152109,
#   'potential_decks': 600322},
#  {'name': 'Mox Opal',
#   'sanitized': 'mox-opal',
#   'sanitized_wo': 'mox-opal',
#   'url': '/cards/mox-opal',
#   'synergy': 0.01,
#   'num_decks': 151106,
#   'potential_decks': 2949864},
#  {'name': 'Force of Negation',
#   'sanitized': 'force-of-negation',
#   'sanitized_wo': 'force-of-negation',
#   'url': '/cards/force-of-negation',
#   'synergy': 0.06,
#   'num_decks': 150202,
#   'potential_decks': 1457546},
#  {'name': "Rishkar's Expertise",
#   'sanitized': 'rishkars-expertise',
#   'sanitized_wo': 'rishkars-expertise',
#   'url': '/cards/rishkars-expertise',
#   'synergy': 0.06,
#   'num_decks': 148048,
#   'potential_decks': 1282115},
#  {'name': 'Wild Growth',
#   'sanitized': 'wild-growth',
#   'sanitized_wo': 'wild-growth',
#   'url': '/cards/wild-growth',
#   'synergy': 0.06,
#   'num_decks': 147106,
#   'potential_decks': 1284092},
#  {'name': 'Rapid Hybridization',
#   'sanitized': 'rapid-hybridization',
#   'sanitized_wo': 'rapid-hybridization',
#   'url': '/cards/rapid-hybridization',
#   'synergy': 0.05,
#   'num_decks': 146336,
#   'potential_decks': 1464231},
#  {'name': 'Diabolic Intent',
#   'sanitized': 'diabolic-intent',
#   'sanitized_wo': 'diabolic-intent',
#   'url': '/cards/diabolic-intent',
#   'synergy': 0.05,
#   'num_decks': 145931,
#   'potential_decks': 1533501},
#  {'name': 'Lightning Bolt',
#   'sanitized': 'lightning-bolt',
#   'sanitized_wo': 'lightning-bolt',
#   'url': '/cards/lightning-bolt',
#   'synergy': 0.05,
#   'num_decks': 145703,
#   'potential_decks': 1420981},
#  {'name': 'Talisman of Conviction',
#   'sanitized': 'talisman-of-conviction',
#   'sanitized_wo': 'talisman-of-conviction',
#   'url': '/cards/talisman-of-conviction',
#   'synergy': 0.19,
#   'num_decks': 145611,
#   'potential_decks': 629497},
#  {'name': 'Read the Bones',
#   'sanitized': 'read-the-bones',
#   'sanitized_wo': 'read-the-bones',
#   'url': '/cards/read-the-bones',
#   'synergy': 0.05,
#   'num_decks': 143320,
#   'potential_decks': 1532716},
#  {'name': 'Mosswort Bridge',
#   'sanitized': 'mosswort-bridge',
#   'sanitized_wo': 'mosswort-bridge',
#   'url': '/cards/mosswort-bridge',
#   'synergy': 0.06,
#   'num_decks': 141003,
#   'potential_decks': 1283629},
#  {'name': 'Krosan Grip',
#   'sanitized': 'krosan-grip',
#   'sanitized_wo': 'krosan-grip',
#   'url': '/cards/krosan-grip',
#   'synergy': 0.06,
#   'num_decks': 140804,
#   'potential_decks': 1283653},
#  {'name': 'Shamanic Revelation',
#   'sanitized': 'shamanic-revelation',
#   'sanitized_wo': 'shamanic-revelation',
#   'url': '/cards/shamanic-revelation',
#   'synergy': 0.06,
#   'num_decks': 140632,
#   'potential_decks': 1283045},
#  {'name': 'The Great Henge',
#   'sanitized': 'the-great-henge',
#   'sanitized_wo': 'the-great-henge',
#   'url': '/cards/the-great-henge',
#   'synergy': 0.06,
#   'num_decks': 138450,
#   'potential_decks': 1275323},
#  {'name': 'Eiganjo, Seat of the Empire',
#   'sanitized': 'eiganjo-seat-of-the-empire',
#   'sanitized_wo': 'eiganjo-seat-of-the-empire',
#   'url': '/cards/eiganjo-seat-of-the-empire',
#   'synergy': 0.06,
#   'num_decks': 136866,
#   'potential_decks': 1200670},
#  {'name': 'Talisman of Progress',
#   'sanitized': 'talisman-of-progress',
#   'sanitized_wo': 'talisman-of-progress',
#   'url': '/cards/talisman-of-progress',
#   'synergy': 0.17,
#   'num_decks': 136253,
#   'potential_decks': 652814},
#  {'name': 'Phyrexian Tower',
#   'sanitized': 'phyrexian-tower',
#   'sanitized_wo': 'phyrexian-tower',
#   'url': '/cards/phyrexian-tower',
#   'synergy': 0.05,
#   'num_decks': 136055,
#   'potential_decks': 1533549},
#  {'name': 'Black Market Connections',
#   'sanitized': 'black-market-connections',
#   'sanitized_wo': 'black-market-connections',
#   'url': '/cards/black-market-connections',
#   'synergy': 0.06,
#   'num_decks': 135259,
#   'potential_decks': 1132464},
#  {'name': 'Skyshroud Claim',
#   'sanitized': 'skyshroud-claim',
#   'sanitized_wo': 'skyshroud-claim',
#   'url': '/cards/skyshroud-claim',
#   'synergy': 0.06,
#   'num_decks': 134434,
#   'potential_decks': 1283924},
#  {'name': 'Bala Ged Recovery',
#   'sanitized': 'bala-ged-recovery',
#   'sanitized_wo': 'bala-ged-recovery',
#   'url': '/cards/bala-ged-recovery',
#   'cards': [{'name': 'Bala Ged Recovery', 'url': 'bala-ged-recovery'},
#    {'name': 'Bala Ged Sanctuary', 'url': 'bala-ged-recovery'}],
#   'synergy': 0.06,
#   'num_decks': 134046,
#   'potential_decks': 1265095},
#  {'name': "Akroma's Will",
#   'sanitized': 'akromas-will',
#   'sanitized_wo': 'akromas-will',
#   'url': '/cards/akromas-will',
#   'synergy': 0.06,
#   'num_decks': 133406,
#   'potential_decks': 1318747},
#  {'name': 'Damn',
#   'sanitized': 'damn',
#   'sanitized_wo': 'damn',
#   'url': '/cards/damn',
#   'synergy': 0.16,
#   'num_decks': 132995,
#   'potential_decks': 651051},
#  {'name': 'Growth Spiral',
#   'sanitized': 'growth-spiral',
#   'sanitized_wo': 'growth-spiral',
#   'url': '/cards/growth-spiral',
#   'synergy': 0.17,
#   'num_decks': 132821,
#   'potential_decks': 607550},
#  {'name': 'Anointed Procession',
#   'sanitized': 'anointed-procession',
#   'sanitized_wo': 'anointed-procession',
#   'url': '/cards/anointed-procession',
#   'synergy': 0.06,
#   'num_decks': 132259,
#   'potential_decks': 1338690},
#  {'name': 'Harrow',
#   'sanitized': 'harrow',
#   'sanitized_wo': 'harrow',
#   'url': '/cards/harrow',
#   'synergy': 0.05,
#   'num_decks': 131244,
#   'potential_decks': 1283976},
#  {'name': 'Crop Rotation',
#   'sanitized': 'crop-rotation',
#   'sanitized_wo': 'crop-rotation',
#   'url': '/cards/crop-rotation',
#   'synergy': 0.05,
#   'num_decks': 130611,
#   'potential_decks': 1283955},
#  {'name': 'Despark',
#   'sanitized': 'despark',
#   'sanitized_wo': 'despark',
#   'url': '/cards/despark',
#   'synergy': 0.15,
#   'num_decks': 129903,
#   'potential_decks': 672422},
#  {'name': 'Harmonize',
#   'sanitized': 'harmonize',
#   'sanitized_wo': 'harmonize',
#   'url': '/cards/harmonize',
#   'synergy': 0.05,
#   'num_decks': 129767,
#   'potential_decks': 1283640},
#  {'name': 'Decanter of Endless Water',
#   'sanitized': 'decanter-of-endless-water',
#   'sanitized_wo': 'decanter-of-endless-water',
#   'url': '/cards/decanter-of-endless-water',
#   'synergy': 0.0,
#   'num_decks': 127343,
#   'potential_decks': 2170015},
#  {'name': 'Impact Tremors',
#   'sanitized': 'impact-tremors',
#   'sanitized_wo': 'impact-tremors',
#   'url': '/cards/impact-tremors',
#   'synergy': 0.05,
#   'num_decks': 122853,
#   'potential_decks': 1419844},
#  {'name': 'Finale of Devastation',
#   'sanitized': 'finale-of-devastation',
#   'sanitized_wo': 'finale-of-devastation',
#   'url': '/cards/finale-of-devastation',
#   'synergy': 0.05,
#   'num_decks': 118628,
#   'potential_decks': 1278440},
#  {'name': 'Doubling Season',
#   'sanitized': 'doubling-season',
#   'sanitized_wo': 'doubling-season',
#   'url': '/cards/doubling-season',
#   'synergy': 0.05,
#   'num_decks': 117914,
#   'potential_decks': 1283659},
#  {'name': 'Diabolic Tutor',
#   'sanitized': 'diabolic-tutor',
#   'sanitized_wo': 'diabolic-tutor',
#   'url': '/cards/diabolic-tutor',
#   'synergy': 0.04,
#   'num_decks': 115508,
#   'potential_decks': 1533493},
#  {'name': 'Guardian Project',
#   'sanitized': 'guardian-project',
#   'sanitized_wo': 'guardian-project',
#   'url': '/cards/guardian-project',
#   'synergy': 0.05,
#   'num_decks': 114105,
#   'potential_decks': 1279114},
#  {'name': 'Bedevil',
#   'sanitized': 'bedevil',
#   'sanitized_wo': 'bedevil',
#   'url': '/cards/bedevil',
#   'synergy': 0.13,
#   'num_decks': 113720,
#   'potential_decks': 676689},
#  {'name': 'Mana Geyser',
#   'sanitized': 'mana-geyser',
#   'sanitized_wo': 'mana-geyser',
#   'url': '/cards/mana-geyser',
#   'synergy': 0.04,
#   'num_decks': 113183,
#   'potential_decks': 1420541},
#  {'name': 'The One Ring',
#   'sanitized': 'the-one-ring',
#   'sanitized_wo': 'the-one-ring',
#   'url': '/cards/the-one-ring',
#   'synergy': 0.01,
#   'num_decks': 112783,
#   'potential_decks': 1231274},
#  {'name': 'Crumbling Necropolis',
#   'sanitized': 'crumbling-necropolis',
#   'sanitized_wo': 'crumbling-necropolis',
#   'url': '/cards/crumbling-necropolis',
#   'synergy': 0.28,
#   'num_decks': 112227,
#   'potential_decks': 350269},
#  {'name': 'Simic Signet',
#   'sanitized': 'simic-signet',
#   'sanitized_wo': 'simic-signet',
#   'url': '/cards/simic-signet',
#   'synergy': 0.15,
#   'num_decks': 111867,
#   'potential_decks': 609792},
#  {'name': 'Seat of the Synod',
#   'sanitized': 'seat-of-the-synod',
#   'sanitized_wo': 'seat-of-the-synod',
#   'url': '/cards/seat-of-the-synod',
#   'synergy': 0.04,
#   'num_decks': 109104,
#   'potential_decks': 1464602},
#  {'name': 'Wrath of God',
#   'sanitized': 'wrath-of-god',
#   'sanitized_wo': 'wrath-of-god',
#   'url': '/cards/wrath-of-god',
#   'synergy': 0.05,
#   'num_decks': 109014,
#   'potential_decks': 1340893},
#  {'name': 'Gitaxian Probe',
#   'sanitized': 'gitaxian-probe',
#   'sanitized_wo': 'gitaxian-probe',
#   'url': '/cards/gitaxian-probe',
#   'synergy': 0.04,
#   'num_decks': 108799,
#   'potential_decks': 1464453},
#  {'name': 'Arcane Sanctum',
#   'sanitized': 'arcane-sanctum',
#   'sanitized_wo': 'arcane-sanctum',
#   'url': '/cards/arcane-sanctum',
#   'synergy': 0.26,
#   'num_decks': 108634,
#   'potential_decks': 368786},
#  {'name': 'Baleful Strix',
#   'sanitized': 'baleful-strix',
#   'sanitized_wo': 'baleful-strix',
#   'url': '/cards/baleful-strix',
#   'synergy': 0.11,
#   'num_decks': 107531,
#   'potential_decks': 763598},
#  {'name': 'Narset, Parter of Veils',
#   'sanitized': 'narset-parter-of-veils',
#   'sanitized_wo': 'narset-parter-of-veils',
#   'url': '/cards/narset-parter-of-veils',
#   'synergy': 0.04,
#   'num_decks': 106733,
#   'potential_decks': 1458627},
#  {'name': "Avacyn's Pilgrim",
#   'sanitized': 'avacyns-pilgrim',
#   'sanitized_wo': 'avacyns-pilgrim',
#   'url': '/cards/avacyns-pilgrim',
#   'synergy': 0.14,
#   'num_decks': 106098,
#   'potential_decks': 590687},
#  {'name': 'Explore',
#   'sanitized': 'explore',
#   'sanitized_wo': 'explore',
#   'url': '/cards/explore',
#   'synergy': 0.04,
#   'num_decks': 106093,
#   'potential_decks': 1283616},
#  {'name': 'Putrefy',
#   'sanitized': 'putrefy',
#   'sanitized_wo': 'putrefy',
#   'url': '/cards/putrefy',
#   'synergy': 0.14,
#   'num_decks': 105473,
#   'potential_decks': 603718},
#  {'name': 'Underworld Breach',
#   'sanitized': 'underworld-breach',
#   'sanitized_wo': 'underworld-breach',
#   'url': '/cards/underworld-breach',
#   'synergy': 0.04,
#   'num_decks': 105410,
#   'potential_decks': 1408927},
#  {'name': 'Fabricate',
#   'sanitized': 'fabricate',
#   'sanitized_wo': 'fabricate',
#   'url': '/cards/fabricate',
#   'synergy': 0.04,
#   'num_decks': 105032,
#   'potential_decks': 1464602},
#  {'name': 'Zagoth Triome',
#   'sanitized': 'zagoth-triome',
#   'sanitized_wo': 'zagoth-triome',
#   'url': '/cards/zagoth-triome',
#   'synergy': 0.3,
#   'num_decks': 104930,
#   'potential_decks': 307313},
#  {'name': 'Goblin Bombardment',
#   'sanitized': 'goblin-bombardment',
#   'sanitized_wo': 'goblin-bombardment',
#   'url': '/cards/goblin-bombardment',
#   'synergy': 0.04,
#   'num_decks': 104718,
#   'potential_decks': 1420826},
#  {'name': 'Rakdos Charm',
#   'sanitized': 'rakdos-charm',
#   'sanitized_wo': 'rakdos-charm',
#   'url': '/cards/rakdos-charm',
#   'synergy': 0.12,
#   'num_decks': 104443,
#   'potential_decks': 679126},
#  {'name': "Jetmir's Garden",
#   'sanitized': 'jetmirs-garden',
#   'sanitized_wo': 'jetmirs-garden',
#   'url': '/cards/jetmirs-garden',
#   'synergy': 0.34,
#   'num_decks': 104387,
#   'potential_decks': 271913},
#  {'name': 'Ketria Triome',
#   'sanitized': 'ketria-triome',
#   'sanitized_wo': 'ketria-triome',
#   'url': '/cards/ketria-triome',
#   'synergy': 0.31,
#   'num_decks': 103954,
#   'potential_decks': 295621},
#  {'name': "Mirari's Wake",
#   'sanitized': 'miraris-wake',
#   'sanitized_wo': 'miraris-wake',
#   'url': '/cards/miraris-wake',
#   'synergy': 0.14,
#   'num_decks': 103897,
#   'potential_decks': 590929},
#  {'name': "Raffine's Tower",
#   'sanitized': 'raffines-tower',
#   'sanitized_wo': 'raffines-tower',
#   'url': '/cards/raffines-tower',
#   'synergy': 0.29,
#   'num_decks': 103550,
#   'potential_decks': 313591},
#  {'name': 'Jungle Shrine',
#   'sanitized': 'jungle-shrine',
#   'sanitized_wo': 'jungle-shrine',
#   'url': '/cards/jungle-shrine',
#   'synergy': 0.29,
#   'num_decks': 103141,
#   'potential_decks': 320919},
#  {'name': 'Castle Locthwain',
#   'sanitized': 'castle-locthwain',
#   'sanitized_wo': 'castle-locthwain',
#   'url': '/cards/castle-locthwain',
#   'synergy': 0.03,
#   'num_decks': 103082,
#   'potential_decks': 1523203},
#  {'name': 'Kindred Discovery',
#   'sanitized': 'kindred-discovery',
#   'sanitized_wo': 'kindred-discovery',
#   'url': '/cards/kindred-discovery',
#   'synergy': 0.04,
#   'num_decks': 102704,
#   'potential_decks': 1462126},
#  {'name': 'Exploration',
#   'sanitized': 'exploration',
#   'sanitized_wo': 'exploration',
#   'url': '/cards/exploration',
#   'synergy': 0.04,
#   'num_decks': 102512,
#   'potential_decks': 1283963},
#  {'name': 'Supreme Verdict',
#   'sanitized': 'supreme-verdict',
#   'sanitized_wo': 'supreme-verdict',
#   'url': '/cards/supreme-verdict',
#   'synergy': 0.12,
#   'num_decks': 102346,
#   'potential_decks': 652655},
#  {'name': 'Indatha Triome',
#   'sanitized': 'indatha-triome',
#   'sanitized_wo': 'indatha-triome',
#   'url': '/cards/indatha-triome',
#   'synergy': 0.31,
#   'num_decks': 102241,
#   'potential_decks': 297227},
#  {'name': 'Bastion of Remembrance',
#   'sanitized': 'bastion-of-remembrance',
#   'sanitized_wo': 'bastion-of-remembrance',
#   'url': '/cards/bastion-of-remembrance',
#   'synergy': 0.03,
#   'num_decks': 101547,
#   'potential_decks': 1515847},
#  {'name': 'Hardened Scales',
#   'sanitized': 'hardened-scales',
#   'sanitized_wo': 'hardened-scales',
#   'url': '/cards/hardened-scales',
#   'synergy': 0.04,
#   'num_decks': 100776,
#   'potential_decks': 1283145},
#  {'name': "Green Sun's Zenith",
#   'sanitized': 'green-suns-zenith',
#   'sanitized_wo': 'green-suns-zenith',
#   'url': '/cards/green-suns-zenith',
#   'synergy': 0.04,
#   'num_decks': 100086,
#   'potential_decks': 1283601},
#  {'name': "Cathars' Crusade",
#   'sanitized': 'cathars-crusade',
#   'sanitized_wo': 'cathars-crusade',
#   'url': '/cards/cathars-crusade',
#   'synergy': 0.04,
#   'num_decks': 99838,
#   'potential_decks': 1340229},
# ...
#   'potential_decks': 17741},
#  {'name': 'Riveteers Ascendancy',
#   'sanitized': 'riveteers-ascendancy',
#   'sanitized_wo': 'riveteers-ascendancy',
#   'url': '/cards/riveteers-ascendancy',
#   'synergy': 0.06,
#   'num_decks': 16862,
#   'potential_decks': 235937},
#  {'name': 'Shorikai, Genesis Engine',
#   'sanitized': 'shorikai-genesis-engine',
#   'sanitized_wo': 'shorikai-genesis-engine',
#   'url': '/commanders/shorikai-genesis-engine',
#   'num_decks': 16058,
#   'potential_decks': 16861},
#  {'name': 'Court of Garenbrig',
#   'sanitized': 'court-of-garenbrig',
#   'sanitized_wo': 'court-of-garenbrig',
#   'url': '/cards/court-of-garenbrig',
#   'synergy': 0.04,
#   'num_decks': 16013,
#   'potential_decks': 209643},
#  {'name': 'Fist of Suns',
#   'sanitized': 'fist-of-suns',
#   'sanitized_wo': 'fist-of-suns',
#   'url': '/cards/fist-of-suns',
#   'synergy': 0.08,
#   'num_decks': 15606,
#   'potential_decks': 179955},
#  {'name': 'Ghalta, Stampede Tyrant',
#   'sanitized': 'ghalta-stampede-tyrant',
#   'sanitized_wo': 'ghalta-stampede-tyrant',
#   'url': '/cards/ghalta-stampede-tyrant',
#   'synergy': 0.11,
#   'num_decks': 15604,
#   'potential_decks': 78699},
#  {'name': 'Maelstrom Nexus',
#   'sanitized': 'maelstrom-nexus',
#   'sanitized_wo': 'maelstrom-nexus',
#   'url': '/cards/maelstrom-nexus',
#   'synergy': 0.08,
#   'num_decks': 14995,
#   'potential_decks': 179951},
#  {'name': 'Kutzil, Malamet Exemplar',
#   'sanitized': 'kutzil-malamet-exemplar',
#   'sanitized_wo': 'kutzil-malamet-exemplar',
#   'url': '/cards/kutzil-malamet-exemplar',
#   'synergy': 0.19,
#   'num_decks': 14692,
#   'potential_decks': 59549},
#  {'name': 'Sanctum of All',
#   'sanitized': 'sanctum-of-all',
#   'sanitized_wo': 'sanctum-of-all',
#   'url': '/cards/sanctum-of-all',
#   'synergy': 0.08,
#   'num_decks': 14422,
#   'potential_decks': 177117},
#  {'name': 'Prosper, Tome-Bound',
#   'sanitized': 'prosper-tome-bound',
#   'sanitized_wo': 'prosper-tome-bound',
#   'url': '/commanders/prosper-tome-bound',
#   'num_decks': 14141,
#   'potential_decks': 14752},
#  {'name': 'Rise of the Witch-king',
#   'sanitized': 'rise-of-the-witch-king',
#   'sanitized_wo': 'rise-of-the-witch-king',
#   'url': '/cards/rise-of-the-witch-king',
#   'synergy': 0.06,
#   'num_decks': 14110,
#   'potential_decks': 185944},
#  {'name': 'Dihada, Binder of Wills',
#   'sanitized': 'dihada-binder-of-wills',
#   'sanitized_wo': 'dihada-binder-of-wills',
#   'url': '/cards/dihada-binder-of-wills',
#   'synergy': 0.06,
#   'num_decks': 13925,
#   'potential_decks': 214702},
#  {'name': 'The Skullspore Nexus',
#   'sanitized': 'the-skullspore-nexus',
#   'sanitized_wo': 'the-skullspore-nexus',
#   'url': '/cards/the-skullspore-nexus',
#   'synergy': 0.1,
#   'num_decks': 13911,
#   'potential_decks': 78699},
#  {'name': 'Virtue of Strength',
#   'sanitized': 'virtue-of-strength',
#   'sanitized_wo': 'virtue-of-strength',
#   'url': '/cards/virtue-of-strength',
#   'synergy': 0.04,
#   'num_decks': 13864,
#   'potential_decks': 191136},
#  {'name': 'Bloodletter of Aclazotz',
#   'sanitized': 'bloodletter-of-aclazotz',
#   'sanitized_wo': 'bloodletter-of-aclazotz',
#   'url': '/cards/bloodletter-of-aclazotz',
#   'synergy': 0.08,
#   'num_decks': 13761,
#   'potential_decks': 91498},
#  {'name': 'Decadent Dragon',
#   'sanitized': 'decadent-dragon',
#   'sanitized_wo': 'decadent-dragon',
#   'url': '/cards/decadent-dragon',
#   'synergy': 0.11,
#   'num_decks': 13575,
#   'potential_decks': 95240},
#  {'name': 'The Kami War',
#   'sanitized': 'the-kami-war',
#   'sanitized_wo': 'the-kami-war',
#   'url': '/cards/the-kami-war',
#   'cards': [{'name': 'The Kami War', 'url': 'the-kami-war'},
#    {'name': 'O-Kagachi Made Manifest', 'url': 'the-kami-war'}],
#   'synergy': 0.07,
#   'num_decks': 12831,
#   'potential_decks': 162463},
#  {'name': "Captain N'ghathrod",
#   'sanitized': 'captain-nghathrod',
#   'sanitized_wo': 'captain-nghathrod',
#   'url': '/commanders/captain-nghathrod',
#   'num_decks': 10646,
#   'potential_decks': 11150},
#  {'name': 'In the Darkness Bind Them',
#   'sanitized': 'in-the-darkness-bind-them',
#   'sanitized_wo': 'in-the-darkness-bind-them',
#   'url': '/cards/in-the-darkness-bind-them',
#   'synergy': 0.08,
#   'num_decks': 10306,
#   'potential_decks': 110455},
#  {'name': 'Doors of Durin',
#   'sanitized': 'doors-of-durin',
#   'sanitized_wo': 'doors-of-durin',
#   'url': '/cards/doors-of-durin',
#   'synergy': 0.04,
#   'num_decks': 9559,
#   'potential_decks': 188882},
#  {'name': "Brass's Tunnel-Grinder",
#   'sanitized': 'brasss-tunnel-grinder',
#   'sanitized_wo': 'brasss-tunnel-grinder',
#   'url': '/cards/brasss-tunnel-grinder',
#   'cards': [{'name': "Brass's Tunnel-Grinder", 'url': 'brasss-tunnel-grinder'},
#    {'name': 'Tecutlan, the Searing Rift', 'url': 'brasss-tunnel-grinder'}],
#   'synergy': 0.03,
#   'num_decks': 9448,
#   'potential_decks': 143701},
#  {'name': 'Bartolomé del Presidio',
#   'sanitized': 'bartolome-del-presidio',
#   'sanitized_wo': 'bartolome-del-presidio',
#   'url': '/cards/bartolome-del-presidio',
#   'synergy': 0.2,
#   'num_decks': 9285,
#   'potential_decks': 37626},
#  {'name': 'Urza, Chief Artificer',
#   'sanitized': 'urza-chief-artificer',
#   'sanitized_wo': 'urza-chief-artificer',
#   'url': '/commanders/urza-chief-artificer',
#   'num_decks': 8734,
#   'potential_decks': 9197},
#  {'name': 'Thousand Moons Smithy',
#   'sanitized': 'thousand-moons-smithy',
#   'sanitized_wo': 'thousand-moons-smithy',
#   'url': '/cards/thousand-moons-smithy',
#   'cards': [{'name': 'Thousand Moons Smithy', 'url': 'thousand-moons-smithy'},
#    {'name': 'Barracks of the Thousand', 'url': 'thousand-moons-smithy'}],
#   'synergy': 0.03,
#   'num_decks': 8177,
#   'potential_decks': 123231},
#  {'name': 'Restless Cottage',
#   'sanitized': 'restless-cottage',
#   'sanitized_wo': 'restless-cottage',
#   'url': '/cards/restless-cottage',
#   'synergy': 0.06,
#   'num_decks': 7834,
#   'potential_decks': 100439},
#  {'name': 'Zhulodok, Void Gorger',
#   'sanitized': 'zhulodok-void-gorger',
#   'sanitized_wo': 'zhulodok-void-gorger',
#   'url': '/commanders/zhulodok-void-gorger',
#   'num_decks': 7816,
#   'potential_decks': 7973},
#  {'name': 'Marneus Calgar',
#   'sanitized': 'marneus-calgar',
#   'sanitized_wo': 'marneus-calgar',
#   'url': '/commanders/marneus-calgar',
#   'num_decks': 7003,
#   'potential_decks': 7265},
#  {'name': 'Osgir, the Reconstructor',
#   'sanitized': 'osgir-the-reconstructor',
#   'sanitized_wo': 'osgir-the-reconstructor',
#   'url': '/commanders/osgir-the-reconstructor',
#   'num_decks': 6719,
#   'potential_decks': 6941},
#  {'name': 'Kozilek, the Great Distortion',
#   'sanitized': 'kozilek-the-great-distortion',
#   'sanitized_wo': 'kozilek-the-great-distortion',
#   'url': '/commanders/kozilek-the-great-distortion',
#   'num_decks': 6427,
#   'potential_decks': 6637},
#  {'name': 'The Indomitable',
#   'sanitized': 'the-indomitable',
#   'sanitized_wo': 'the-indomitable',
#   'url': '/cards/the-indomitable',
#   'synergy': 0.05,
#   'num_decks': 6058,
#   'potential_decks': 73959},
#  {'name': 'Carmen, Cruel Skymarcher',
#   'sanitized': 'carmen-cruel-skymarcher',
#   'sanitized_wo': 'carmen-cruel-skymarcher',
#   'url': '/cards/carmen-cruel-skymarcher',
#   'synergy': 0.1,
#   'num_decks': 6003,
#   'potential_decks': 49188},
#  {'name': 'Restless Bivouac',
#   'sanitized': 'restless-bivouac',
#   'sanitized_wo': 'restless-bivouac',
#   'url': '/cards/restless-bivouac',
#   'synergy': 0.04,
#   'num_decks': 5933,
#   'potential_decks': 109418},
#  {'name': 'Mishra, Eminent One',
#   'sanitized': 'mishra-eminent-one',
#   'sanitized_wo': 'mishra-eminent-one',
#   'url': '/commanders/mishra-eminent-one',
#   'num_decks': 5331,
#   'potential_decks': 5551},
#  {'name': 'Pantlaza, Sun-Favored',
#   'sanitized': 'pantlaza-sun-favored',
#   'sanitized_wo': 'pantlaza-sun-favored',
#   'url': '/cards/pantlaza-sun-favored',
#   'synergy': 0.11,
#   'num_decks': 5141,
#   'potential_decks': 41517},
#  {'name': 'Restless Vinestalk',
#   'sanitized': 'restless-vinestalk',
#   'sanitized_wo': 'restless-vinestalk',
#   'url': '/cards/restless-vinestalk',
#   'synergy': 0.04,
#   'num_decks': 5003,
#   'potential_decks': 93391},
#  {'name': 'Imotekh the Stormlord',
#   'sanitized': 'imotekh-the-stormlord',
#   'sanitized_wo': 'imotekh-the-stormlord',
#   'url': '/commanders/imotekh-the-stormlord',
#   'num_decks': 4300,
#   'potential_decks': 4479},
#  {'name': "Kraum, Ludevic's Opus // Tymna the Weaver",
#   'sanitized': 'kraum-ludevics-opus-tymna-the-weaver',
#   'sanitized_wo': 'kraum-ludevics-opus-tymna-the-weaver',
#   'url': '/commanders/kraum-ludevics-opus-tymna-the-weaver',
#   'cards': [{'name': "Kraum, Ludevic's Opus", 'url': 'kraum-ludevics-opus'},
#    {'name': 'Tymna the Weaver', 'url': 'tymna-the-weaver'}],
#   'is_partner': True,
#   'names': ["Kraum, Ludevic's Opus", 'Tymna the Weaver'],
#   'num_decks': 4099,
#   'potential_decks': 4168},
#  {'name': 'Éowyn, Shieldmaiden',
#   'sanitized': 'eowyn-shieldmaiden',
#   'sanitized_wo': 'eowyn-shieldmaiden',
#   'url': '/commanders/eowyn-shieldmaiden',
#   'num_decks': 3986,
#   'potential_decks': 4178},
#  {'name': 'Restless Reef',
#   'sanitized': 'restless-reef',
#   'sanitized_wo': 'restless-reef',
#   'url': '/cards/restless-reef',
#   'synergy': 0.05,
#   'num_decks': 3931,
#   'potential_decks': 57065},
#  {'name': 'Sliver Gravemother',
#   'sanitized': 'sliver-gravemother',
#   'sanitized_wo': 'sliver-gravemother',
#   'url': '/cards/sliver-gravemother',
#   'synergy': 0.12,
#   'num_decks': 3846,
#   'potential_decks': 31078},
#  {'name': 'Restless Ridgeline',
#   'sanitized': 'restless-ridgeline',
#   'sanitized_wo': 'restless-ridgeline',
#   'url': '/cards/restless-ridgeline',
#   'synergy': 0.04,
#   'num_decks': 3813,
#   'potential_decks': 63613},
#  {'name': 'Squirming Emergence',
#   'sanitized': 'squirming-emergence',
#   'sanitized_wo': 'squirming-emergence',
#   'url': '/cards/squirming-emergence',
#   'synergy': 0.07,
#   'num_decks': 3707,
#   'potential_decks': 44820},
#  {'name': 'Huatli, Poet of Unity',
#   'sanitized': 'huatli-poet-of-unity',
#   'sanitized_wo': 'huatli-poet-of-unity',
#   'url': '/cards/huatli-poet-of-unity',
#   'cards': [{'name': 'Huatli, Poet of Unity', 'url': 'huatli-poet-of-unity'},
#    {'name': 'Roar of the Fifth People', 'url': 'huatli-poet-of-unity'}],
#   'synergy': 0.11,
#   'num_decks': 3422,
#   'potential_decks': 25668},
#  {'name': 'Commodore Guff',
#   'sanitized': 'commodore-guff',
#   'sanitized_wo': 'commodore-guff',
#   'url': '/commanders/commodore-guff',
#   'num_decks': 2973,
#   'potential_decks': 3129},
#  {'name': "Liberator, Urza's Battlethopter",
#   'sanitized': 'liberator-urzas-battlethopter',
#   'sanitized_wo': 'liberator-urzas-battlethopter',
#   'url': '/commanders/liberator-urzas-battlethopter',
#   'num_decks': 2370,
#   'potential_decks': 2492},
#  {'name': 'Nuka-Cola Vending Machine',
#   'sanitized': 'nuka-cola-vending-machine',
#   'sanitized_wo': 'nuka-cola-vending-machine',
#   'url': '/cards/nuka-cola-vending-machine',
#   'synergy': 0.01,
#   'num_decks': 2081,
#   'potential_decks': 5367},
#  {'name': 'Ishai, Ojutai Dragonspeaker // Jeska, Thrice Reborn',
#   'sanitized': 'ishai-ojutai-dragonspeaker-jeska-thrice-reborn',
#   'sanitized_wo': 'ishai-ojutai-dragonspeaker-jeska-thrice-reborn',
#   'url': '/commanders/ishai-ojutai-dragonspeaker-jeska-thrice-reborn',
#   'cards': [{'name': 'Ishai, Ojutai Dragonspeaker',
#     'url': 'ishai-ojutai-dragonspeaker'},
#    {'name': 'Jeska, Thrice Reborn', 'url': 'jeska-thrice-reborn'}],
#   'is_partner': True,
#   'names': ['Ishai, Ojutai Dragonspeaker', 'Jeska, Thrice Reborn'],
#   'num_decks': 2001,
#   'potential_decks': 2055},
#  {'name': 'The Tenth Doctor // Rose Tyler',
#   'sanitized': 'the-tenth-doctor-rose-tyler',
#   'sanitized_wo': 'the-tenth-doctor-rose-tyler',
#   'url': '/commanders/the-tenth-doctor-rose-tyler',
#   'cards': [{'name': 'The Tenth Doctor', 'url': 'the-tenth-doctor'},
#    {'name': 'Rose Tyler', 'url': 'rose-tyler'}],
#   'is_partner': True,
#   'names': ['The Tenth Doctor', 'Rose Tyler'],
#   'num_decks': 1935,
#   'potential_decks': 2021},
#  {'name': 'Bruse Tarl, Boorish Herder // Thrasios, Triton Hero',
#   'sanitized': 'bruse-tarl-boorish-herder-thrasios-triton-hero',
#   'sanitized_wo': 'bruse-tarl-boorish-herder-thrasios-triton-hero',
#   'url': '/commanders/bruse-tarl-boorish-herder-thrasios-triton-hero',
#   'cards': [{'name': 'Bruse Tarl, Boorish Herder',
#     'url': 'bruse-tarl-boorish-herder'},
#    {'name': 'Thrasios, Triton Hero', 'url': 'thrasios-triton-hero'}],
#   'is_partner': True,
#   'names': ['Bruse Tarl, Boorish Herder', 'Thrasios, Triton Hero'],
#   'num_decks': 1797,
#   'potential_decks': 1864},
#  {'name': 'Radstorm',
#   'sanitized': 'radstorm',
#   'sanitized_wo': 'radstorm',
#   'url': '/cards/radstorm',
#   'synergy': 0.29,
#   'num_decks': 1105,
#   'potential_decks': 2258},
#  {'name': 'Demand Answers',
#   'sanitized': 'demand-answers',
#   'sanitized_wo': 'demand-answers',
#   'url': '/cards/demand-answers',
#   'synergy': 0.07,
#   'num_decks': 1100,
#   'potential_decks': 6902},
#  {'name': 'Aurelia, the Law Above',
#   'sanitized': 'aurelia-the-law-above',
#   'sanitized_wo': 'aurelia-the-law-above',
#   'url': '/cards/aurelia-the-law-above',
#   'synergy': 0.14,
#   'num_decks': 777,
#   'potential_decks': 3958},
#  {'name': 'Rakdos, Patron of Chaos',
#   'sanitized': 'rakdos-patron-of-chaos',
#   'sanitized_wo': 'rakdos-patron-of-chaos',
#   'url': '/cards/rakdos-patron-of-chaos',
#   'synergy': 0.14,
#   'num_decks': 661,
#   'potential_decks': 3459},
#  {'name': "Caesar, Legion's Emperor",
#   'sanitized': 'caesar-legions-emperor',
#   'sanitized_wo': 'caesar-legions-emperor',
#   'url': '/cards/caesar-legions-emperor',
#   'synergy': 0.48,
#   'num_decks': 638,
#   'potential_decks': 1075},
#  {'name': 'Slime Against Humanity',
#   'sanitized': 'slime-against-humanity',
#   'sanitized_wo': 'slime-against-humanity',
#   'url': '/cards/slime-against-humanity',
#   'synergy': 0.04,
#   'num_decks': 578,
#   'potential_decks': 6534},
#  {'name': 'Idolized',
#   'sanitized': 'idolized',
#   'sanitized_wo': 'idolized',
#   'url': '/cards/idolized',
#   'synergy': 0.06,
#   'num_decks': 493,
#   'potential_decks': 3191},
#  {'name': "Warleader's Call",
#   'sanitized': 'warleaders-call',
#   'sanitized_wo': 'warleaders-call',
#   'url': '/cards/warleaders-call',
#   'synergy': 0.08,
#   'num_decks': 488,
#   'potential_decks': 3958},
#  {'name': 'The Fifteenth Doctor',
#   'sanitized': 'the-fifteenth-doctor',
#   'sanitized_wo': 'the-fifteenth-doctor',
#   'url': '/cards/the-fifteenth-doctor',
#   'synergy': 0.15,
#   'num_decks': 446,
#   'potential_decks': 2513},
#  {'name': 'Feral Ghoul',
#   'sanitized': 'feral-ghoul',
#   'sanitized_wo': 'feral-ghoul',
#   'url': '/cards/feral-ghoul',
#   'synergy': 0.05,
#   'num_decks': 438,
#   'potential_decks': 3358},
#  {'name': 'Alpha Deathclaw',
#   'sanitized': 'alpha-deathclaw',
#   'sanitized_wo': 'alpha-deathclaw',
#   'url': '/cards/alpha-deathclaw',
#   'synergy': 0.16,
#   'num_decks': 433,
#   'potential_decks': 1726},
#  {'name': "Tolsimir, Midnight's Light",
#   'sanitized': 'tolsimir-midnights-light',
#   'sanitized_wo': 'tolsimir-midnights-light',
#   'url': '/cards/tolsimir-midnights-light',
#   'synergy': 0.13,
#   'num_decks': 413,
#   'potential_decks': 2550},
#  {'name': 'V.A.T.S.',
#   'sanitized': 'vats',
#   'sanitized_wo': 'vats',
#   'url': '/cards/vats',
#   'synergy': 0.04,
#   'num_decks': 366,
#   'potential_decks': 3358},
#  {'name': 'Lara Croft, Tomb Raider',
#   'sanitized': 'lara-croft-tomb-raider',
#   'sanitized_wo': 'lara-croft-tomb-raider',
#   'url': '/cards/lara-croft-tomb-raider',
#   'synergy': 0.18,
#   'num_decks': 316,
#   'potential_decks': 1597},
#  {'name': 'Rex, Cyber-Hound',
#   'sanitized': 'rex-cyber-hound',
#   'sanitized_wo': 'rex-cyber-hound',
#   'url': '/cards/rex-cyber-hound',
#   'synergy': 0.09,
#   'num_decks': 111,
#   'potential_decks': 972},
#  {'name': 'Leyline of the Guildpact',
#   'sanitized': 'leyline-of-the-guildpact',
#   'sanitized_wo': 'leyline-of-the-guildpact',
#   'url': '/cards/leyline-of-the-guildpact',
#   'synergy': 0.3,
#   'num_decks': 104,
#   'potential_decks': 339},
#  {'name': 'Dogmeat, Ever Loyal',
#   'sanitized': 'dogmeat-ever-loyal',
#   'sanitized_wo': 'dogmeat-ever-loyal',
#   'url': '/cards/dogmeat-ever-loyal',
#   'synergy': 0.17,
#   'num_decks': 80,
#   'potential_decks': 433},
#  {'name': 'Dr. Madison Li',
#   'sanitized': 'dr-madison-li',
#   'sanitized_wo': 'dr-madison-li',
#   'url': '/cards/dr-madison-li',
#   'synergy': 0.12,
#   'num_decks': 39,
#   'potential_decks': 313}]

# %%
len([k for k,v in lists['non_commander'].items() if isinstance(v,dict) and len(v.keys())==2 and isinstance(v['cards'],list)])
# Out:
# 11794

# %%
with open(os.path.join(DATA_PATH,'edhreclists.pkl'), 'wb') as f:
    pickle.dump(lists, f)

# %%
sol = request_json('Sol Ring')
sol['header'],sol['container']['json_dict']['card']['num_decks']
# Out:
# ('Sol Ring (Card)', 2953387)

# %%
max([card['num_decks'] for card in lists['non_commander']['Sol Ring']])
# Out:
# 2261244

# %%
lists['valid'][comm]['cards'][-1]
# Out:
# {'name': 'Roaming Throne',
#  'sanitized': 'roaming-throne',
#  'sanitized_wo': 'roaming-throne',
#  'url': '/cards/roaming-throne',
#  'synergy': -0.18,
#  'num_decks': 11,
#  'potential_decks': 157}

# %%
def synergy(a,b, lists, a_is_commander=False):
    """
    Calculate count-based synergy between two cards, according to EDHRec play data.
    If considering a commander, it should be the first card listed, and set a_is_commander to True.
    Return: a numerical score: log(ab_counts**2/(a_counts*b_counts))
    """
    # get a-card fequency
    a_set = False
    a_freq = 0
    a_cards = []
    if a_is_commander: # commander card
        for split in ['valid','test']:
            if a in lists[split]:
                a_freq = lists[split][a]['total']
                a_cards = lists[split][a]['cards']
                a_set = True
                break
    elif a in lists['non_commander']: # normal card we've already queried
        a_freq = lists['non_commander'][a]['total']
        a_cards = lists['non_commander'][a]['cards']
        a_set = True

    if not a_set: # need to query the API for a-card data
        a_data = None
        while a_data is None:
            a_data = request_json(a,a_is_commander)
        a_freq = a_data['container']['json_dict']['card']['num_decks']
        a_cards = a_data['cardlist']

    # get a and b co-fequency
    ab = [card for card in a_cards if card['name'] == b]
    if len(ab)>0:
        ab_freq = ab[0]['num_decks']
    else: # cards don't co-occur. assume 1 co-occurrence for logarithm
        ab_freq = 1

    # get b-card fequency
    b_set = False
    b_freq = 0
    if b in lists['non_commander']: # there can't be 2 commanders generally
        b_freq = lists['non_commander'][b]['total']
        b_set = True
    if not b_set: # need to query the API for a data
        b_data = None
        while b_data is None:
            b_data = request_json(b,False)
        b_freq = b_data['container']['json_dict']['card']['num_decks']

    ratio = ab_freq**2/(a_freq*b_freq) # squaring the numerator gives better spread
    return math.log(ratio)

# %%
comm = 'Stangg, Echo Warrior'
high_syn = 'Command Tower'
low_syn = 'Roaming Throne'

# %%
for a,b,c in [(high_syn, high_syn,False),(comm, high_syn,True),(comm, low_syn,True),(high_syn,low_syn,False)]:
    print(synergy(a,b, lists,a_is_commander=c))
# Out:
# -29.49589487285557
# -7.713427787246376
# -13.591501177382606
# -4.306623108230701

# %%
math.mean([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 math.mean([1,2,3])
#
# AttributeError: module 'math' has no attribute 'mean'

# %% [markdown]
# # synergy metrics

# %%
from scrape_cardlists import request_json, CARDLISTS_PATH
lists = pickle.load(open(CARDLISTS_PATH, 'rb'))
DECK_PATH = os.path.abspath(os.path.join('..', 'data','decks'))

path='gpt'
deck_path = os.path.join(DECK_PATH, path)
print(deck_path)
deckfiles = os.listdir(deck_path)
deckfiles = [f for f in deckfiles if 'txt' in f]
len(deckfiles)
# Out:
# c:\Users\eviye\Documents\UCSD 2023-2024\dsc180ab\edhbuilder\data\decks\gpt
# 189

# %%
def request_json(name:str, is_commander, redirect=''):
    formatted_name = format_card_name(name)
    if redirect:
        print(f"Redirected to {redirect}")
        json_url = f"https://json.edhrec.com/pages{redirect}.json"
    else:
        json_url = f"https://json.edhrec.com/pages/{'commanders' if is_commander else 'cards'}/{formatted_name}.json"
    response = requests.get(json_url)
    if response.status_code == 200:
        json_data = response.json()
        if 'redirect' in json_data:
            return request_json(name, is_commander,redirect=json_data['redirect'])
        # print(f"JSON request successful!")
        return json_data
    else:
        print(f"JSON request for \"{name}\" ({formatted_name}) failed! Try different card name")

def synergy(a,b, lists, a_is_commander=False):
    """
    Calculate count-based synergy between two cards, according to EDHRec play data.
    If considering a commander, it should be the first card listed, and set a_is_commander to True.

    a: a card name
    b: a card name
    lists: a dictionary of cardlists, as returned by scrape_cardlists.py
    a_is_commander: a boolean indicating whether a is a commander card

    Return: a numerical score: log(ab_counts**2/(a_counts*b_counts))
    """
    # get a-card fequency
    a_set = False
    a_freq = 0
    a_cards = []
    if a_is_commander: # commander card
        for split in ['valid','test']:
            if a in lists[split]:
                a_freq = lists[split][a]['total']
                a_cards = lists[split][a]['cards']
                a_set = True
                break
    elif a in lists['non_commander']: # normal card we've already queried
        a_freq = lists['non_commander'][a]['total']
        a_cards = lists['non_commander'][a]['cards']
        a_set = True

    if not a_set: # need to query the API for a-card data
        a_data = None
        for _ in range(5):
            a_data = request_json(a,a_is_commander)
            if a_data is not None:
                break
        if a_data is None:
            raise ValueError('Failed to get data for card:',a)
        a_freq = a_data['container']['json_dict']['card']['num_decks']
        a_cards = {card['name']:card['num_decks'] for card in a_data['cardlist']}
        a_split = 'test' if a_is_commander else 'non_commander'
        lists[a_split][a] = {'cards':a_cards, 'total':a_freq} # save the data for later use
        print(f'Adding card to {a_split} list: {a}')

    # get a and b co-fequency
    if b in a_cards:
        ab_freq = a_cards[b]
    else: # cards don't co-occur. assume 1 co-occurrence for calculating logarithm
        ab_freq = 1

    # get b-card fequency
    b_set = False
    b_freq = 0
    if b in lists['non_commander']: # there can't be 2 commanders
        b_freq = lists['non_commander'][b]['total']
        b_set = True
    if not b_set: # need to query the API for a data
        b_data = None
        for _ in range(5):
            b_data = request_json(b,False)
            if b_data is not None:
                break
            print(repr(b))
        if b_data is None:
            raise ValueError('Failed to get data for card:',b)
        b_cards = {card['name']:card['num_decks'] for card in b_data['cardlist']}
        b_freq = b_data['container']['json_dict']['card']['num_decks']
        lists['non_commander'][b] = {'cards':b_cards, 'total':b_freq} # save the data for later use
        print(f'Adding card to non_commander list: {b}')

    ratio = ab_freq**2/(a_freq*b_freq) # squaring the numerator gives better spread
    return math.log(ratio), lists

def mean (l):
    return sum(l)/len(l)

# %%
commander = 'Ashad, the Lone Cyberman'
deck = ['Wizards of Thay', 'Mulldrifter', "Thieves' Tools",\
 'Counterspell', 'Wing Splicer', 'Through the Breach', 'Volo, Itinerant Scholar'\
, 'Torgaar, Famine Incarnate', 'Thunderheads', 'Tezzeret the Schemer', 'Whirlwin\
d Denial', 'Warbeast of Gorgoroth', 'Voidmage Apprentice', 'Vexing Scuttler', 'V\
odalian Mage', 'Whirler Rogue', 'Vandalblast', 'Tolarian Kraken', 'Tezzeret, Cru\
el Machinist', 'Time Elemental', 'Undead Alchemist', 'Storm-Kiln Artist', 'Wretc\
hed Gryff', 'Ugin, the Ineffable', 'The Eleventh Hour', 'Vex', 'Vizier of Many F\
aces', 'Turn // Burn', 'Mind Stone', 'Wandering Archaic // Explore the Vastlands\
', 'Viashino Heretic', 'Wrexial, the Risen Deep', 'Witness Protection', 'Volcani\
c Vision', 'Vedalken Blademaster', 'Vindictive Flamestoker', 'Zombie Boa', 'Voda\
lian Mystic', 'Vedalken Anatomist', 'Unexpected Windfall', 'Wandering Fumarole',\
 'Warping Wail', 'Warteye Witch', 'Unspeakable Symbol', 'Tombstalker', 'Teferi,\
Temporal Pilgrim', 'Talrand, Sky Summoner', 'Tar Pit Warrior', 'Wasteland Strang\
ler', 'Thousand-Year Storm', "Vraska's Contempt", 'Stone Idol Trap', 'Thraxodemo\
n', 'Virtue of Knowledge // Vantress Visions', 'Thieving Amalgam', 'Winding Cany\
ons', 'Vesuvan Shapeshifter', "Tamiyo's Logbook", 'Waste Away', 'Vicious Offerin\
g', "Veteran's Armaments", 'Teleportal', 'Violet Pall']

# %%
commander_sim = []
co_card_sim = []
print(f'evaluating deck: {commander}')
failed = set()
for i in tqdm(range(len(deck))):
    card = deck[i]
    if card in failed:
        continue
    try:
        sim, lists = synergy(commander,card,lists, a_is_commander=True)
        commander_sim.append(sim)
        card_sim = []
        for j in range(len(deck)):
            b = deck[j]
            print(card, b)
            if i == j or b in failed: # ignore synergy with itself, ignore failed cards
                continue
            try:
                sim, lists = synergy(card, b, lists)
                card_sim.append(sim)
            except ValueError as e: # b card not found
                print(e)
                # print(card, b)
                failed.add(b)
                continue
        co_card_sim.append(mean(card_sim))
    except ValueError as e:  # a card not found
        print(e)
        # print(card, b)
        failed.add(a)
        continue
return mean(commander_sim), mean(co_card_sim), lists
# Out:
# evaluating deck: Ashad, the Lone Cyberman
#   0%|          | 0/63 [00:00<?, ?it/s]
# Wizards of Thay Wizards of Thay
# Wizards of Thay Mulldrifter
# Wizards of Thay Thieves' Tools
# Wizards of Thay Counterspell
# Wizards of Thay Wing Splicer
# Wizards of Thay Through the Breach
# Wizards of Thay Volo, Itinerant Scholar
# Wizards of Thay Torgaar, Famine Incarnate
# Wizards of Thay Thunderheads
# Wizards of Thay Tezzeret the Schemer
# Wizards of Thay Whirlwind Denial
# Wizards of Thay Warbeast of Gorgoroth
# Wizards of Thay Voidmage Apprentice
# Wizards of Thay Vexing Scuttler
# Wizards of Thay Vodalian Mage
# Wizards of Thay Whirler Rogue
# Wizards of Thay Vandalblast
# Wizards of Thay Tolarian Kraken
# Wizards of Thay Tezzeret, Cruel Machinist
# Wizards of Thay Time Elemental
# Wizards of Thay Undead Alchemist
# Wizards of Thay Storm-Kiln Artist
# Wizards of Thay Wretched Gryff
# Wizards of Thay Ugin, the Ineffable
# Wizards of Thay The Eleventh Hour
# Wizards of Thay Vex
# Wizards of Thay Vizier of Many Faces
# Wizards of Thay Turn // Burn
#   0%|          | 0/63 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[26], line 19
#      17     continue
#      18 try:
# ---> 19     sim, lists = synergy(card, b, lists)
#      20     card_sim.append(sim)
#      21 except ValueError as e: # b card not found
#
# Cell In[24], line 75, in synergy(a, b, lists, a_is_commander)
#      73 b_data = None
#      74 for _ in range(5):
# ---> 75     b_data = request_json(b,False)
#      76     if b_data is not None:
#      77         break
#
# Cell In[24], line 12, in request_json(name, is_commander, redirect)
#      10 json_data = response.json()
#      11 if 'redirect' in json_data:
# ---> 12     return request_json(name, is_commander,redirect=json_data['redirect'])
#      13 # print(f"JSON request successful!")
#      14 return json_data
#
# Cell In[24], line 4, in request_json(name, is_commander, redirect)
#       2 formatted_name = format_card_name(name)
#       3 if redirect:
# ----> 4     print(f"Redirected to {json_data['redirect']}")
#       5     json_url = f"https://json.edhrec.com/pages{redirect}.json"
#       6 else:
#
# UnboundLocalError: cannot access local variable 'json_data' where it is not associated with a value
