# %%
from openai import OpenAI
import pandas as pd
OPENAI_API_KEY = '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'
from os import path

# %%
# Open the file and read its contents
file = ''
try:
    with open('../data/test_deck.txt', 'r', encoding='utf-8') as file:
        file_contents = file.read()
    print("File content:")
    file = (file_contents)
except FileNotFoundError:
    print(f"The file was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File content:

# %%
client = OpenAI(api_key='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')

gpt_message = client.chat.completions.create(
    
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a Magic the Gathering deck evaluator, you accept a list of 99 cards plus a commander and evaluate the power level of the deck. \
        You do so by identifying what role each card fulfills and formulating a strategy out of that info. Additionally, you predict the average winspeed of the deck, estimated with a number of turns."},
        {"role": "user", "content": file}
    ]
)

# %%
gpt_message.choices[0].message.content
# Out:
# "Based on the list of cards provided, the deck appears to have a mix of control, combo, and token strategies.\n\nControl:\n- Arcane Denial\n- Austere Command\n- Counterspell\n- Dovin's Veto\n- Fell the Mighty\n- Maze of Ith\n- Negate\n- Path to Exile\n- Swords to Plowshares\n- Thought Vessel\n\nThese control cards allow you to disrupt your opponents' plans, protect your own board, and remove threats efficiently.\n\nCombo:\n- Ashnod's Altar\n- Blood Artist\n- Corpse Knight\n- Pitiless Plunderer\n- Smothering Tithe\n- Zulaport Cutthroat\n\nThese combo pieces suggest that the deck focuses on gaining value from sacrificing or generating a large number of creatures. Combining some of these cards with token generators or sacrifice outlets can create powerful synergies and potentially lead to game-ending plays.\n\nTokens:\n- Birth of the Imperium\n- Collector's Vault\n- Kaya's Ghostform\n- Launch the Fleet\n- Martial Coup\n- Nadir Kraken\n- Ophiomancer\n- Reef Worm\n- Spawning Pit\n- Talisman of Dominance\n- Talisman of Hierarchy\n- Talisman of Progress\n- Thalisse, Reverent Medium\n- The Black Gate\n- Viscera Seer\n- Woe Strider\n\nThese cards suggest a strong token strategy that focuses on generating a wide board presence or creating a sacrifice engine. Tokens can provide you with multiple attackers or blockers, and with the presence of Blood Artist, Zulaport Cutthroat, and Pitiless Plunderer, they can be used as resources to gain advantage.\n\nOverall, the deck appears to have a good mix of control elements, combo potential, and token strategies. The inclusion of powerful cards such as Sol Ring, Arcane Signet, and Reliquary Tower further strengthen the deck's potential.\n\nThe average winspeed of the deck is difficult to determine without additional information, such as the average mana curve and the specific win conditions in the deck. However, based on the inclusion of control elements and combo potential, the deck likely has the potential to win games in the mid to late stages, rather than achieving early or aggressive victories. A conservative estimate would put the average winspeed at around 8-10 turns."

# %%
deck = file_contents.strip().split('\n')
deck
# Out:
# ['Commander: Marneus Calgar',
#  "1x An Offer You Can't Refuse",
#  '1x Arcane Denial',
#  '1x Arcane Sanctum',
#  '1x Arcane Signet',
#  "1x Ashnod's Altar",
#  '1x Austere Command',
#  '1x Battle Angels of Tyr',
#  '1x Birth of the Imperium',
#  '1x Black Market Connections',
#  '1x Blood Artist',
#  '1x Brainstorm',
#  '1x Cabal Coffers',
#  '1x Chivalric Alliance',
#  "1x Collector's Vault",
#  '1x Command Tower',
#  "1x Commander's Sphere",
#  '1x Commissar Severina Raine',
#  '1x Corpse Knight',
#  '1x Counterspell',
#  '1x Darkwater Catacombs',
#  '1x Deadly Dispute',
#  '1x Decanter of Endless Water',
#  '1x Deny the Witch',
#  "1x Dovin's Veto",
#  '1x Eaten by Piranhas',
#  '1x Elas il-Kor, Sadistic Pilgrim',
#  '1x Eloise, Nephalia Sleuth',
#  '1x Ethereal Investigator',
#  '1x Exotic Orchard',
#  '1x Faerie Artisans',
#  '1x Faerie Mastermind',
#  '1x Fell the Mighty',
#  "1x Galadriel's Dismissal",
#  '1x Idol of Oblivion',
#  '6x Island',
#  "1x Kaya's Ghostform",
#  '1x Launch the Fleet',
#  '1x Lotho, Corrupt Shirriff',
#  '1x Martial Coup',
#  '1x Maze of Ith',
#  '1x Mind Stone',
#  '1x Minn, Wily Illusionist',
#  '1x Mirkwood Bats',
#  '1x Monologue Tax',
#  '1x Morphic Pool',
#  '1x Nadir Kraken',
#  '1x Negate',
#  '1x Not Dead After All',
#  '1x Obscura Storefront',
#  '1x Ophiomancer',
#  '1x Orcish Bowmasters',
#  '1x Path of Ancestry',
#  '1x Path to Exile',
#  '1x Pitiless Plunderer',
#  '6x Plains',
#  '1x Plaza of Heroes',
#  '1x Prince Imrahil the Fair',
#  "1x Raffine's Tower",
#  '1x Reef Worm',
#  '1x Reliquary Tower',
#  '1x Sanguinary Priest',
#  '1x Sea of Clouds',
#  '1x Skullclamp',
#  '1x Skycloud Expanse',
#  '1x Smothering Tithe',
#  '1x Sol Ring',
#  '1x Spawning Pit',
#  '6x Swamp',
#  '1x Swiftfoot Boots',
#  '1x Swords to Plowshares',
#  '1x Talisman of Dominance',
#  '1x Talisman of Hierarchy',
#  '1x Talisman of Progress',
#  '1x Thalisse, Reverent Medium',
#  '1x The Black Gate',
#  '1x The Golden Throne',
#  '1x The Watcher in the Water',
#  '1x Thought Vessel',
#  '1x Training Grounds',
#  '1x Urborg, Tomb of Yawgmoth',
#  '1x Vexilus Praetor',
#  '1x Viscera Seer',
#  '1x Woe Strider',
#  '1x Zulaport Cutthroat']

# %%
deck[1][0]
# Out:
# '1'

# %%
commander = deck.pop(0)

decklist = []
for card in deck:
    qty = card[0]
    name = card[3:]
    decklist.append((name, qty))
decklist
# Out:
# [('Arcane Sanctum', '1'),
#  ('Arcane Signet', '1'),
#  ("Ashnod's Altar", '1'),
#  ('Austere Command', '1'),
#  ('Battle Angels of Tyr', '1'),
#  ('Birth of the Imperium', '1'),
#  ('Black Market Connections', '1'),
#  ('Blood Artist', '1'),
#  ('Brainstorm', '1'),
#  ('Cabal Coffers', '1'),
#  ('Chivalric Alliance', '1'),
#  ("Collector's Vault", '1'),
#  ('Command Tower', '1'),
#  ("Commander's Sphere", '1'),
#  ('Commissar Severina Raine', '1'),
#  ('Corpse Knight', '1'),
#  ('Counterspell', '1'),
#  ('Darkwater Catacombs', '1'),
#  ('Deadly Dispute', '1'),
#  ('Decanter of Endless Water', '1'),
#  ('Deny the Witch', '1'),
#  ("Dovin's Veto", '1'),
#  ('Eaten by Piranhas', '1'),
#  ('Elas il-Kor, Sadistic Pilgrim', '1'),
#  ('Eloise, Nephalia Sleuth', '1'),
#  ('Ethereal Investigator', '1'),
#  ('Exotic Orchard', '1'),
#  ('Faerie Artisans', '1'),
#  ('Faerie Mastermind', '1'),
#  ('Fell the Mighty', '1'),
#  ("Galadriel's Dismissal", '1'),
#  ('Idol of Oblivion', '1'),
#  ('Island', '6'),
#  ("Kaya's Ghostform", '1'),
#  ('Launch the Fleet', '1'),
#  ('Lotho, Corrupt Shirriff', '1'),
#  ('Martial Coup', '1'),
#  ('Maze of Ith', '1'),
#  ('Mind Stone', '1'),
#  ('Minn, Wily Illusionist', '1'),
#  ('Mirkwood Bats', '1'),
#  ('Monologue Tax', '1'),
#  ('Morphic Pool', '1'),
#  ('Nadir Kraken', '1'),
#  ('Negate', '1'),
#  ('Not Dead After All', '1'),
#  ('Obscura Storefront', '1'),
#  ('Ophiomancer', '1'),
#  ('Orcish Bowmasters', '1'),
#  ('Path of Ancestry', '1'),
#  ('Path to Exile', '1'),
#  ('Pitiless Plunderer', '1'),
#  ('Plains', '6'),
#  ('Plaza of Heroes', '1'),
#  ('Prince Imrahil the Fair', '1'),
#  ("Raffine's Tower", '1'),
#  ('Reef Worm', '1'),
#  ('Reliquary Tower', '1'),
#  ('Sanguinary Priest', '1'),
#  ('Sea of Clouds', '1'),
#  ('Skullclamp', '1'),
#  ('Skycloud Expanse', '1'),
#  ('Smothering Tithe', '1'),
#  ('Sol Ring', '1'),
#  ('Spawning Pit', '1'),
#  ('Swamp', '6'),
#  ('Swiftfoot Boots', '1'),
#  ('Swords to Plowshares', '1'),
#  ('Talisman of Dominance', '1'),
#  ('Talisman of Hierarchy', '1'),
#  ('Talisman of Progress', '1'),
#  ('Thalisse, Reverent Medium', '1'),
#  ('The Black Gate', '1'),
#  ('The Golden Throne', '1'),
#  ('The Watcher in the Water', '1'),
#  ('Thought Vessel', '1'),
#  ('Training Grounds', '1'),
#  ('Urborg, Tomb of Yawgmoth', '1'),
#  ('Vexilus Praetor', '1'),
#  ('Viscera Seer', '1'),
#  ('Woe Strider', '1'),
#  ('Zulaport Cutthroat', '1')]

# %%
library = pd.read_pickle('../data/cards.pkl')
library
# Out:
#                 artist                             artistIds asciiName  \
# 0         Pete Venters  d54c4a1a-c0c5-4834-84db-125d341f3ad8       NaN
# 1         Pete Venters  d54c4a1a-c0c5-4834-84db-125d341f3ad8       NaN
# 2          Volkan Baǵa  93bec3c0-0260-4d31-8064-5d01efb4153f       NaN
# 3          Volkan Baǵa  93bec3c0-0260-4d31-8064-5d01efb4153f       NaN
# 4             Mark Zug  48e2b98c-5467-4671-bd42-4c3746115117       NaN
# ...                ...                                   ...       ...
# 87561   Campbell White  d281eab4-463a-4ba8-9039-8943737960a0       NaN
# 87562  Jason Rainville  6ed7e669-579b-443d-b223-e5cbcb2a7483       NaN
# 87563   Campbell White  d281eab4-463a-4ba8-9039-8943737960a0       NaN
# 87564      Jonas De Ro  561ebf9e-8d93-4b57-8156-8826d0c19601       NaN
# 87565      Colin Boyer  9c201dbe-db56-429a-87e6-189ea70c2632       NaN
#
#       attractionLights availability boosterTypes borderColor cardParts  \
# 0                  NaN  mtgo, paper      default       black       NaN
# 1                  NaN  mtgo, paper      default       black       NaN
# 2                  NaN  mtgo, paper      default       black       NaN
# 3                  NaN  mtgo, paper      default       black       NaN
# 4                  NaN  mtgo, paper      default       black       NaN
# ...                ...          ...          ...         ...       ...
# 87561              NaN  mtgo, paper          NaN       black       NaN
# 87562              NaN  mtgo, paper          NaN       black       NaN
# 87563              NaN  mtgo, paper          NaN       black       NaN
# 87564              NaN  mtgo, paper          NaN       black       NaN
# 87565              NaN  mtgo, paper          NaN       black       NaN
#
#       colorIdentity colorIndicator  ... subsets        subtypes supertypes  \
# 0                 W            NaN  ...     NaN   Human, Cleric        NaN
# 1                 W            NaN  ...     NaN   Human, Cleric        NaN
# 2                 W            NaN  ...     NaN           Angel        NaN
# 3                 W            NaN  ...     NaN           Angel        NaN
# 4                 W            NaN  ...     NaN             NaN        NaN
# ...             ...            ...  ...     ...             ...        ...
# 87561             U            NaN  ...     NaN             NaN        NaN
# 87562             B            NaN  ...     NaN             NaN        NaN
# 87563             R            NaN  ...     NaN             NaN        NaN
# 87564             G            NaN  ...     NaN             NaN        NaN
# 87565          R, W            NaN  ...     NaN  Human, Warrior        NaN
#
#                                                     text  toughness  \
# 0      First strike (This creature deals combat damag...          4
# 1      First strike (This creature deals combat damag...          4
# 2      Flying\nWhen Angel of Mercy enters the battlef...          3
# 3      Flying\nWhen Angel of Mercy enters the battlef...          3
# 4      Target creature gets +3/+3 and gains flying un...        NaN
# ...                                                  ...        ...
# 87561  Kicker {1}{U} (You may pay an additional {1}{U...        NaN
# 87562  Kicker {2}{B} (You may pay an additional {2}{B...        NaN
# 87563  Kicker {5} (You may pay an additional {5} as y...        NaN
# 87564  Sacrifice a land. Search your library for up t...        NaN
# 87565              Other Warriors you control get +1/+1.          3
#
#                            type     types  \
# 0       Creature — Human Cleric  Creature
# 1       Creature — Human Cleric  Creature
# 2              Creature — Angel  Creature
# 3              Creature — Angel  Creature
# 4                       Sorcery   Sorcery
# ...                         ...       ...
# 87561                   Instant   Instant
# 87562                   Sorcery   Sorcery
# 87563                   Sorcery   Sorcery
# 87564                   Instant   Instant
# 87565  Creature — Human Warrior  Creature
#
#                                        uuid  \
# 0      5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# 1      b7c19924-b4bf-56fc-aa73-f586e940bd42
# 2      57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 3      8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a
# 4      55bd38ca-dc73-5c06-8f80-a6ddd2f44382
# ...                                     ...
# 87561  3f492516-7767-5ed7-a1d4-e3f7c06aee2f
# 87562  3f9a0369-5fe7-5aee-85fe-3cfaacd275af
# 87563  97577e9e-69a9-5a8b-9c24-a72703790046
# 87564  deb51cbd-b890-5b2d-9d6f-7b896e16c6fd
# 87565  46407d93-df48-5161-95fe-f24086746663
#
#                                  variations     watermark
# 0      b7c19924-b4bf-56fc-aa73-f586e940bd42           NaN
# 1      5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c           NaN
# 2      8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a           NaN
# 3      57aaebc1-850c-503d-9f6e-bb8d00d8bf7c           NaN
# 4      c5655330-5131-5f40-9d3e-0549d88c6e9e           NaN
# ...                                     ...           ...
# 87561  dd604910-0e81-5d56-b022-e08f21de0879  planeswalker
# 87562  d947d9cd-f855-5496-b5de-88006b49865f  planeswalker
# 87563  dbd65728-bba8-536e-a908-5dfa56068dcb  planeswalker
# 87564  7ef6cffb-335a-5831-8319-20b6a020f1c4  planeswalker
# 87565  f3434acf-7796-572c-a889-487c84cf7948  planeswalker
#
# [87566 rows x 78 columns]

# %%
library.iloc[0]
# Out:
# artist                                      Pete Venters
# artistIds           d54c4a1a-c0c5-4834-84db-125d341f3ad8
# asciiName                                            NaN
# attractionLights                                     NaN
# availability                                 mtgo, paper
#                                     ...
# type                             Creature — Human Cleric
# types                                           Creature
# uuid                5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# variations          b7c19924-b4bf-56fc-aa73-f586e940bd42
# watermark                                            NaN
# Name: 0, Length: 78, dtype: object
