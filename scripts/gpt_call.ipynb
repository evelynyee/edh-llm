# %%
from openai import OpenAI
import pickle
from power_calculator import calculate_power
import numpy as np
import pandas as pd
import os

# %%
def load_data(fp):
    with open(fp, "rb") as f:
        data = pickle.load(f)
    return data

# %%
data = load_data('../data/decks/manual.pkl')
data
# Out:
#            Elenda, the Dusk Rose                       Ghave, Guru of Spores  \
# 0         Xira, the Golden Sting                     Zegana, Utopian Speaker
# 1       Ziatora, the Incinerator                    Yorvo, Lord of Garenbrig
# 2            Xathrid Necromancer                            Yotian Dissident
# 3    Yannik, Scavenging Sentinel                                  Young Wolf
# 4           Widespread Brutality                      Zabaz, the Glimmerwasp
# ..                           ...                                         ...
# 495                  Tomb Tyrant                          Topography Tracker
# 496           White Mana Battery  Voldaren Pariah // Abolisher of Bloodlines
# 497   Sword of Truth and Justice  Voldaren Pariah // Abolisher of Bloodlines
# 498            Squire's Devotion                            Valiant Endeavor
# 499              Torii Watchward                                    Tervigon
#
#         Kambal, Consul of Allocation               Arcum Dagsson  \
# 0                 Zulaport Cutthroat           Zur the Enchanter
# 1    Zof Consumption // Zof Bloodbog   Zareth San, the Trickster
# 2    Zof Consumption // Zof Bloodbog             Zimone and Dina
# 3                   Yawgmoth's Edict  Yuriko, the Tiger's Shadow
# 4                 Zulaport Chainmage    Zimone, Quandrix Prodigy
# ..                               ...                         ...
# 495                      Syphon Life           The Eighth Doctor
# 496              Zeriam, Golden Wind    Zahid, Djinn of the Lamp
# 497                   Westfold Rider           Sway of the Stars
# 498            Stormscape Apprentice     Vorel of the Hull Clade
# 499                   Vexing Arcanix         Vhal, Eager Scholar
#
#                                          The Swarmlord  \
# 0                                       _____-o-saurus
# 1                            Zethi, Arcane Blademaster
# 2                              Zegana, Utopian Speaker
# 3                             Yorvo, Lord of Garenbrig
# 4                             Zektar Shrine Expedition
# ..                                                 ...
# 495                                The Legend of Arena
# 496                               Thundering Mightmare
# 497  Valentin, Dean of the Vein // Lisette, Dean of...
# 498  Valentin, Dean of the Vein // Lisette, Dean of...
# 499                                             Thrive
#
#                     Illuminor Szeras             Iwamori of the Open Fist  \
# 0              Zaxara, the Exemplary                            Zoologist
# 1                  Xenic Poltergeist             Zimone, Quandrix Prodigy
# 2                   Zhentarim Bandit                         World Shaper
# 3                       Wreck Hunter                           Wood Elves
# 4                     Zanikev Locust                    Woodland Bellower
# ..                               ...                                  ...
# 495                   The Dining Car  Who // What // When // Where // Why
# 496           Xira, the Golden Sting  Who // What // When // Where // Why
# 497         The Balrog, Durin's Bane                      Tome of Legends
# 498  Zof Consumption // Zof Bloodbog                      Swell of Growth
# 499  Zof Consumption // Zof Bloodbog                     Wheel of Torture
#
#             Kefnet the Mindful                     The Locust God  \
# 0     Zara, Renegade Recruiter  Young Red Dragon // Bathe in Gold
# 1    Zareth San, the Trickster  Young Red Dragon // Bathe in Gold
# 2         Winterthorn Blessing                Zirilan of the Claw
# 3              Zimone and Dina         Wyll of the Celestial Pact
# 4                Zephyr Scribe                Éowyn, Shieldmaiden
# ..                         ...                                ...
# 495       Stronghold Biologist                       Unlucky Drop
# 496           Veiled Crocodile               Widespread Brutality
# 497          Surrakar Banisher                     Wall of Deceit
# 498                  Whetstone                     Tavern Brawler
# 499         Supreme Inquisitor                 Worldheart Phoenix
#
#                             Krav, the Unredeemed  ...  \
# 0                                 Zanikev Locust  ...
# 1                     Yuriko, the Tiger's Shadow  ...
# 2                     Zask, Skittering Swarmlord  ...
# 3                        Witch-king, Sky Scourge  ...
# 4                         Wolf in _____ Clothing  ...
# ..                                           ...  ...
# 495  Tergrid, God of Fright // Tergrid's Lantern  ...
# 496                                Skullsnatcher  ...
# 497                            Sultai Soothsayer  ...
# 498                            Thought-Knot Seer  ...
# 499                     Ziatora's Proving Ground  ...
#
#        Maarika, Brutal Gladiator       Medomai the Ageless  \
# 0                  Yavimaya Wurm             Zealot il-Vec
# 1    Zagras, Thief of Heartbeats             Zephyr Winder
# 2           You Are Already Dead           Yuan-Ti Malison
# 3              Yamabushi's Storm  Zhou Yu, Chief Commander
# 4              Yamabushi's Flame            Winter's Chill
# ..                           ...                       ...
# 495             Wreath of Geists            Zur's Weirding
# 496                The Tarrasque   Three Bowls of Porridge
# 497           The Cheetah Planet          Targeting Rocket
# 498            Undercity Reaches               Voodoo Doll
# 499                  Unholy Heat          Windbrisk Raptor
#
#                             Katerina of Myra's Marvels  \
# 0                         You're Confronted by Robbers
# 1                               Yenna, Redtooth Regent
# 2                                        Worthy Knight
# 3                                   White Sun's Zenith
# 4                                    Wondrous Crucible
# ..                                                 ...
# 495                                       Snake Basket
# 496                                          Tallowisp
# 497  Ulamog, the Ceaseless Hunger // Ulamog, the Ce...
# 498                             Sigarda, Heron's Grace
# 499                       Ulamog, the Ceaseless Hunger
#
#      Vorthos, Steward of Myth          The Fourth Doctor  \
# 0    Zahid, Djinn of the Lamp      Zhulodok, Void Gorger
# 1                    Zephyrim    Xanathar, Guild Kingpin
# 2         Yahenni's Expertise  Yidris, Maelstrom Wielder
# 3              Wretched Gryff           Write into Being
# 4          Worldheart Phoenix            Ziatora's Envoy
# ..                        ...                        ...
# 495       Ugin, the Ineffable          Tel-Jilad Justice
# 496               Think Twice      Walker of Secret Ways
# 497    Wasp of the Bitter End            Wizard's Retort
# 498          Venarian Glimmer            Wirewood Savage
# 499              Wirewood Elf        Telemin Performance
#
#                        Amy Pond              Ryan Sinclair  \
# 0              Zurgo and Ojutai           Zoyowa's Justice
# 1           _____ Balls of Fire      Zhulodok, Void Gorger
# 2       Witch-king, Sky Scourge            Ziatora's Envoy
# 3                  Weatherlight  Yidris, Maelstrom Wielder
# 4    Your Fate Is Thrice Sealed  Yet Another Aether Vortex
# ..                          ...                        ...
# 495           Vigilante Justice             Taurean Mauler
# 496                 Skullscorch            Slaughter Games
# 497                 Void Mirror                  Twinflame
# 498                 Thunderwave        Viashino Bladescout
# 499         Struggle // Survive                 Zoanthrope
#
#             Jamie McCrimmon           The Master, Formed Anew  \
# 0       Yuan-Ti Scaleshield         Zethi, Arcane Blademaster
# 1        Yavimaya Sojourner            Wyll of the Elder Pact
# 2    Wrenn and Realmbreaker                    Writ of Return
# 3     Zhulodok, Void Gorger                 Wondrous Crucible
# 4     Zaxara, the Exemplary  Young Blue Dragon // Sand Augury
# ..                      ...                               ...
# 495           Tangle Spider                 Tribute to Urborg
# 496         Trail of Crumbs            Tasha, Unholy Archmage
# 497        Titania's Chosen                          Twincast
# 498     The Fugitive Doctor                    Treasure Chest
# 499          Storybook Ride              Traumatic Revelation
#
#      Vrestin, Menoptra Leader
# 0    Yorvo, Lord of Garenbrig
# 1            Yavimaya Sapherd
# 2       Zaxara, the Exemplary
# 3           Woodland Champion
# 4      Xira, the Golden Sting
# ..                        ...
# 495          Wildslayer Elves
# 496   The Millennium Calendar
# 497          Thoughtweft Trio
# 498              Wilfred Mott
# 499        Wolfir Silverheart
#
# [500 rows x 98 columns]

# %%
cmdr = 'Elenda, the Dusk Rose'
pool = data[cmdr]
pool = set(pool)
pool
# Out:
# {'Sprouting Thrinax',
#  "Squire's Devotion",
#  'Staff of Titania',
#  'Staff of the Storyteller',
#  'Storm Herd',
#  'Stormfront Riders',
#  'Strength of Arms',
#  'Sun-Blessed Guardian // Furnace-Blessed Conqueror',
#  'Sunfall',
#  'Sunspire Gatekeepers',
#  'Supply // Demand',
#  'Supply Caravan',
#  'Sword of Body and Mind',
#  'Sword of Truth and Justice',
#  'Sword of the Meek',
#  'Sworn Companions',
#  'Synapse Necromage',
#  'Syndicate Messenger',
#  'Syphon Flesh',
#  'Syr Armont, the Redeemer',
#  'Syr Ginger, the Meal Ender',
#  "Taborax, Hope's Demise",
#  'Tainted Adversary',
#  'Take Up Arms',
#  'Tangled Colony',
#  "Tarrian's Soulcleaver",
#  "Tatsumasa, the Dragon's Fang",
#  'Team Pennant',
#  "Tegwyll's Scouring",
#  'Tempt with Glory',
#  'Ten Wizards Mountain',
#  'Tend the Pests',
#  'Tenured Inkcaster',
#  'Tetravus',
#  'Tetzin, Gnome Champion // The Golden-Gear Colossus',
#  'Tevesh Szat, Doom of Fools',
#  "Teyo's Lightshield",
#  'Teysa, Envoy of Ghosts',
#  'Teysa, Orzhov Scion',
#  'Teysa, Orzhov Scion Avatar',
#  'Tezzeret the Schemer',
#  "Thalia's Geistcaller",
#  "Thalia's Lieutenant",
#  'Thalisse, Reverent Medium',
#  'The Battle of Bywater',
#  'The Big Idea',
#  'The Book of Vile Darkness',
#  'The Cave of Skulls',
#  'The Circle of Loyalty',
#  'The Curse of Fenric',
#  'The Cyber-Controller',
#  'The Dalek Emperor',
#  'The Flesh Is Weak',
#  'The Fourth Sphere',
#  'The Girl in the Fireplace',
#  'The Great Aerie',
#  'The Iron Guardian Stirs',
#  'The Meathook Massacre',
#  'The Mouth of Sauron',
#  'The Mycotyrant',
#  'The Ozolith',
#  'The Pit',
#  'The Provider',
#  'The Rani',
#  'The Restoration of Eiganjo // Architect of Restoration',
#  'The Scarab God',
#  'The Torment of Gollum',
#  'The Wandering Emperor',
#  'The War Games',
#  'The Wilds',
#  "The Witch's Vanity",
#  'Their Number Is Legion',
#  'There Is No Refuge',
#  "Thieves' Tools",
#  'Thopter Architect',
#  'Thopter Assembly',
#  'Thopter Foundry',
#  'Thopter Shop',
#  'Thopter Squadron',
#  'Thornbite Staff',
#  'Thornmantle Striker',
#  'Thornwatch Scarecrow',
#  'Thousand Moons Smithy // Barracks of the Thousand',
#  'Thraben Doomsayer',
#  'Thraben Sentry // Thraben Militia',
#  'Thraben Standard Bearer',
#  'Thran Vigil',
#  'Three Blind Mice',
#  'Threefold Thunderhulk',
#  'Throne of Empires',
#  'Thunderhawk Gunship',
#  'Thundersteel Colossus',
#  'Thwart the Grave',
#  'Tiller of Flesh',
#  'Timely Reinforcements',
#  'Timothar, Baron of Bats',
#  'Tin-Wing Chimera',
#  "Tinker's Tote",
#  'Titan Forge',
#  'Tivash, Gloom Summoner',
#  'Tobias, Doomed Conqueror',
#  'Together Forever',
#  'Toll of the Invasion',
#  'Tolsimir Wolfblood',
#  'Tolsimir, Friend to Wolves',
#  'Tomb Tyrant',
#  'Tomb of Urami',
#  'Too Greedily, Too Deep',
#  'Topple',
#  'Torens, Fist of the Angels',
#  'Torii Watchward',
#  'Tormod, the Desecrator',
#  'Totentanz, Swarm Piper',
#  'Touch the Spirit Realm',
#  'Towashi',
#  'Towashi Guide-Bot',
#  'Toxrill, the Corrosive',
#  'Transluminant',
#  'Transmogrifying Wand',
#  'Traumatic Revelation',
#  'Traveling Plague',
#  'Treacherous Pit-Dweller',
#  'Treasure Map // Treasure Cove',
#  'Treasure Vault',
#  'Treebeard, Gracious Host',
#  'Triad of Fates',
#  "Tribute to Horobi // Echo of Death's Wail",
#  'Tribute to Hunger',
#  'Triplicate Titan',
#  'Triskelavus',
#  'Triskelion',
#  'Triumph of Gerrard',
#  'Trostani Discordant',
#  "Trostani's Judgment",
#  "Trostani's Summoner",
#  "Trostani, Selesnya's Voice",
#  'Truefire Captain',
#  'Truss, Chief Engineer',
#  'Trynn, Champion of Freedom',
#  'Tumble Magnet',
#  'Tura Kennerüd, Skyknight',
#  'Twilight Drover',
#  'Twilight Shepherd',
#  'Twisted Embrace',
#  'Twisted Sewer-Witch',
#  'Tymaret Calls the Dead',
#  'Tyrannical Pitlord',
#  'Tyrite Sanctum',
#  'Tyvar Kell',
#  'Tyvar the Bellicose',
#  'UNIT Headquarters',
#  'Uchuulon',
#  "Ugin's Conjurant",
#  'Ugin, the Ineffable',
#  'Uglúk of the White Hand',
#  'Ukkima, Stalking Shadow',
#  'Ulder Ravengard, Marshal',
#  'Ultramarines Honour Guard',
#  'Umbral Juke',
#  "Umezawa's Jitte",
#  'Unassuming Sage',
#  'Unbreakable Bond',
#  'Unbreathing Horde',
#  'Undead Augur',
#  'Undead Servant',
#  'Undercellar Sweep',
#  'Undercity Scavenger',
#  'Undercity Uprising',
#  "Undercity's Embrace",
#  'Underworld Hermit',
#  'Underworld Sentinel',
#  'Undying Evil',
#  'Undying Malice',
#  'Unerring Sling',
#  'Unexpected Fangs',
#  'Unforgiving One',
#  'Unholy Indenture',
#  'Unified Front',
#  'Unified Strike',
#  'Unlicensed Disintegration',
#  'Unnatural Hunger',
#  'Unruly Mob',
#  'Unscythe, Killer of Kings',
#  'Unspeakable Symbol',
#  'Untethered Express',
#  'Unwavering Initiate',
#  'Unyaro',
#  'Urbis Protector',
#  'Urborg Justice',
#  'Urborg Shambler',
#  'Urge to Feed',
#  'Urtet, Remnant of Memnarch',
#  "Urza's Factory",
#  'Urza, Chief Artificer',
#  'Urza, Prince of Kroog',
#  'Usher of the Fallen',
#  'Valentin, Dean of the Vein // Lisette, Dean of the Root',
#  'Valiant Endeavor',
#  'Valiant Rescuer',
#  'Valiant Veteran',
#  'Valkyrie Harbinger',
#  "Valkyrie's Sword",
#  'Valor in Akros',
#  'Valor of the Worthy',
#  'Valorous Steed',
#  'Vampire Envoy',
#  'Vampire Outcasts',
#  'Vampire Scrivener',
#  'Vampire Socialite',
#  'Vampiric Dragon',
#  'Vampiric Embrace',
#  'Vampiric Sliver',
#  'Vampirism',
#  'Vanguard of Brimaz',
#  'Vanguard of the Rose',
#  'Vanish into Memory',
#  'Varina, Lich Queen',
#  'Varolz, the Scar-Striped',
#  'Vashta Nerada',
#  'Vat of Rebirth',
#  'Vault 101: Birthday Party',
#  'Vazi, Keen Negotiator',
#  'Vebulid',
#  'Veil of Assimilation',
#  'Vein Drinker',
#  'Velis Vel',
#  'Venerable Knight',
#  'Venerable Warsinger',
#  'Venerated Loxodon',
#  'Vengeance',
#  'Vengeant Vampire',
#  'Vengeful Dead',
#  'Vengeful Vampire',
#  'Venomcrawler',
#  'Venser, Corpse Puppet',
#  'Vessel of Ephemera',
#  'Veteran Soldier',
#  'Veteran Warleader',
#  'Veteran of the Depths',
#  "Veteran's Armaments",
#  "Vexyr, Ich-Tekik's Heir",
#  'Vhal, Scholar of Mortality',
#  'Vhal, Scholar of Tactics',
#  'Vhati il-Dal',
#  'Vicious Battlerager',
#  "Victory's Envoy",
#  'Vigil for the Lost',
#  'Vigor Mortis',
#  'Vikya, Scorching Stalwart',
#  'Vile Deacon',
#  'Vile Rebirth',
#  'Vile Requiem',
#  'Village Cannibals',
#  'Vindictive Vampire',
#  'Violet Pall',
#  'Viridian Longbow',
#  'Virtue of Loyalty // Ardenvale Fealty',
#  "Virtue's Ruin",
#  'Virulent Plague',
#  'Virulent Wound',
#  'Vish Kal, Blood Arbiter',
#  'Vishgraz, the Doomhive',
#  'Visionary Augmenter',
#  'Visions of Glory',
#  'Vislor Turlough',
#  'Vitality Hunter',
#  "Vito's Inquisitor",
#  'Vito, Fanatic of Aclazotz',
#  'Vitu-Ghazi Guildmage',
#  'Vitu-Ghazi, the City-Tree',
#  'Vivisection Evangelist',
#  'Vizier of Remedies',
#  'Vizier of the Scorpion',
#  'Vladimir and Godfrey',
#  'Vodalian Wave-Knight',
#  'Vodalian Zombie',
#  'Vogar, Necropolis Tyrant',
#  'Voice of Duty',
#  'Voice of Resurgence',
#  'Voice of Truth',
#  'Voice of the Blessed',
#  'Voice of the Provinces',
#  'Voidwing Hybrid',
#  'Voldaren Bloodcaster // Bloodbat Summoner',
#  'Voldaren Pariah // Abolisher of Bloodlines',
#  "Volrath's Laboratory",
#  'Volrath, the Shapestealer',
#  'Voodoo Doll',
#  'Voracious Fell Beast',
#  'Voracious Hatchling',
#  'Voracious Null',
#  'Voracious Vacuum',
#  'Voracious Vampire',
#  'Voracious Vermin',
#  'Vorrac Battlehorns',
#  'Vraska the Unseen',
#  "Vraska's Contempt",
#  "Vraska's Fall",
#  "Vraska, Betrayal's Sting",
#  'Vraska, Regal Gorgon',
#  'Vraska, Relic Seeker',
#  "Vraska, Swarm's Eminence",
#  'Vulpine Harvester',
#  'Vulshok Battlegear',
#  'Vulshok Gauntlets',
#  'Vulturous Aven',
#  'Vulturous Zombie',
#  'Wake the Dead',
#  'Wake the Dragon',
#  'Wake the Reflections',
#  'Wakedancer',
#  'Walker of the Wastes',
#  'Walking Archive',
#  'Walking Ballista',
#  'Wall of Limbs',
#  'Wall of Resurgence',
#  'Wall of Reverence',
#  'Wand of Orcus',
#  'Wand of the Elements',
#  'Wandermare',
#  'Wanted Scoundrels',
#  'War Oracle',
#  'War Report',
#  'Warchanter Skald',
#  'Warden of the First Tree',
#  'Warden of the Inner Sky',
#  'Warehouse Tabby',
#  'Warg Rider',
#  'Warped Physique',
#  'Warping Wail',
#  'Warrant // Warden',
#  'Warren Weirding',
#  'Warteye Witch',
#  'Wasitora, Nekoru Queen',
#  'Waste Management',
#  'Watcher of the Spheres',
#  'Watchful Giant',
#  'Watchwing Scarecrow',
#  'Water Gun Balloon Game',
#  'Wave of Rats',
#  'Waveskimmer Aven',
#  'Waxmane Baku',
#  'Wayfaring Temple',
#  'Waylay',
#  'Wayward Angel',
#  'Wayward Servant',
#  'Weapon Rack',
#  'Weaponcraft Enthusiast',
#  'Weaponized Scrap',
#  'Weatherlight Compleated',
#  'Wedding Announcement // Wedding Festivity',
#  'Wedding Invitation',
#  'Wedding Ring',
#  'Wedding Security',
#  'Weeping Angel',
#  'Wei Assassins',
#  'Weirding Shaman',
#  'Welkin Guide',
#  'Well of Lost Dreams',
#  'Werefox Bodyguard',
#  "Wernog, Rider's Chaplain",
#  'Western Paladin',
#  'Westvale Abbey // Ormendahl, Profane Prince',
#  'Whalebone Glider',
#  'When Fluffy Bunnies Attack',
#  'When We Were Young',
#  'Whirlermaker',
#  'Whisper, Blood Liturgist',
#  'White Mana Battery',
#  "White Sun's Twilight",
#  "White Sun's Zenith",
#  'White Ward',
#  'Who // What // When // Where // Why',
#  'Wicked Guardian',
#  'Wicked Visitor',
#  'Widespread Brutality',
#  'Wight',
#  'Wight of Precinct Six',
#  'Wildfire Awakener',
#  'Wilhelt, the Rotcleaver',
#  'Will of the All-Hunter',
#  'Willowdusk, Essence Seer',
#  'Wilt-Leaf Liege',
#  'Winding Constrictor',
#  'Windwright Mage',
#  'Wine of Blood and Iron',
#  'Wingmantle Chaplain',
#  'Wingmate Roc',
#  'Wingrattle Scarecrow',
#  'Wings of the Guard',
#  'Wingsteed Rider',
#  'Wintermoor Commander',
#  'Wire Surgeons',
#  'Wirefly Hive',
#  'Wispweaver Angel',
#  "Witch's Oven",
#  'Witch-Maw Nephilim',
#  'Witch-king, Sky Scourge',
#  'Withering Wisps',
#  "Wizard's Rockets",
#  'Wizened Cenn',
#  'Woe Strider',
#  'Woebearer',
#  'Woeleecher',
#  'Wojek Siren',
#  'Wolf in _____ Clothing',
#  "Wolfhunter's Quiver",
#  'Woodlurker Mimic',
#  'Woodwraith Corrupter',
#  'Word of Binding',
#  'Workshop Assistant',
#  'Worldsoul Colossus',
#  'Worm Harvest',
#  'Worthy Knight',
#  'Wreck Hunter',
#  'Wretched Anurid',
#  'Wretched Banquet',
#  "Wurm's Tooth",
#  'Wurmcoil Engine',
#  'Wyll of the Celestial Pact',
#  'Wyll of the Fiend Pact',
#  "Wyrm's Crossing Patrol",
#  'Xantcha',
#  'Xanthic Statue',
#  'Xathrid Demon',
#  'Xathrid Necromancer',
#  'Xavier Sal, Infested Captain',
#  'Xenic Poltergeist',
#  'Xenk, Paladin Unbroken',
#  'Xenosquirrels',
#  'Xira, the Golden Sting',
#  'Yahenni, Undying Partisan',
#  'Yannik, Scavenging Sentinel',
#  "Yarok's Fenlurker",
#  "Yawgmoth's Vile Offering",
#  'Yawgmoth, Thran Physician',
#  'Yenna, Redtooth Regent',
#  'Yoke of the Damned',
#  'Yore-Tiller Nephilim',
#  'Yoshimaru, Ever Faithful',
#  'Yotian Dissident',
#  'Yotian Frontliner',
#  'Yotian Tactician',
#  'You Hear Something on Watch',
#  "You're Ambushed on the Road",
#  "You're Confronted by Robbers",
#  "You're in Command",
#  'Youthful Valkyrie',
#  'Yukora, the Prisoner',
#  'Zabaz, the Glimmerwasp',
#  'Zagras, Thief of Heartbeats',
#  'Zanikev Locust',
#  'Zar Ojanen, Scion of Efrava',
#  'Zaxara, the Exemplary',
#  'Zealots en-Dal',
#  'Zedruu the Greathearted',
#  'Zenith Flare',
#  'Zeriam, Golden Wind',
#  'Zethi, Arcane Blademaster',
#  'Zhalfirin Commander',
#  'Zhalfirin Decoy',
#  'Zhalfirin Lancer',
#  'Zhentarim Bandit',
#  'Ziatora, the Incinerator',
#  'Zombie Apocalypse',
#  'Zombie Brute',
#  'Zombie Fanboy',
#  'Zombie Infestation',
#  'Zombie Mob',
#  'Zombie Outlander',
#  'Zombify',
#  'Zuberi, Golden Feather',
#  'Zulaport Cutthroat',
#  'Zur, Eternal Schemer',
#  'Zurgo Helmsmasher',
#  '_____ Bird Gets the Worm',
#  '_____ _____ Rocketship',
#  'capital offense',
#  'Éomer, King of Rohan',
#  'Éowyn, Fearless Knight',
#  'Éowyn, Shieldmaiden'}

# %%
target_power = calculate_power('C:/users/theod/edh-llm/data/test_deck.txt')
target_power
# Out:
# {'overall': '12.87',
#  'cmc': '3',
#  'ramp': '12',
#  'draw': '35',
#  'interaction': '9'}

# %%
selected = [cmdr]
selected
# Out:
# ['Elenda, the Dusk Rose']

# %%
client = OpenAI(api_key='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')

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are building a commander deck for magic the gathering. You will be given a pool of already selected cards, a candidate pool, some hueristics of the cards already selected as well as a target hueristic score. Select five the cards from the candidate pool that will move the current hueristic score toward the target score. Return simply the names of the cards you have selected, separated by semi-colons"},
    {"role": "user", "content": \
    "Selected: " + ""+\
    "Candidate Pool: " + '; '.join(pool) + \
    "Current Power: " + "" + \
    "Target Power: " + str(target_power)}
  ]
)

print(completion.choices[0].message.content)
# Out:
# Ugin, the Ineffable; Trostani's Summoner; Triskelavus; Thornbite Staff; Thornwatch Scarecrow

# %%
picked = completion.choices[0].message.content
picked = picked.split('; ')
picked
# Out:
# ['Ugin, the Ineffable',
#  "Trostani's Summoner",
#  'Triskelavus',
#  'Thornbite Staff',
#  'Thornwatch Scarecrow']

# %%
for card in picked:
    if card in pool:
        pool.remove(card)
        selected.append(card)
    else:
        print('failed to find ' + card)

selected
# Out:
# ['Elenda, the Dusk Rose',
#  'Ugin, the Ineffable',
#  "Trostani's Summoner",
#  'Triskelavus',
#  'Thornbite Staff',
#  'Thornwatch Scarecrow']

# %%
with open("../data/temp_deck.txt", "a") as file:
    for string in selected:
        file.write("1 " + string + "\n")
    selected = []

# %%
cur_power = calculate_power('C:/users/theod/edh-llm/data/temp_deck.txt')
# Out:
# {'overall': '0.67', 'cmc': '3', 'ramp': '0', 'draw': '0', 'interaction': '0'}

# %%
with open("../data/temp_deck.txt", "a+") as file:
    file.seek(0)
    print(file.readlines())
    print(file.readlines())
# Out:
# ['1 Elenda, the Dusk Rose\n', '1 Ugin, the Ineffable\n', "1 Trostani's Summoner\n", '1 Triskelavus\n', '1 Thornbite Staff\n', '1 Thornwatch Scarecrow\n']
# []
