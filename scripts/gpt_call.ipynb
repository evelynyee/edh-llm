# %%
from openai import OpenAI
import pickle

# %%
def load_data(fp):
    with open(fp, "rb") as f:
        data = pickle.load(f)
    return data

# %%
data = load_data('../data/decks/manual.pkl')
data
# Out:
#            Elenda, the Dusk Rose                       Ghave, Guru of Spores  \
# 0         Xira, the Golden Sting                     Zegana, Utopian Speaker
# 1       Ziatora, the Incinerator                    Yorvo, Lord of Garenbrig
# 2            Xathrid Necromancer                            Yotian Dissident
# 3    Yannik, Scavenging Sentinel                                  Young Wolf
# 4           Widespread Brutality                      Zabaz, the Glimmerwasp
# ..                           ...                                         ...
# 495                  Tomb Tyrant                          Topography Tracker
# 496           White Mana Battery  Voldaren Pariah // Abolisher of Bloodlines
# 497   Sword of Truth and Justice  Voldaren Pariah // Abolisher of Bloodlines
# 498            Squire's Devotion                            Valiant Endeavor
# 499              Torii Watchward                                    Tervigon
#
# ...

# %%
data['Elenda, ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\theod\.conda\envs\DSC180\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data[0]
#
# ...

# %%
client = OpenAI(api_key='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')

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are building a commander deck for magic the gathering. You will be given a pool of already selected cards, a candidate pool, some hueristics of the cards already selected as well as a target hueristic score. Select one of the cards from the candidate pool that will move the current hueristic score toward the target score"},
    {"role": "user", "content": ""}
  ]
)

print(completion.choices[0].message)
